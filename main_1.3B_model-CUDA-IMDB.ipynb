# %% [markdown]
# ## TODO
# - start med student har samme arkitæktur som ensemble (kinda done)
# - fix some of the plots for the ensemble that broke (i think they broke when changing size of the ensemble and or epochs)
# - do more comparative analysis of the student model and ensemble

# %% [markdown]
# # Embed dataset:

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, accuracy_score, ConfusionMatrixDisplay, log_loss, f1_score
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
import warnings

# %%
# Check for GPU
if torch.backends.mps.is_available():
    device = torch.device('mps')
    print('Using MPS device')
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print('Using CUDA device')
else:
    device = torch.device('cpu')
    print('No GPU found. Using CPU')
# Out:
# Using MPS device

# %%
# Paths to save/load embeddings and labels
imdb_train_embeddings_file = 'imdb_train_embeddings.npy'
imdb_train_labels_file = 'imdb_train_labels.npy'

imdb_train_embeddings = np.load(imdb_train_embeddings_file)
imdb_train_labels = np.load(imdb_train_labels_file)
print("Loaded train, validation, and test embeddings and labels from disk.")
# Out:
# Loaded train, validation, and test embeddings and labels from disk.

# %%
imdb_train_embeddings, imdb_test_embeddings, imdb_train_labels, imdb_test_labels = train_test_split(
        imdb_train_embeddings, 
        imdb_train_labels, 
        test_size=0.20,       # This specifies that 20% of the data goes to the distil
        random_state=42,      # Ensures reproducibility
        stratify=imdb_train_labels # Ensures that the class distribution is preserved
    )

print(f"Train embeddings shape: {imdb_train_embeddings.shape}")
print(f"Train labels shape: {imdb_train_labels.shape}")
print(f"Test embeddings shape: {imdb_test_embeddings.shape}")
print(f"Test labels shape: {imdb_test_labels.shape}")
# Out:
# Train embeddings shape: (20000, 2048)
# Train labels shape: (20000,)
# Test embeddings shape: (5000, 2048)
# Test labels shape: (5000,)

# %% [markdown]
# # Ensemble training

# %%
# Ensure reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Number of MLPs in the ensemble
N = 100
batch_size = 2024
epochs = 10
hidden_size = 128

class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=64, output_size=2):
        super(MLP, self).__init__()
        # Input layer to first hidden layer
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        # Optional dropout to help prevent overfitting
        self.dropout1 = nn.Dropout(p=0.5)
        # First hidden layer to second hidden layer
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.dropout2 = nn.Dropout(p=0.5)
        # Second hidden layer to output layer
        self.fc3 = nn.Linear(hidden_dim2, output_size)
    
    def forward(self, x):
        # First hidden layer with ReLU activation
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        # Second hidden layer with ReLU activation
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        # Output layer
        x = self.fc3(x)
        # returns the logits
        return x

# Load your embeddings and labels (assuming they are already loaded)
# train_embeddings, train_labels, validation_embeddings, validation_labels, test_embeddings, test_labels

# Convert data to PyTorch tensors
# train_X = torch.from_numpy(train80_embeddings).float()
# train_y = torch.from_numpy(train80_labels).long()
train_X = torch.from_numpy(imdb_train_embeddings).float()
train_y = torch.from_numpy(imdb_train_labels).long()
val_X = torch.from_numpy(imdb_test_embeddings).float()
val_y = torch.from_numpy(imdb_test_labels).long()

# Create data loaders
train_dataset = TensorDataset(train_X, train_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

ensemble_models = []

# Metrics storage
ensemble_sizes = []
accuracies = []
nlls = []
eces = []
f1_list = []

# Function to compute Expected Calibration Error
def compute_ece(probs, labels, n_bins=10, mode='ECE'):
    """
    Compute Expected Calibration Error (ECE), Weighted ECE, or Maximum Calibration Error (MCE).

    Args:
        probs (np.ndarray): Predicted probabilities (shape: [n_samples, n_classes]).
        labels (np.ndarray): Ground truth labels (shape: [n_samples]).
        n_bins (int): Number of bins for confidence intervals.
        mode (str): Type of calibration error to compute ('ECE', 'wECE', 'MCE').

    Returns:
        float: Calibration error (ECE, wECE, or MCE).
    """
    assert probs.ndim == 2, "probs must be a 2D array with shape (n_samples, n_classes)"
    assert probs.shape[0] == labels.shape[0], "probs and labels must have the same number of samples"
    assert np.allclose(np.sum(probs, axis=1), 1, atol=1e-6), "Each row of probs must sum to 1"

    bin_boundaries = np.linspace(0, 1, n_bins + 1)
    bin_lowers = bin_boundaries[:-1]
    bin_uppers = bin_boundaries[1:]

    confidences = np.max(probs, axis=1)
    predictions = np.argmax(probs, axis=1)
    accuracies = predictions == labels

    ece = 0.0
    max_calib_error = 0.0
    for bin_lower, bin_upper in zip(bin_lowers, bin_uppers):
        # Handle last bin's inclusion
        if bin_upper == 1.0:
            in_bin = np.logical_and(confidences >= bin_lower, confidences <= bin_upper)
        else:
            in_bin = np.logical_and(confidences >= bin_lower, confidences < bin_upper)

        prop_in_bin = np.mean(in_bin)
        if in_bin.sum() > 0:  # Only process non-empty bins
            accuracy_in_bin = np.mean(accuracies[in_bin])
            avg_confidence_in_bin = np.mean(confidences[in_bin])

            calib_error = np.abs(avg_confidence_in_bin - accuracy_in_bin)
            ece += prop_in_bin * calib_error
            max_calib_error = max(max_calib_error, calib_error)

    if mode == 'ECE':
        return ece
    elif mode == 'MCE':
        return max_calib_error
    else:
        raise ValueError(f"Unsupported mode: {mode}. Choose 'ECE' or 'MCE'.")

# %%
# Training and evaluation loop
for n in range(1, N + 1):
    print(f"Training MLP {n}/{N}")
    input_size = train_X.shape[1]
    model = MLP(input_size, hidden_size, output_size=2).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    
    # Train the model
    model.train()
    for epoch in range(epochs):
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    # Evaluate the current individual model
    model.eval()
    with torch.no_grad():
        outputs = model(val_X.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        preds = np.argmax(probs, axis=1)
        
        single_probs = probs
        
        # Compute individual model metrics
        acc = accuracy_score(val_y.numpy(), preds)
        nll = log_loss(val_y.numpy(), probs)
        ece = compute_ece(probs, val_y.numpy())
        f1 = f1_score(val_y.numpy(),preds)
        
        print(f"Validation -- Model {n}: Accuracy = {acc:.4f}, NLL = {nll:.4f}, ECE = {ece:.4f}, F1 = {f1:.4f}")
    

    # Add the trained model to the ensemble
    ensemble_models.append(model)
    
    # Evaluate the ensemble up to the current number of models
    model.eval()
    with torch.no_grad():
        # Collect outputs from each model in the ensemble
        ensemble_outputs = []
        for m in ensemble_models:
            outputs = m(val_X.to(device))
            probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
            ensemble_outputs.append(probs)
        
        # Average the probabilities
        ensemble_probs = np.mean(ensemble_outputs, axis=0)
        ensemble_preds = np.argmax(ensemble_probs, axis=1)
        
        # Compute metrics
        acc = accuracy_score(val_y.numpy(), ensemble_preds)
        nll = log_loss(val_y.numpy(), ensemble_probs)
        ece = compute_ece(ensemble_probs, val_y.numpy())
        f1 = f1_score(val_y.numpy(), ensemble_preds, average='weighted')  # Using weighted averaging
        
        # Store metrics
        ensemble_sizes.append(n)
        accuracies.append(acc)
        nlls.append(nll)
        eces.append(ece)
        f1_list.append(f1)
        
        print(f"Validation -- Ensemble Size {n}: Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")

# Plot metrics as a function of ensemble size
plt.figure(figsize=(16, 4))

plt.subplot(1, 4, 1)
plt.plot(ensemble_sizes, accuracies, marker='o')
plt.title('Accuracy vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 4, 2)
plt.plot(ensemble_sizes, nlls, marker='o', color='orange')
plt.title('NLL vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Negative Log-Likelihood')
plt.grid(True)

plt.subplot(1, 4, 3)
plt.plot(ensemble_sizes, eces, marker='o', color='green')
plt.title('ECE vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Expected Calibration Error')
plt.grid(True)

# F1 Score Plot
plt.subplot(1, 4, 4)
plt.plot(ensemble_sizes, f1_list, marker='o', color='purple')
plt.title('F1 Score vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('F1 Score')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Training MLP 1/100
# Validation -- Model 1: Accuracy = 0.8706, NLL = 0.3114, ECE = 0.0224, F1 = 0.8714
# Validation -- Ensemble Size 1: Accuracy: 0.8706, NLL: 0.3114, ECE: 0.0224, F1 Score: 0.8706
# Training MLP 2/100
# Validation -- Model 2: Accuracy = 0.8732, NLL = 0.3077, ECE = 0.0197, F1 = 0.8738
# Validation -- Ensemble Size 2: Accuracy: 0.8724, NLL: 0.3066, ECE: 0.0179, F1 Score: 0.8724
# Training MLP 3/100
# Validation -- Model 3: Accuracy = 0.8686, NLL = 0.3121, ECE = 0.0171, F1 = 0.8699
# Validation -- Ensemble Size 3: Accuracy: 0.8718, NLL: 0.3067, ECE: 0.0165, F1 Score: 0.8718
# Training MLP 4/100
# Validation -- Model 4: Accuracy = 0.8704, NLL = 0.3104, ECE = 0.0229, F1 = 0.8698
# Validation -- Ensemble Size 4: Accuracy: 0.8730, NLL: 0.3061, ECE: 0.0184, F1 Score: 0.8730
# Training MLP 5/100
# Validation -- Model 5: Accuracy = 0.8724, NLL = 0.3104, ECE = 0.0222, F1 = 0.8723
# Validation -- Ensemble Size 5: Accuracy: 0.8742, NLL: 0.3059, ECE: 0.0181, F1 Score: 0.8742
# Training MLP 6/100
# Validation -- Model 6: Accuracy = 0.8726, NLL = 0.3117, ECE = 0.0232, F1 = 0.8720
# Validation -- Ensemble Size 6: Accuracy: 0.8724, NLL: 0.3059, ECE: 0.0181, F1 Score: 0.8724
# Training MLP 7/100
# Validation -- Model 7: Accuracy = 0.8716, NLL = 0.3083, ECE = 0.0222, F1 = 0.8719
# Validation -- Ensemble Size 7: Accuracy: 0.8726, NLL: 0.3054, ECE: 0.0172, F1 Score: 0.8726
# Training MLP 8/100
# Validation -- Model 8: Accuracy = 0.8688, NLL = 0.3116, ECE = 0.0213, F1 = 0.8681
# Validation -- Ensemble Size 8: Accuracy: 0.8738, NLL: 0.3055, ECE: 0.0175, F1 Score: 0.8738
# Training MLP 9/100
# Validation -- Model 9: Accuracy = 0.8694, NLL = 0.3113, ECE = 0.0220, F1 = 0.8687
# Validation -- Ensemble Size 9: Accuracy: 0.8728, NLL: 0.3054, ECE: 0.0169, F1 Score: 0.8728
# Training MLP 10/100
# Validation -- Model 10: Accuracy = 0.8732, NLL = 0.3096, ECE = 0.0199, F1 = 0.8735
# Validation -- Ensemble Size 10: Accuracy: 0.8738, NLL: 0.3052, ECE: 0.0167, F1 Score: 0.8738
# Training MLP 11/100
# Validation -- Model 11: Accuracy = 0.8716, NLL = 0.3141, ECE = 0.0216, F1 = 0.8710
# Validation -- Ensemble Size 11: Accuracy: 0.8734, NLL: 0.3055, ECE: 0.0168, F1 Score: 0.8734
# Training MLP 12/100
# Validation -- Model 12: Accuracy = 0.8688, NLL = 0.3139, ECE = 0.0210, F1 = 0.8681
# Validation -- Ensemble Size 12: Accuracy: 0.8724, NLL: 0.3056, ECE: 0.0152, F1 Score: 0.8724
# Training MLP 13/100
# Validation -- Model 13: Accuracy = 0.8716, NLL = 0.3107, ECE = 0.0206, F1 = 0.8720
# Validation -- Ensemble Size 13: Accuracy: 0.8732, NLL: 0.3055, ECE: 0.0162, F1 Score: 0.8732
# Training MLP 14/100
# Validation -- Model 14: Accuracy = 0.8698, NLL = 0.3176, ECE = 0.0282, F1 = 0.8683
# Validation -- Ensemble Size 14: Accuracy: 0.8732, NLL: 0.3057, ECE: 0.0164, F1 Score: 0.8732
# Training MLP 15/100
# Validation -- Model 15: Accuracy = 0.8694, NLL = 0.3119, ECE = 0.0218, F1 = 0.8682
# Validation -- Ensemble Size 15: Accuracy: 0.8728, NLL: 0.3058, ECE: 0.0159, F1 Score: 0.8728
# Training MLP 16/100
# Validation -- Model 16: Accuracy = 0.8692, NLL = 0.3146, ECE = 0.0205, F1 = 0.8691
# Validation -- Ensemble Size 16: Accuracy: 0.8728, NLL: 0.3059, ECE: 0.0159, F1 Score: 0.8728
# Training MLP 17/100
# Validation -- Model 17: Accuracy = 0.8696, NLL = 0.3132, ECE = 0.0196, F1 = 0.8698
# Validation -- Ensemble Size 17: Accuracy: 0.8736, NLL: 0.3059, ECE: 0.0181, F1 Score: 0.8736
# Training MLP 18/100
# Validation -- Model 18: Accuracy = 0.8724, NLL = 0.3112, ECE = 0.0261, F1 = 0.8719
# Validation -- Ensemble Size 18: Accuracy: 0.8734, NLL: 0.3059, ECE: 0.0185, F1 Score: 0.8734
# Training MLP 19/100
# Validation -- Model 19: Accuracy = 0.8666, NLL = 0.3159, ECE = 0.0304, F1 = 0.8659
# Validation -- Ensemble Size 19: Accuracy: 0.8726, NLL: 0.3060, ECE: 0.0180, F1 Score: 0.8726
# Training MLP 20/100
# Validation -- Model 20: Accuracy = 0.8716, NLL = 0.3116, ECE = 0.0189, F1 = 0.8719
# Validation -- Ensemble Size 20: Accuracy: 0.8722, NLL: 0.3057, ECE: 0.0178, F1 Score: 0.8722
# Training MLP 21/100
# Validation -- Model 21: Accuracy = 0.8696, NLL = 0.3126, ECE = 0.0228, F1 = 0.8693
# Validation -- Ensemble Size 21: Accuracy: 0.8722, NLL: 0.3058, ECE: 0.0165, F1 Score: 0.8722
# Training MLP 22/100
# Validation -- Model 22: Accuracy = 0.8716, NLL = 0.3090, ECE = 0.0189, F1 = 0.8715
# Validation -- Ensemble Size 22: Accuracy: 0.8712, NLL: 0.3057, ECE: 0.0163, F1 Score: 0.8712
# Training MLP 23/100
# Validation -- Model 23: Accuracy = 0.8692, NLL = 0.3132, ECE = 0.0255, F1 = 0.8690
# Validation -- Ensemble Size 23: Accuracy: 0.8716, NLL: 0.3057, ECE: 0.0169, F1 Score: 0.8716
# Training MLP 24/100
# Validation -- Model 24: Accuracy = 0.8670, NLL = 0.3143, ECE = 0.0228, F1 = 0.8668
# Validation -- Ensemble Size 24: Accuracy: 0.8716, NLL: 0.3058, ECE: 0.0162, F1 Score: 0.8716
# Training MLP 25/100
# Validation -- Model 25: Accuracy = 0.8704, NLL = 0.3159, ECE = 0.0251, F1 = 0.8699
# Validation -- Ensemble Size 25: Accuracy: 0.8720, NLL: 0.3059, ECE: 0.0174, F1 Score: 0.8720
# Training MLP 26/100
# Validation -- Model 26: Accuracy = 0.8724, NLL = 0.3136, ECE = 0.0206, F1 = 0.8735
# Validation -- Ensemble Size 26: Accuracy: 0.8718, NLL: 0.3060, ECE: 0.0165, F1 Score: 0.8718
# Training MLP 27/100
# Validation -- Model 27: Accuracy = 0.8722, NLL = 0.3123, ECE = 0.0221, F1 = 0.8715
# Validation -- Ensemble Size 27: Accuracy: 0.8718, NLL: 0.3060, ECE: 0.0159, F1 Score: 0.8718
# Training MLP 28/100
# Validation -- Model 28: Accuracy = 0.8736, NLL = 0.3123, ECE = 0.0234, F1 = 0.8734
# Validation -- Ensemble Size 28: Accuracy: 0.8726, NLL: 0.3060, ECE: 0.0174, F1 Score: 0.8726
# Training MLP 29/100
# Validation -- Model 29: Accuracy = 0.8688, NLL = 0.3124, ECE = 0.0248, F1 = 0.8685
# Validation -- Ensemble Size 29: Accuracy: 0.8716, NLL: 0.3060, ECE: 0.0162, F1 Score: 0.8716
# Training MLP 30/100
# Validation -- Model 30: Accuracy = 0.8674, NLL = 0.3153, ECE = 0.0260, F1 = 0.8688
# Validation -- Ensemble Size 30: Accuracy: 0.8718, NLL: 0.3061, ECE: 0.0170, F1 Score: 0.8718
# Training MLP 31/100
# Validation -- Model 31: Accuracy = 0.8706, NLL = 0.3099, ECE = 0.0165, F1 = 0.8703
# Validation -- Ensemble Size 31: Accuracy: 0.8716, NLL: 0.3059, ECE: 0.0167, F1 Score: 0.8716
# Training MLP 32/100
# Validation -- Model 32: Accuracy = 0.8704, NLL = 0.3141, ECE = 0.0219, F1 = 0.8699
# Validation -- Ensemble Size 32: Accuracy: 0.8722, NLL: 0.3060, ECE: 0.0166, F1 Score: 0.8722
# Training MLP 33/100
# Validation -- Model 33: Accuracy = 0.8680, NLL = 0.3147, ECE = 0.0239, F1 = 0.8671
# Validation -- Ensemble Size 33: Accuracy: 0.8720, NLL: 0.3061, ECE: 0.0166, F1 Score: 0.8720
# Training MLP 34/100
# Validation -- Model 34: Accuracy = 0.8678, NLL = 0.3172, ECE = 0.0222, F1 = 0.8656
# Validation -- Ensemble Size 34: Accuracy: 0.8722, NLL: 0.3061, ECE: 0.0165, F1 Score: 0.8722
# Training MLP 35/100
# Validation -- Model 35: Accuracy = 0.8734, NLL = 0.3115, ECE = 0.0242, F1 = 0.8736
# Validation -- Ensemble Size 35: Accuracy: 0.8718, NLL: 0.3061, ECE: 0.0162, F1 Score: 0.8718
# Training MLP 36/100
# Validation -- Model 36: Accuracy = 0.8706, NLL = 0.3090, ECE = 0.0192, F1 = 0.8706
# Validation -- Ensemble Size 36: Accuracy: 0.8718, NLL: 0.3060, ECE: 0.0165, F1 Score: 0.8718
# Training MLP 37/100
# Validation -- Model 37: Accuracy = 0.8702, NLL = 0.3128, ECE = 0.0209, F1 = 0.8690
# Validation -- Ensemble Size 37: Accuracy: 0.8722, NLL: 0.3060, ECE: 0.0164, F1 Score: 0.8722
# Training MLP 38/100
# Validation -- Model 38: Accuracy = 0.8700, NLL = 0.3095, ECE = 0.0178, F1 = 0.8690
# Validation -- Ensemble Size 38: Accuracy: 0.8722, NLL: 0.3059, ECE: 0.0170, F1 Score: 0.8722
# Training MLP 39/100
# Validation -- Model 39: Accuracy = 0.8708, NLL = 0.3110, ECE = 0.0229, F1 = 0.8701
# Validation -- Ensemble Size 39: Accuracy: 0.8720, NLL: 0.3059, ECE: 0.0167, F1 Score: 0.8720
# Training MLP 40/100
# Validation -- Model 40: Accuracy = 0.8710, NLL = 0.3099, ECE = 0.0228, F1 = 0.8713
# Validation -- Ensemble Size 40: Accuracy: 0.8722, NLL: 0.3058, ECE: 0.0166, F1 Score: 0.8722
# Training MLP 41/100
# Validation -- Model 41: Accuracy = 0.8680, NLL = 0.3128, ECE = 0.0198, F1 = 0.8654
# Validation -- Ensemble Size 41: Accuracy: 0.8726, NLL: 0.3058, ECE: 0.0165, F1 Score: 0.8726
# Training MLP 42/100
# Validation -- Model 42: Accuracy = 0.8698, NLL = 0.3188, ECE = 0.0276, F1 = 0.8689
# Validation -- Ensemble Size 42: Accuracy: 0.8726, NLL: 0.3058, ECE: 0.0167, F1 Score: 0.8726
# Training MLP 43/100
# Validation -- Model 43: Accuracy = 0.8708, NLL = 0.3159, ECE = 0.0277, F1 = 0.8704
# Validation -- Ensemble Size 43: Accuracy: 0.8724, NLL: 0.3059, ECE: 0.0163, F1 Score: 0.8724
# Training MLP 44/100
# Validation -- Model 44: Accuracy = 0.8672, NLL = 0.3167, ECE = 0.0223, F1 = 0.8683
# Validation -- Ensemble Size 44: Accuracy: 0.8726, NLL: 0.3059, ECE: 0.0173, F1 Score: 0.8726
# Training MLP 45/100
# Validation -- Model 45: Accuracy = 0.8702, NLL = 0.3131, ECE = 0.0224, F1 = 0.8687
# Validation -- Ensemble Size 45: Accuracy: 0.8730, NLL: 0.3059, ECE: 0.0171, F1 Score: 0.8730
# Training MLP 46/100
# Validation -- Model 46: Accuracy = 0.8692, NLL = 0.3151, ECE = 0.0272, F1 = 0.8689
# Validation -- Ensemble Size 46: Accuracy: 0.8730, NLL: 0.3060, ECE: 0.0174, F1 Score: 0.8730
# Training MLP 47/100
# Validation -- Model 47: Accuracy = 0.8700, NLL = 0.3089, ECE = 0.0192, F1 = 0.8706
# Validation -- Ensemble Size 47: Accuracy: 0.8732, NLL: 0.3059, ECE: 0.0177, F1 Score: 0.8732
# Training MLP 48/100
# Validation -- Model 48: Accuracy = 0.8694, NLL = 0.3087, ECE = 0.0243, F1 = 0.8710
# Validation -- Ensemble Size 48: Accuracy: 0.8728, NLL: 0.3058, ECE: 0.0174, F1 Score: 0.8728
# Training MLP 49/100
# Validation -- Model 49: Accuracy = 0.8706, NLL = 0.3118, ECE = 0.0228, F1 = 0.8689
# Validation -- Ensemble Size 49: Accuracy: 0.8732, NLL: 0.3058, ECE: 0.0176, F1 Score: 0.8732
# Training MLP 50/100
# Validation -- Model 50: Accuracy = 0.8676, NLL = 0.3142, ECE = 0.0240, F1 = 0.8666
# Validation -- Ensemble Size 50: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0172, F1 Score: 0.8730
# Training MLP 51/100
# Validation -- Model 51: Accuracy = 0.8676, NLL = 0.3140, ECE = 0.0259, F1 = 0.8680
# Validation -- Ensemble Size 51: Accuracy: 0.8730, NLL: 0.3059, ECE: 0.0176, F1 Score: 0.8730
# Training MLP 52/100
# Validation -- Model 52: Accuracy = 0.8732, NLL = 0.3102, ECE = 0.0217, F1 = 0.8742
# Validation -- Ensemble Size 52: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0177, F1 Score: 0.8730
# Training MLP 53/100
# Validation -- Model 53: Accuracy = 0.8674, NLL = 0.3139, ECE = 0.0222, F1 = 0.8669
# Validation -- Ensemble Size 53: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0176, F1 Score: 0.8730
# Training MLP 54/100
# Validation -- Model 54: Accuracy = 0.8716, NLL = 0.3114, ECE = 0.0243, F1 = 0.8718
# Validation -- Ensemble Size 54: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0176, F1 Score: 0.8730
# Training MLP 55/100
# Validation -- Model 55: Accuracy = 0.8684, NLL = 0.3109, ECE = 0.0240, F1 = 0.8685
# Validation -- Ensemble Size 55: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0175, F1 Score: 0.8730
# Training MLP 56/100
# Validation -- Model 56: Accuracy = 0.8694, NLL = 0.3147, ECE = 0.0271, F1 = 0.8674
# Validation -- Ensemble Size 56: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0180, F1 Score: 0.8730
# Training MLP 57/100
# Validation -- Model 57: Accuracy = 0.8706, NLL = 0.3126, ECE = 0.0189, F1 = 0.8727
# Validation -- Ensemble Size 57: Accuracy: 0.8730, NLL: 0.3058, ECE: 0.0175, F1 Score: 0.8730
# Training MLP 58/100
# Validation -- Model 58: Accuracy = 0.8698, NLL = 0.3122, ECE = 0.0217, F1 = 0.8706
# Validation -- Ensemble Size 58: Accuracy: 0.8732, NLL: 0.3058, ECE: 0.0180, F1 Score: 0.8732
# Training MLP 59/100
# Validation -- Model 59: Accuracy = 0.8716, NLL = 0.3080, ECE = 0.0185, F1 = 0.8712
# Validation -- Ensemble Size 59: Accuracy: 0.8734, NLL: 0.3057, ECE: 0.0182, F1 Score: 0.8734
# Training MLP 60/100
# Validation -- Model 60: Accuracy = 0.8682, NLL = 0.3109, ECE = 0.0200, F1 = 0.8689
# Validation -- Ensemble Size 60: Accuracy: 0.8728, NLL: 0.3057, ECE: 0.0175, F1 Score: 0.8728
# Training MLP 61/100
# Validation -- Model 61: Accuracy = 0.8718, NLL = 0.3132, ECE = 0.0250, F1 = 0.8711
# Validation -- Ensemble Size 61: Accuracy: 0.8728, NLL: 0.3057, ECE: 0.0174, F1 Score: 0.8728
# Training MLP 62/100
# Validation -- Model 62: Accuracy = 0.8694, NLL = 0.3079, ECE = 0.0166, F1 = 0.8691
# Validation -- Ensemble Size 62: Accuracy: 0.8726, NLL: 0.3057, ECE: 0.0170, F1 Score: 0.8726
# Training MLP 63/100
# Validation -- Model 63: Accuracy = 0.8700, NLL = 0.3094, ECE = 0.0230, F1 = 0.8691
# Validation -- Ensemble Size 63: Accuracy: 0.8730, NLL: 0.3056, ECE: 0.0172, F1 Score: 0.8730
# Training MLP 64/100
# Validation -- Model 64: Accuracy = 0.8744, NLL = 0.3089, ECE = 0.0238, F1 = 0.8746
# Validation -- Ensemble Size 64: Accuracy: 0.8730, NLL: 0.3056, ECE: 0.0172, F1 Score: 0.8730
# Training MLP 65/100
# Validation -- Model 65: Accuracy = 0.8714, NLL = 0.3114, ECE = 0.0220, F1 = 0.8707
# Validation -- Ensemble Size 65: Accuracy: 0.8726, NLL: 0.3056, ECE: 0.0171, F1 Score: 0.8726
# Training MLP 66/100
# Validation -- Model 66: Accuracy = 0.8680, NLL = 0.3196, ECE = 0.0246, F1 = 0.8690
# Validation -- Ensemble Size 66: Accuracy: 0.8726, NLL: 0.3056, ECE: 0.0175, F1 Score: 0.8726
# Training MLP 67/100
# Validation -- Model 67: Accuracy = 0.8704, NLL = 0.3096, ECE = 0.0195, F1 = 0.8692
# Validation -- Ensemble Size 67: Accuracy: 0.8728, NLL: 0.3056, ECE: 0.0172, F1 Score: 0.8728
# Training MLP 68/100
# Validation -- Model 68: Accuracy = 0.8696, NLL = 0.3067, ECE = 0.0192, F1 = 0.8697
# Validation -- Ensemble Size 68: Accuracy: 0.8728, NLL: 0.3055, ECE: 0.0175, F1 Score: 0.8728
# Training MLP 69/100
# Validation -- Model 69: Accuracy = 0.8674, NLL = 0.3073, ECE = 0.0229, F1 = 0.8663
# Validation -- Ensemble Size 69: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0176, F1 Score: 0.8730
# Training MLP 70/100
# Validation -- Model 70: Accuracy = 0.8700, NLL = 0.3133, ECE = 0.0202, F1 = 0.8712
# Validation -- Ensemble Size 70: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0176, F1 Score: 0.8730
# Training MLP 71/100
# Validation -- Model 71: Accuracy = 0.8696, NLL = 0.3113, ECE = 0.0185, F1 = 0.8691
# Validation -- Ensemble Size 71: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0174, F1 Score: 0.8732
# Training MLP 72/100
# Validation -- Model 72: Accuracy = 0.8686, NLL = 0.3097, ECE = 0.0196, F1 = 0.8687
# Validation -- Ensemble Size 72: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0178, F1 Score: 0.8730
# Training MLP 73/100
# Validation -- Model 73: Accuracy = 0.8690, NLL = 0.3118, ECE = 0.0277, F1 = 0.8687
# Validation -- Ensemble Size 73: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0182, F1 Score: 0.8732
# Training MLP 74/100
# Validation -- Model 74: Accuracy = 0.8678, NLL = 0.3143, ECE = 0.0220, F1 = 0.8662
# Validation -- Ensemble Size 74: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0178, F1 Score: 0.8730
# Training MLP 75/100
# Validation -- Model 75: Accuracy = 0.8716, NLL = 0.3106, ECE = 0.0230, F1 = 0.8713
# Validation -- Ensemble Size 75: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0179, F1 Score: 0.8732
# Training MLP 76/100
# Validation -- Model 76: Accuracy = 0.8706, NLL = 0.3106, ECE = 0.0214, F1 = 0.8711
# Validation -- Ensemble Size 76: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0179, F1 Score: 0.8732
# Training MLP 77/100
# Validation -- Model 77: Accuracy = 0.8676, NLL = 0.3107, ECE = 0.0224, F1 = 0.8674
# Validation -- Ensemble Size 77: Accuracy: 0.8728, NLL: 0.3054, ECE: 0.0175, F1 Score: 0.8728
# Training MLP 78/100
# Validation -- Model 78: Accuracy = 0.8702, NLL = 0.3109, ECE = 0.0191, F1 = 0.8694
# Validation -- Ensemble Size 78: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0175, F1 Score: 0.8732
# Training MLP 79/100
# Validation -- Model 79: Accuracy = 0.8646, NLL = 0.3129, ECE = 0.0204, F1 = 0.8637
# Validation -- Ensemble Size 79: Accuracy: 0.8732, NLL: 0.3054, ECE: 0.0176, F1 Score: 0.8732
# Training MLP 80/100
# Validation -- Model 80: Accuracy = 0.8664, NLL = 0.3170, ECE = 0.0266, F1 = 0.8664
# Validation -- Ensemble Size 80: Accuracy: 0.8734, NLL: 0.3054, ECE: 0.0177, F1 Score: 0.8734
# Training MLP 81/100
# Validation -- Model 81: Accuracy = 0.8722, NLL = 0.3109, ECE = 0.0219, F1 = 0.8722
# Validation -- Ensemble Size 81: Accuracy: 0.8728, NLL: 0.3054, ECE: 0.0170, F1 Score: 0.8728
# Training MLP 82/100
# Validation -- Model 82: Accuracy = 0.8702, NLL = 0.3132, ECE = 0.0200, F1 = 0.8699
# Validation -- Ensemble Size 82: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0172, F1 Score: 0.8730
# Training MLP 83/100
# Validation -- Model 83: Accuracy = 0.8738, NLL = 0.3066, ECE = 0.0213, F1 = 0.8737
# Validation -- Ensemble Size 83: Accuracy: 0.8730, NLL: 0.3054, ECE: 0.0173, F1 Score: 0.8730
# Training MLP 84/100
# Validation -- Model 84: Accuracy = 0.8682, NLL = 0.3106, ECE = 0.0198, F1 = 0.8675
# Validation -- Ensemble Size 84: Accuracy: 0.8728, NLL: 0.3054, ECE: 0.0174, F1 Score: 0.8728
# Training MLP 85/100
# Validation -- Model 85: Accuracy = 0.8692, NLL = 0.3111, ECE = 0.0197, F1 = 0.8678
# Validation -- Ensemble Size 85: Accuracy: 0.8728, NLL: 0.3054, ECE: 0.0172, F1 Score: 0.8728
# Training MLP 86/100
# Validation -- Model 86: Accuracy = 0.8698, NLL = 0.3117, ECE = 0.0251, F1 = 0.8689
# Validation -- Ensemble Size 86: Accuracy: 0.8726, NLL: 0.3054, ECE: 0.0172, F1 Score: 0.8726
# Training MLP 87/100
# Validation -- Model 87: Accuracy = 0.8696, NLL = 0.3109, ECE = 0.0243, F1 = 0.8707
# Validation -- Ensemble Size 87: Accuracy: 0.8728, NLL: 0.3053, ECE: 0.0175, F1 Score: 0.8728
# Training MLP 88/100
# Validation -- Model 88: Accuracy = 0.8716, NLL = 0.3114, ECE = 0.0228, F1 = 0.8710
# Validation -- Ensemble Size 88: Accuracy: 0.8728, NLL: 0.3053, ECE: 0.0178, F1 Score: 0.8728
# Training MLP 89/100
# Validation -- Model 89: Accuracy = 0.8704, NLL = 0.3112, ECE = 0.0223, F1 = 0.8712
# Validation -- Ensemble Size 89: Accuracy: 0.8726, NLL: 0.3053, ECE: 0.0172, F1 Score: 0.8726
# Training MLP 90/100
# Validation -- Model 90: Accuracy = 0.8708, NLL = 0.3131, ECE = 0.0236, F1 = 0.8711
# Validation -- Ensemble Size 90: Accuracy: 0.8726, NLL: 0.3054, ECE: 0.0174, F1 Score: 0.8726
# Training MLP 91/100
# Validation -- Model 91: Accuracy = 0.8704, NLL = 0.3152, ECE = 0.0287, F1 = 0.8706
# Validation -- Ensemble Size 91: Accuracy: 0.8724, NLL: 0.3054, ECE: 0.0178, F1 Score: 0.8724
# Training MLP 92/100
# Validation -- Model 92: Accuracy = 0.8724, NLL = 0.3085, ECE = 0.0175, F1 = 0.8718
# Validation -- Ensemble Size 92: Accuracy: 0.8724, NLL: 0.3054, ECE: 0.0176, F1 Score: 0.8724
# Training MLP 93/100
# Validation -- Model 93: Accuracy = 0.8692, NLL = 0.3130, ECE = 0.0251, F1 = 0.8681
# Validation -- Ensemble Size 93: Accuracy: 0.8724, NLL: 0.3054, ECE: 0.0176, F1 Score: 0.8724
# Training MLP 94/100
# Validation -- Model 94: Accuracy = 0.8702, NLL = 0.3127, ECE = 0.0245, F1 = 0.8714
# Validation -- Ensemble Size 94: Accuracy: 0.8722, NLL: 0.3054, ECE: 0.0177, F1 Score: 0.8722
# Training MLP 95/100
# Validation -- Model 95: Accuracy = 0.8726, NLL = 0.3091, ECE = 0.0211, F1 = 0.8738
# Validation -- Ensemble Size 95: Accuracy: 0.8724, NLL: 0.3053, ECE: 0.0174, F1 Score: 0.8724
# Training MLP 96/100
# Validation -- Model 96: Accuracy = 0.8710, NLL = 0.3105, ECE = 0.0219, F1 = 0.8706
# Validation -- Ensemble Size 96: Accuracy: 0.8724, NLL: 0.3053, ECE: 0.0174, F1 Score: 0.8724
# Training MLP 97/100
# Validation -- Model 97: Accuracy = 0.8688, NLL = 0.3119, ECE = 0.0183, F1 = 0.8693
# Validation -- Ensemble Size 97: Accuracy: 0.8724, NLL: 0.3053, ECE: 0.0176, F1 Score: 0.8724
# Training MLP 98/100
# Validation -- Model 98: Accuracy = 0.8684, NLL = 0.3163, ECE = 0.0250, F1 = 0.8684
# Validation -- Ensemble Size 98: Accuracy: 0.8720, NLL: 0.3054, ECE: 0.0177, F1 Score: 0.8720
# Training MLP 99/100
# Validation -- Model 99: Accuracy = 0.8672, NLL = 0.3112, ECE = 0.0197, F1 = 0.8678
# Validation -- Ensemble Size 99: Accuracy: 0.8720, NLL: 0.3054, ECE: 0.0179, F1 Score: 0.8720
# Training MLP 100/100
# Validation -- Model 100: Accuracy = 0.8708, NLL = 0.3120, ECE = 0.0172, F1 = 0.8703
# Validation -- Ensemble Size 100: Accuracy: 0.8718, NLL: 0.3054, ECE: 0.0187, F1 Score: 0.8718

# %% [markdown]
# Har gjort MLPen dybere for at den ikke overfitter i distillation

# %% [markdown]
# ### The method used above for ensemble prediction is averaging (Mean Voting)
#    - **Description**: Each MLP produces a probability distribution over classes or a continuous output. The ensemble output is the average of these predictions.
#    - **Application**: Commonly used for regression tasks or classification tasks where probabilities are averaged.
#    - **Pros**: Simple to implement; works well when individual models are reasonably accurate and diverse.
#    - **Cons**: Does not account for cases where some models are more accurate than others.

# %%
all_probs = []
for model in ensemble_models:
    model.eval()
    with torch.no_grad():
        outputs = model(inputs.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        all_probs.append(probs)

all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)

# Predictive mean (averaged probabilities)
mean_probs = np.mean(all_probs, axis=0)

# Predictive variance (epistemic uncertainty)
variance_probs = np.var(all_probs, axis=0)

# Predictive entropy
entropy = -np.sum(mean_probs * np.log(mean_probs + 1e-9), axis=1)

# %% [markdown]
# ## Predictive Variance Histogram
# Purpose: To see the distribution of uncertainties across all predictions.

# %%
# Sum variances across classes if multi-class (for overall uncertainty)
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.hist(total_variance, bins=50, color='skyblue', edgecolor='black')
plt.title('Histogram of Predictive Variance')
plt.xlabel('Predictive Variance')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Predictive Entropy Histogram
# Purpose: Similar to variance, entropy gives a sense of uncertainty in predictions.

# %%
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Scatter Plots of Uncertainty vs. Confidence
#
# Purpose: To observe the relationship between model confidence and uncertainty.

# %%
# Model confidence: max probability from mean_probs
confidence = np.max(mean_probs, axis=1)

# Total variance or entropy as uncertainty measure
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.scatter(confidence, total_variance, alpha=0.5)
plt.title('Predictive Variance vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Variance')
plt.show()

# %% [markdown]
# ## Uncertainty vs. Correctness
# Purpose: To check if higher uncertainties correspond to incorrect predictions.

# %%
# # Predicted labels
# predicted_labels = np.argmax(mean_probs, axis=1)

# # True labels
# true_labels = val_y.numpy()

# # Correct predictions
# correct = (predicted_labels == true_labels)

# # Total variance or entropy
# total_variance = np.sum(variance_probs, axis=1)

# plt.figure(figsize=(8, 6))
# plt.scatter(total_variance, correct, alpha=0.5, c=correct, cmap='bwr')
# plt.title('Predictive Variance vs. Correctness')
# plt.xlabel('Predictive Variance')
# plt.ylabel('Correct Prediction (1=True, 0=False)')
# plt.show()

# %% [markdown]
# ## Reliability Diagram (Calibration Curve)
# Purpose: To assess how well the predicted probabilities are calibrated.

# %%
def plot_reliability_diagram(prob_pos, true_labels, n_bins=10):
    """
    Compute and plot a reliability diagram.
    
    Parameters:
    - prob_pos: 1D array of predicted probabilities for the positive class.
    - true_labels: 1D array of ground truth binary labels.
    - n_bins: Number of bins in the diagram.
    """
    # Define bins from 0 to 1
    bins = np.linspace(0, 1, n_bins + 1)
    
    # Arrays to store the bin means and fraction of positives
    bin_preds = np.zeros(n_bins)
    bin_true = np.zeros(n_bins)
    bin_counts = np.zeros(n_bins)
    
    for i in range(n_bins):
        # Find samples with predictions in the current bin.
        indices = np.where((prob_pos >= bins[i]) & (prob_pos < bins[i+1]))[0]
        if len(indices) > 0:
            bin_preds[i] = np.mean(prob_pos[indices])
            bin_true[i] = np.mean(true_labels[indices])
            bin_counts[i] = len(indices)
    
    # Plot the reliability diagram
    plt.figure(figsize=(8, 6))
    plt.plot(bin_preds, bin_true, "s-", label="Ensemble")
    plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    plt.title("Reliability Diagram (Manual Binning)")
    plt.xlabel("Mean Predicted Probability")
    plt.ylabel("Fraction of Positives")
    plt.legend()
    plt.show()
    
    # Optionally print the bin counts for analysis
    print("Bin counts:", bin_counts)

# Example usage:
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.
ensemble_prob_pos = ensemble_probs[:, 1]  # Extract probability for positive class
plot_reliability_diagram(ensemble_prob_pos, val_y.numpy(), n_bins=10)
# Out:
# Bin counts: [1616.  302.  224.  183.  186.  165.  186.  232.  336. 1570.]

# %%
def plot_reliability_diagram(prob_pos, true_labels, n_bins=10):
    """
    Compute and plot a reliability diagram.
    
    Parameters:
    - prob_pos: 1D array of predicted probabilities for the positive class.
    - true_labels: 1D array of ground truth binary labels.
    - n_bins: Number of bins in the diagram.
    """
    # Define bins from 0 to 1
    bins = np.linspace(0, 1, n_bins + 1)
    
    # Arrays to store the bin means and fraction of positives
    bin_preds = np.zeros(n_bins)
    bin_true = np.zeros(n_bins)
    bin_counts = np.zeros(n_bins)
    
    for i in range(n_bins):
        # Find samples with predictions in the current bin.
        indices = np.where((prob_pos >= bins[i]) & (prob_pos < bins[i+1]))[0]
        if len(indices) > 0:
            bin_preds[i] = np.mean(prob_pos[indices])
            bin_true[i] = np.mean(true_labels[indices])
            bin_counts[i] = len(indices)
    
    # Plot the reliability diagram
    plt.figure(figsize=(8, 6))
    plt.plot(bin_preds, bin_true, "s-", label="Ensemble")
    plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    plt.title("Reliability Diagram (Manual Binning)")
    plt.xlabel("Mean Predicted Probability")
    plt.ylabel("Fraction of Positives")
    plt.legend()
    plt.show()
    
    # Optionally print the bin counts for analysis
    print("Bin counts:", bin_counts)

# Example usage:
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.
single_prob_pos = single_probs[:, 1]  # Extract probability for positive class
plot_reliability_diagram(single_prob_pos, val_y.numpy(), n_bins=10)
# Out:
# Bin counts: [1603.  320.  239.  188.  168.  192.  167.  260.  326. 1537.]

# %% [markdown]
# ## Misclassification vs. Uncertainty
# Highlight samples where the model is both uncertain and incorrect.

# %%
# # Identify misclassified samples with high uncertainty
# incorrect = (predicted_labels != true_labels)
# high_uncertainty = entropy > np.percentile(entropy, 75)  # Top 25% uncertainty

# misclassified_uncertain = incorrect & high_uncertainty

# # Print or visualize these samples
# print(f"Number of misclassified and highly uncertain samples: {np.sum(misclassified_uncertain)}")

# %% [markdown]
# ## Comparative Plots Between Individual Models and Ensemble
# Purpose: To show how the ensemble reduces uncertainty compared to individual models.

# %%
# Compute uncertainties for individual models
entropies_individual = []
for probs in all_probs:
    entropy_individual = -np.sum(probs * np.log(probs + 1e-9), axis=1)
    entropies_individual.append(entropy_individual) 

# Average individual entropies
mean_entropy_individual = np.mean(entropies_individual, axis=0)

# Plot comparison
plt.figure(figsize=(8, 6))
plt.hist(mean_entropy_individual, bins=50, alpha=0.5, label='Individual Models')
plt.hist(entropy, bins=50, alpha=0.5, label='Ensemble')
plt.title('Entropy Distribution: Individual vs Ensemble')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Additional Tips:
#
# - Interactive Visualizations: Use tools like Plotly or Bokeh for interactive plots that allow you to hover over data points to see exact values.
# - Dimension Reduction: Apply techniques like t-SNE or UMAP to project high-dimensional data into 2D and color-code the points based on uncertainty.

# %%
# from sklearn.manifold import TSNE

# tsne = TSNE(n_components=2, random_state=0)
# embeddings_2d = tsne.fit_transform(val_X.numpy())

# plt.figure(figsize=(8, 6))
# plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=entropy, cmap='viridis', alpha=0.7)
# plt.colorbar(label='Predictive Entropy')
# plt.title('t-SNE Projection Colored by Uncertainty')
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.show()

# %% [markdown]
# - 	Thresholding: Set thresholds for uncertainty measures to flag or further investigate certain predictions.
#
# Integrating Visualizations into Your Workflow:
#
# 1.	Run the ensemble_uncertainty Function:
#
# mean_probs, variance_probs, entropy = ensemble_uncertainty(ensemble_models, val_X, device)
#
#
# 2.	Choose Appropriate Visualizations:
# - For overall understanding, start with histograms.
# - To explore relationships, use scatter plots.
# - For calibration, use reliability diagrams.
# - For data with spatial structure, consider heatmaps.
# 3.	Interpret the Results:
# - High Variance/Entropy: Indicates where the model is uncertain; consider investigating these samples.
# - Calibration Curves: Help you understand if the probabilities reflect true likelihoods.
# - Misclassifications with High Uncertainty: Potentially difficult samples or outliers.
# 4.	Refine the Model:
# - Use insights from visualizations to improve data preprocessing, model architecture, or training strategies.
# - Consider collecting more data in regions of high uncertainty.
#
# Example Workflow:
#
# Here’s how you might put it all together:

# %%
# Step 1: Compute Uncertainties
all_probs = []
for model in ensemble_models:
    model.eval()
    with torch.no_grad():
        outputs = model(inputs.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        all_probs.append(probs)

all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)

# Predictive mean (averaged probabilities)
mean_probs = np.mean(all_probs, axis=0)

# Predictive variance (epistemic uncertainty)
variance_probs = np.var(all_probs, axis=0)

# Predictive entropy
entropy = -np.sum(mean_probs * np.log(mean_probs + 1e-9), axis=1)

# Step 2: Visualize Histogram of Predictive Entropy
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# Step 3: Scatter Plot of Confidence vs. Predictive Entropy
confidence = np.max(mean_probs, axis=1)
plt.figure(figsize=(8, 6))
plt.scatter(confidence, entropy, alpha=0.5)
plt.title('Predictive Entropy vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Entropy')
plt.show()

# Step 4: Reliability Diagram
# from sklearn.calibration import calibration_curve

# prob_pos = mean_probs[:, 1]
# fraction_of_positives, mean_predicted_value = calibration_curve(val_y.numpy(), prob_pos, n_bins=10)

# plt.figure(figsize=(8, 6))
# plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Ensemble")
# plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
# plt.title('Reliability Diagram')
# plt.xlabel('Mean Predicted Probability')
# plt.ylabel('Fraction of Positives')
# plt.legend()
# plt.show()

# %% [markdown]
# By employing these visualization techniques, you’ll gain a deeper understanding of where and why your model is uncertain. This can guide you in making informed decisions about model improvements, data collection, or even deploying the model in real-world scenarios where uncertainty estimation is critical.
#
# Remember, the key is not just to compute uncertainty measures but to interpret them in the context of your specific problem and data.

# %% [markdown]
# # Distilation

# %% [markdown]
# Certainly! Knowledge distillation is a technique where a smaller model (student) is trained to replicate the behavior of a larger model or an ensemble of models (teacher). In your case, you can distill the knowledge from the ensemble of MLP models into a single MLP model.
#
# Here’s how you can proceed:
# 	1.	Generate Soft Targets: Use the ensemble to generate probability distributions (soft labels) for the training data.
# 	2.	Train the Student Model: Train a single MLP model using these soft targets, minimizing the difference between the student’s outputs and the soft targets from the ensemble.
# 	3.	Implement Distillation Loss: Use a combination of cross-entropy loss with the true labels and Kullback-Leibler (KL) divergence loss with the soft labels.
#
# Below is the complete code integrating knowledge distillation into your existing setup.
#
# Step-by-Step Guide
#
# 1. Generate Soft Targets from the Ensemble
#
# - Use the trained ensemble models to generate the averaged probabilities (mean of softmax outputs) for the training data.
#
# 2. Define the Student Model
#
# - Create a new MLP model that will serve as the student.
#
# 3. Implement the Distillation Loss Function
#
# - Use a custom loss function that combines the standard cross-entropy loss with the KL divergence between the student’s outputs and the soft targets.
# - Introduce a temperature parameter T to soften the probabilities.
#
# 4. Train the Student Model
#
# - Train the student model on the training data using the distillation loss.
# - Monitor the validation performance.

# %%
# Generate Soft Targets from the Ensemble for Training Data
def generate_soft_targets(ensemble_models, train_X):
    all_probs = []
    train_X = train_X.to(device)
    for model in ensemble_models:
        model.eval()
        model.to(device)
        with torch.no_grad():
            outputs = model(train_X)
            probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
            all_probs.append(probs)
        model.cpu()
    all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)
    soft_targets = np.mean(all_probs, axis=0)
    return soft_targets

# Generate soft targets
soft_targets = generate_soft_targets(ensemble_models, train_X)

# Define the Student Model - Using the same architecture as models in the Ensemble
class StudentMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=64, output_size=2):
        super(StudentMLP, self).__init__()
        # Input layer to first hidden layer
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        # Optional dropout to help prevent overfitting
        self.dropout1 = nn.Dropout(p=0.5)
        # First hidden layer to second hidden layer
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.dropout2 = nn.Dropout(p=0.5)
        # Second hidden layer to output layer
        self.fc3 = nn.Linear(hidden_dim2, output_size)
    
    def forward(self, x):
        # First hidden layer with ReLU activation
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        # Second hidden layer with ReLU activation
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        # Output layer
        x = self.fc3(x)
        # returns the logits
        return x

# The Distillation Loss Function
def distillation_loss(y_student_logits, y_true_labels, y_teacher_probs, T=2.0, alpha=0.7, beta=None):
    """
    y_student_logits: Logits output by the student model
    y_true_labels: Ground truth labels
    y_teacher_probs: Soft targets (probabilities) from the teacher (ensemble)
    T: Temperature parameter
    alpha: Weighting factor for hard targets
    beta: Weighting factor for soft targets (default: 1 - alpha)
    """
    if beta is None:
        beta = 1 - alpha

    # Shape checks
    assert y_student_logits.shape[0] == y_true_labels.shape[0], "Batch size mismatch between logits and labels."
    assert y_student_logits.shape[0] == y_teacher_probs.shape[0], "Batch size mismatch between logits and teacher probabilities."

    # Convert teacher probabilities to tensor if necessary
    if not isinstance(y_teacher_probs, torch.Tensor):
        teacher_probs_T = torch.tensor(y_teacher_probs, dtype=torch.float32, device=y_student_logits.device)
    else:
        teacher_probs_T = y_teacher_probs.to(y_student_logits.device)

    # Normalize teacher probabilities
    teacher_probs_T = teacher_probs_T / teacher_probs_T.sum(dim=1, keepdim=True)

    # Logits clipping for stability
    clipped_logits = torch.clamp(y_student_logits, min=-1e9, max=1e9)
    
    # Cross-Entropy Loss with true labels (hard targets)
    ce_loss = nn.CrossEntropyLoss()(clipped_logits, y_true_labels)

    # KL Divergence Loss with soft targets (from teacher)
    log_student_probs = nn.functional.log_softmax(clipped_logits / T, dim=1)
    kl_loss = nn.KLDivLoss(reduction='batchmean')(log_student_probs, teacher_probs_T)

    # Combined Loss
    loss = alpha * ce_loss + beta * (T ** 2) * kl_loss
    return loss


# Train the Student Model with Evaluation Metrics Collected at Each Epoch
def train_student_model(student_model, train_loader, val_X, val_y, soft_targets, epochs=50, T=2.0, alpha=0.7):
    student_model.to(device)
    optimizer = optim.Adam(student_model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)
    scaler = torch.cuda.amp.GradScaler()  # Mixed precision training

    loss_plot, acc_list, nll_list, ece_list, f1_list = [], [], [], [], []

    # Convert soft_targets to tensor
    soft_targets_tensor = torch.tensor(soft_targets, dtype=torch.float32)
    
    # Create validation DataLoader
    val_loader = DataLoader(TensorDataset(val_X, val_y), batch_size=2024, shuffle=False)

    for epoch in range(epochs):
        student_model.train()
        epoch_losses = []

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            # Map soft targets for the current batch
            batch_start = batch_idx * train_loader.batch_size
            batch_end = batch_start + inputs.size(0)
            y_teacher_probs = soft_targets_tensor[batch_start:batch_end].to(device)

            with torch.cuda.amp.autocast():
                outputs = student_model(inputs)
                loss = distillation_loss(outputs, labels, y_teacher_probs, T=T, alpha=alpha)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_losses.append(loss.item())

        avg_loss = np.mean(epoch_losses)
        loss_plot.append(avg_loss)
        scheduler.step(avg_loss)
        print(f"Epoch {epoch + 1}/{epochs}, Loss: {avg_loss:.4f}")

        # Validation loop
        student_model.eval()
        all_val_probs, all_val_preds, all_val_labels = [], [], []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.numpy()
                outputs = student_model(inputs)
                probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
                preds = np.argmax(probs, axis=1)

                all_val_probs.append(probs)
                all_val_preds.append(preds)
                all_val_labels.append(labels)

        all_val_probs = np.concatenate(all_val_probs, axis=0)
        all_val_preds = np.concatenate(all_val_preds, axis=0)
        all_val_labels = np.concatenate(all_val_labels, axis=0)

        # Compute metrics
        acc = accuracy_score(all_val_labels, all_val_preds)
        nll = log_loss(all_val_labels, all_val_probs)
        ece = compute_ece(all_val_probs, all_val_labels)
        f1 = f1_score(all_val_labels, all_val_preds, average='weighted')

        acc_list.append(acc)
        nll_list.append(nll)
        ece_list.append(ece)
        f1_list.append(f1)

        print(f"Validation -- Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")

    # Plot the evaluation metrics
    epochs_range = range(1, epochs + 1)
    plt.figure(figsize=(16, 4))
    
    # Accuracy Plot
    plt.subplot(1, 4, 1)
    plt.plot(epochs_range, acc_list, marker='o', color='blue')
    plt.title('Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    
    # NLL Plot
    plt.subplot(1, 4, 2)
    plt.plot(epochs_range, nll_list, marker='o', color='green')
    plt.title('Validation NLL')
    plt.xlabel('Epoch')
    plt.ylabel('Negative Log Likelihood')
    plt.grid(True)
    
    # ECE Plot
    plt.subplot(1, 4, 3)
    plt.plot(epochs_range, ece_list, marker='o', color='red')
    plt.title('Validation ECE')
    plt.xlabel('Epoch')
    plt.ylabel('ECE')
    plt.grid(True)
    
    # F1 Score Plot
    plt.subplot(1, 4, 4)
    plt.plot(epochs_range, f1_list, marker='o', color='purple')
    plt.title('Validation F1 Score')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(4, 4))
    # Loss Plot
    plt.plot(epochs_range, loss_plot, marker='o', color='orange')
    plt.title('Distillation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    return student_model, loss_plot

# --- Data Preparation ---

# Convert data to PyTorch tensors
train_X = torch.from_numpy(imdb_train_embeddings).float()
train_y = torch.from_numpy(imdb_train_labels).long()

# Prepare DataLoader with indices to match soft targets
train_dataset_with_indices = TensorDataset(train_X, train_y)
train_loader_with_indices = DataLoader(train_dataset_with_indices, batch_size=batch_size, shuffle=False)

# Instantiate the student model
student_model = StudentMLP(input_dim=train_X.shape[1], output_size=2)

# Settings
epochs = 100
T = 1.0
alpha = 0.3

# Ignore warnings of a specific category
warnings.filterwarnings('ignore', category=UserWarning)

student_model, loss_plot = train_student_model(
    student_model,
    train_loader_with_indices,
    val_X,
    val_y,
    soft_targets,
    epochs=epochs,
    T=T,
    alpha=alpha
)

# Re-enable warnings by clearing or overriding the filter
warnings.filterwarnings('default', category=UserWarning)
# Out:
# Epoch 1/100, Loss: 0.3027
# Validation -- Accuracy: 0.8380, NLL: 0.3714, ECE: 0.0251, F1 Score: 0.8380
# Epoch 2/100, Loss: 0.1700
# Validation -- Accuracy: 0.8506, NLL: 0.3428, ECE: 0.0161, F1 Score: 0.8506
# Epoch 3/100, Loss: 0.1424
# Validation -- Accuracy: 0.8600, NLL: 0.3268, ECE: 0.0130, F1 Score: 0.8599
# Epoch 4/100, Loss: 0.1270
# Validation -- Accuracy: 0.8624, NLL: 0.3228, ECE: 0.0111, F1 Score: 0.8624
# Epoch 5/100, Loss: 0.1173
# Validation -- Accuracy: 0.8630, NLL: 0.3194, ECE: 0.0114, F1 Score: 0.8630
# Epoch 6/100, Loss: 0.1094
# Validation -- Accuracy: 0.8648, NLL: 0.3164, ECE: 0.0118, F1 Score: 0.8648
# Epoch 7/100, Loss: 0.1018
# Validation -- Accuracy: 0.8692, NLL: 0.3158, ECE: 0.0219, F1 Score: 0.8692
# Epoch 8/100, Loss: 0.0994
# Validation -- Accuracy: 0.8698, NLL: 0.3142, ECE: 0.0171, F1 Score: 0.8698
# Epoch 9/100, Loss: 0.0947
# Validation -- Accuracy: 0.8700, NLL: 0.3124, ECE: 0.0165, F1 Score: 0.8700
# Epoch 10/100, Loss: 0.0919
# Validation -- Accuracy: 0.8698, NLL: 0.3124, ECE: 0.0150, F1 Score: 0.8698
# Epoch 11/100, Loss: 0.0893
# Validation -- Accuracy: 0.8714, NLL: 0.3120, ECE: 0.0172, F1 Score: 0.8714
# Epoch 12/100, Loss: 0.0872
# Validation -- Accuracy: 0.8712, NLL: 0.3119, ECE: 0.0203, F1 Score: 0.8712
# Epoch 13/100, Loss: 0.0847
# Validation -- Accuracy: 0.8718, NLL: 0.3110, ECE: 0.0202, F1 Score: 0.8718
# Epoch 14/100, Loss: 0.0828
# Validation -- Accuracy: 0.8728, NLL: 0.3116, ECE: 0.0211, F1 Score: 0.8728
# Epoch 15/100, Loss: 0.0824
# Validation -- Accuracy: 0.8722, NLL: 0.3110, ECE: 0.0197, F1 Score: 0.8722
# Epoch 16/100, Loss: 0.0811
# Validation -- Accuracy: 0.8708, NLL: 0.3123, ECE: 0.0191, F1 Score: 0.8708
# Epoch 17/100, Loss: 0.0795
# Validation -- Accuracy: 0.8700, NLL: 0.3102, ECE: 0.0212, F1 Score: 0.8700
# Epoch 18/100, Loss: 0.0782
# Validation -- Accuracy: 0.8720, NLL: 0.3100, ECE: 0.0214, F1 Score: 0.8720
# Epoch 19/100, Loss: 0.0772
# Validation -- Accuracy: 0.8708, NLL: 0.3096, ECE: 0.0195, F1 Score: 0.8708
# Epoch 20/100, Loss: 0.0774
# Validation -- Accuracy: 0.8712, NLL: 0.3102, ECE: 0.0226, F1 Score: 0.8712
# Epoch 21/100, Loss: 0.0754
# Validation -- Accuracy: 0.8698, NLL: 0.3096, ECE: 0.0244, F1 Score: 0.8698
# Epoch 22/100, Loss: 0.0757
# Validation -- Accuracy: 0.8720, NLL: 0.3093, ECE: 0.0198, F1 Score: 0.8720
# Epoch 23/100, Loss: 0.0742
# Validation -- Accuracy: 0.8720, NLL: 0.3082, ECE: 0.0182, F1 Score: 0.8720
# Epoch 24/100, Loss: 0.0734
# Validation -- Accuracy: 0.8742, NLL: 0.3088, ECE: 0.0195, F1 Score: 0.8742
# Epoch 25/100, Loss: 0.0733
# Validation -- Accuracy: 0.8742, NLL: 0.3084, ECE: 0.0258, F1 Score: 0.8742
# Epoch 26/100, Loss: 0.0724
# Validation -- Accuracy: 0.8732, NLL: 0.3098, ECE: 0.0216, F1 Score: 0.8732
# Epoch 27/100, Loss: 0.0721
# Validation -- Accuracy: 0.8736, NLL: 0.3094, ECE: 0.0193, F1 Score: 0.8736
# Epoch 28/100, Loss: 0.0722
# Validation -- Accuracy: 0.8744, NLL: 0.3086, ECE: 0.0202, F1 Score: 0.8744
# Epoch 29/100, Loss: 0.0716
# Validation -- Accuracy: 0.8752, NLL: 0.3071, ECE: 0.0193, F1 Score: 0.8752
# Epoch 30/100, Loss: 0.0714
# Validation -- Accuracy: 0.8740, NLL: 0.3079, ECE: 0.0201, F1 Score: 0.8740
# Epoch 31/100, Loss: 0.0716
# Validation -- Accuracy: 0.8750, NLL: 0.3076, ECE: 0.0201, F1 Score: 0.8750
# Epoch 32/100, Loss: 0.0708
# Validation -- Accuracy: 0.8752, NLL: 0.3080, ECE: 0.0224, F1 Score: 0.8752
# Epoch 33/100, Loss: 0.0707
# Validation -- Accuracy: 0.8736, NLL: 0.3070, ECE: 0.0244, F1 Score: 0.8736
# Epoch 34/100, Loss: 0.0713
# Validation -- Accuracy: 0.8718, NLL: 0.3075, ECE: 0.0199, F1 Score: 0.8718
# Epoch 35/100, Loss: 0.0714
# Validation -- Accuracy: 0.8758, NLL: 0.3083, ECE: 0.0225, F1 Score: 0.8758
# Epoch 36/100, Loss: 0.0722
# Validation -- Accuracy: 0.8736, NLL: 0.3086, ECE: 0.0221, F1 Score: 0.8736
# Epoch 37/100, Loss: 0.0724
# Validation -- Accuracy: 0.8716, NLL: 0.3112, ECE: 0.0241, F1 Score: 0.8716
# Epoch 38/100, Loss: 0.0721
# Validation -- Accuracy: 0.8682, NLL: 0.3165, ECE: 0.0223, F1 Score: 0.8682
# Epoch 39/100, Loss: 0.0734
# Validation -- Accuracy: 0.8660, NLL: 0.3252, ECE: 0.0263, F1 Score: 0.8660
# Epoch 40/100, Loss: 0.0724
# Validation -- Accuracy: 0.8720, NLL: 0.3072, ECE: 0.0195, F1 Score: 0.8720
# Epoch 41/100, Loss: 0.0686
# Validation -- Accuracy: 0.8746, NLL: 0.3060, ECE: 0.0184, F1 Score: 0.8746
# Epoch 42/100, Loss: 0.0668
# Validation -- Accuracy: 0.8726, NLL: 0.3085, ECE: 0.0217, F1 Score: 0.8726
# Epoch 43/100, Loss: 0.0667
# Validation -- Accuracy: 0.8714, NLL: 0.3091, ECE: 0.0223, F1 Score: 0.8714
# Epoch 44/100, Loss: 0.0663
# Validation -- Accuracy: 0.8726, NLL: 0.3080, ECE: 0.0196, F1 Score: 0.8726
# Epoch 45/100, Loss: 0.0663
# Validation -- Accuracy: 0.8726, NLL: 0.3083, ECE: 0.0199, F1 Score: 0.8726
# Epoch 46/100, Loss: 0.0657
# Validation -- Accuracy: 0.8730, NLL: 0.3087, ECE: 0.0203, F1 Score: 0.8730
# Epoch 47/100, Loss: 0.0655
# Validation -- Accuracy: 0.8724, NLL: 0.3088, ECE: 0.0220, F1 Score: 0.8724
# Epoch 48/100, Loss: 0.0651
# Validation -- Accuracy: 0.8732, NLL: 0.3087, ECE: 0.0212, F1 Score: 0.8732
# Epoch 49/100, Loss: 0.0648
# Validation -- Accuracy: 0.8732, NLL: 0.3087, ECE: 0.0226, F1 Score: 0.8732
# Epoch 50/100, Loss: 0.0645
# Validation -- Accuracy: 0.8734, NLL: 0.3088, ECE: 0.0225, F1 Score: 0.8734
# Epoch 51/100, Loss: 0.0645
# Validation -- Accuracy: 0.8720, NLL: 0.3091, ECE: 0.0239, F1 Score: 0.8720
# Epoch 52/100, Loss: 0.0644
# Validation -- Accuracy: 0.8726, NLL: 0.3089, ECE: 0.0228, F1 Score: 0.8726
# Epoch 53/100, Loss: 0.0643
# Validation -- Accuracy: 0.8720, NLL: 0.3089, ECE: 0.0248, F1 Score: 0.8720
# Epoch 54/100, Loss: 0.0636
# Validation -- Accuracy: 0.8730, NLL: 0.3088, ECE: 0.0214, F1 Score: 0.8730
# Epoch 55/100, Loss: 0.0640
# Validation -- Accuracy: 0.8720, NLL: 0.3087, ECE: 0.0235, F1 Score: 0.8720
# Epoch 56/100, Loss: 0.0644
# Validation -- Accuracy: 0.8730, NLL: 0.3090, ECE: 0.0233, F1 Score: 0.8730
# Epoch 57/100, Loss: 0.0638
# Validation -- Accuracy: 0.8728, NLL: 0.3092, ECE: 0.0232, F1 Score: 0.8728
# Epoch 58/100, Loss: 0.0638
# Validation -- Accuracy: 0.8724, NLL: 0.3090, ECE: 0.0218, F1 Score: 0.8724
# Epoch 59/100, Loss: 0.0639
# Validation -- Accuracy: 0.8726, NLL: 0.3090, ECE: 0.0207, F1 Score: 0.8726
# Epoch 60/100, Loss: 0.0636
# Validation -- Accuracy: 0.8730, NLL: 0.3091, ECE: 0.0191, F1 Score: 0.8730
# Epoch 61/100, Loss: 0.0636
# Validation -- Accuracy: 0.8732, NLL: 0.3093, ECE: 0.0204, F1 Score: 0.8732
# Epoch 62/100, Loss: 0.0633
# Validation -- Accuracy: 0.8736, NLL: 0.3096, ECE: 0.0203, F1 Score: 0.8736
# Epoch 63/100, Loss: 0.0629
# Validation -- Accuracy: 0.8728, NLL: 0.3092, ECE: 0.0199, F1 Score: 0.8728
# Epoch 64/100, Loss: 0.0631
# Validation -- Accuracy: 0.8740, NLL: 0.3093, ECE: 0.0204, F1 Score: 0.8740
# Epoch 65/100, Loss: 0.0632
# Validation -- Accuracy: 0.8738, NLL: 0.3094, ECE: 0.0214, F1 Score: 0.8738
# Epoch 66/100, Loss: 0.0634
# Validation -- Accuracy: 0.8724, NLL: 0.3095, ECE: 0.0238, F1 Score: 0.8724
# Epoch 67/100, Loss: 0.0631
# Validation -- Accuracy: 0.8726, NLL: 0.3097, ECE: 0.0251, F1 Score: 0.8726
# Epoch 68/100, Loss: 0.0631
# Validation -- Accuracy: 0.8732, NLL: 0.3099, ECE: 0.0227, F1 Score: 0.8732
# Epoch 69/100, Loss: 0.0629
# Validation -- Accuracy: 0.8724, NLL: 0.3095, ECE: 0.0226, F1 Score: 0.8724
# Epoch 70/100, Loss: 0.0630
# Validation -- Accuracy: 0.8724, NLL: 0.3095, ECE: 0.0233, F1 Score: 0.8724
# Epoch 71/100, Loss: 0.0634
# Validation -- Accuracy: 0.8724, NLL: 0.3095, ECE: 0.0230, F1 Score: 0.8724
# Epoch 72/100, Loss: 0.0629
# Validation -- Accuracy: 0.8726, NLL: 0.3095, ECE: 0.0232, F1 Score: 0.8726
# Epoch 73/100, Loss: 0.0626
# Validation -- Accuracy: 0.8722, NLL: 0.3095, ECE: 0.0237, F1 Score: 0.8722
# Epoch 74/100, Loss: 0.0627
# Validation -- Accuracy: 0.8722, NLL: 0.3096, ECE: 0.0241, F1 Score: 0.8722
# Epoch 75/100, Loss: 0.0631
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0241, F1 Score: 0.8720
# Epoch 76/100, Loss: 0.0626
# Validation -- Accuracy: 0.8718, NLL: 0.3096, ECE: 0.0241, F1 Score: 0.8718
# Epoch 77/100, Loss: 0.0625
# Validation -- Accuracy: 0.8718, NLL: 0.3096, ECE: 0.0245, F1 Score: 0.8718
# Epoch 78/100, Loss: 0.0629
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0241, F1 Score: 0.8720
# Epoch 79/100, Loss: 0.0628
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0252, F1 Score: 0.8720
# Epoch 80/100, Loss: 0.0631
# Validation -- Accuracy: 0.8722, NLL: 0.3095, ECE: 0.0246, F1 Score: 0.8722
# Epoch 81/100, Loss: 0.0623
# Validation -- Accuracy: 0.8724, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8724
# Epoch 82/100, Loss: 0.0628
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0250, F1 Score: 0.8720
# Epoch 83/100, Loss: 0.0628
# Validation -- Accuracy: 0.8724, NLL: 0.3096, ECE: 0.0243, F1 Score: 0.8724
# Epoch 84/100, Loss: 0.0622
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0237, F1 Score: 0.8720
# Epoch 85/100, Loss: 0.0629
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0249, F1 Score: 0.8720
# Epoch 86/100, Loss: 0.0626
# Validation -- Accuracy: 0.8724, NLL: 0.3096, ECE: 0.0242, F1 Score: 0.8724
# Epoch 87/100, Loss: 0.0625
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0248, F1 Score: 0.8720
# Epoch 88/100, Loss: 0.0627
# Validation -- Accuracy: 0.8718, NLL: 0.3096, ECE: 0.0244, F1 Score: 0.8718
# Epoch 89/100, Loss: 0.0626
# Validation -- Accuracy: 0.8720, NLL: 0.3096, ECE: 0.0241, F1 Score: 0.8720
# Epoch 90/100, Loss: 0.0629
# Validation -- Accuracy: 0.8718, NLL: 0.3095, ECE: 0.0252, F1 Score: 0.8718
# Epoch 91/100, Loss: 0.0623
# Validation -- Accuracy: 0.8718, NLL: 0.3095, ECE: 0.0249, F1 Score: 0.8718
# Epoch 92/100, Loss: 0.0629
# Validation -- Accuracy: 0.8718, NLL: 0.3095, ECE: 0.0246, F1 Score: 0.8718
# Epoch 93/100, Loss: 0.0625
# Validation -- Accuracy: 0.8718, NLL: 0.3095, ECE: 0.0246, F1 Score: 0.8718
# Epoch 94/100, Loss: 0.0623
# Validation -- Accuracy: 0.8718, NLL: 0.3095, ECE: 0.0246, F1 Score: 0.8718
# Epoch 95/100, Loss: 0.0627
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0244, F1 Score: 0.8720
# Epoch 96/100, Loss: 0.0625
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8720
# Epoch 97/100, Loss: 0.0622
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8720
# Epoch 98/100, Loss: 0.0624
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8720
# Epoch 99/100, Loss: 0.0625
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8720
# Epoch 100/100, Loss: 0.0623
# Validation -- Accuracy: 0.8720, NLL: 0.3095, ECE: 0.0247, F1 Score: 0.8720

# %% [markdown]
# Explanation
#
# - Temperature (T): A higher temperature softens the probability distribution, making the model pay more attention to less probable classes. It’s common to set T=2.0 or higher.
# - Alpha (alpha): Balances the importance between the hard targets (true labels) and the soft targets (ensemble outputs). Adjusting alpha allows you to emphasize either the true labels or the knowledge from the ensemble.
# - DataLoader Modification: We ensure that the data loader does not shuffle the data so that the indices of the soft targets align with the batches.
#
# Notes
#
# - Device Management: Ensure that all tensors and models are on the same device during training and inference.
# - Memory Considerations: Storing soft targets for the entire dataset may consume significant memory for large datasets. If this is an issue, consider generating soft targets on-the-fly during training.
# - Performance Evaluation: After training, compare the performance of the student model with the ensemble and individual models to assess the effectiveness of distillation.

# %%
# Paths to save/load embeddings and labels
imdb_train_embeddings_file = 'imdb_train_embeddings.npy'
imdb_train_labels_file = 'imdb_train_labels.npy'
imdb_test_embeddings_file = 'imdb_test_embeddings.npy'
imdb_test_labels_file = 'imdb_test_labels.npy'
imdb_unsupervised_embeddings_file = 'imdb_unsupervised_embeddings.npy'
imdb_unsupervised_labels_file = 'imdb_unsupervised_labels.npy'

# Check if embeddings and labels are already saved
if (os.path.exists(imdb_train_embeddings_file) and os.path.exists(imdb_train_labels_file) and
    os.path.exists(imdb_test_embeddings_file) and os.path.exists(imdb_test_labels_file) and
    os.path.exists(imdb_unsupervised_embeddings_file) and os.path.exists(imdb_unsupervised_labels_file)):
    # Load embeddings and labels
    imdb_train_embeddings = np.load(imdb_train_embeddings_file)
    imdb_train_labels = np.load(imdb_train_labels_file)
    imdb_test_embeddings = np.load(imdb_test_embeddings_file)
    imdb_test_labels = np.load(imdb_test_labels_file)
    imdb_unsupervised_embeddings = np.load(imdb_unsupervised_embeddings_file)
    imdb_unsupervised_labels = np.load(imdb_unsupervised_labels_file)
    print("Loaded train, validation, and test embeddings and labels from disk.")
else:
    # Load model directly
    tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")
    model = AutoModelForCausalLM.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")

    # Move the model to GPU
    model = model.to(device)


    # Load the SST-2 dataset from the GLUE benchmark with streaming
    dataset = load_dataset("stanfordnlp/imdb", streaming=True)

    # Initialize lists to store embeddings and labels for each set
    imdb_train_embeddings_list = []
    imdb_train_labels_list = []
    imdb_test_embeddings_list = []
    imdb_test_labels_list = []
    imdb_unsupervised_embeddings_list = []
    imdb_unsupervised_labels_list = []

    # Function to extract embeddings
    def extract_embeddings(streamed_dataset, embeddings_list, labels_list):
        for example in tqdm(streamed_dataset):
            inputs = tokenizer(
                example['text'],
                return_tensors='pt',
                padding=True,
                truncation=True,
                max_length=128
            ).to(device)
            with torch.no_grad():
                outputs = model(**inputs, output_hidden_states=True)
            hidden_states = outputs.hidden_states[-1]  # last layer hidden states
            embeddings = hidden_states.mean(dim=1).cpu().numpy()  # average over sequence length
            embeddings_list.append(embeddings.squeeze())  # shape (hidden_size,)
            labels_list.append(example['label'])

    # Extract embeddings for train, validation, and test sets
    extract_embeddings(dataset['train'], imdb_train_embeddings_list, imdb_train_labels_list)
    extract_embeddings(dataset['test'], imdb_test_embeddings_list, imdb_test_labels_list)
    extract_embeddings(dataset['unsupervised'], imdb_unsupervised_embeddings_list, imdb_unsupervised_labels_list)

    # Convert lists to numpy arrays
    imdb_train_embeddings = np.vstack(imdb_train_embeddings_list)
    imdb_train_labels = np.array(imdb_train_labels_list)
    imdb_test_embeddings = np.vstack(imdb_test_embeddings_list)
    imdb_test_labels = np.array(imdb_test_labels_list)
    imdb_unsupervised_embeddings = np.vstack(imdb_unsupervised_embeddings_list)
    imdb_unsupervised_labels = np.array(imdb_unsupervised_labels_list)

    # Standardize the embeddings
    scaler = StandardScaler()
    imdb_train_embeddings = scaler.fit_transform(imdb_train_embeddings)
    imdb_test_embeddings = scaler.transform(imdb_test_embeddings)
    imdb_unsupervised_embeddings = scaler.transform(imdb_unsupervised_embeddings)

    # Save embeddings, labels, and scaler to disk
    np.save(imdb_train_embeddings_file, imdb_train_embeddings)
    np.save(imdb_train_labels_file, imdb_train_labels)
    np.save(imdb_test_embeddings_file, imdb_test_embeddings)
    np.save(imdb_test_labels_file, imdb_test_labels)
    np.save(imdb_unsupervised_embeddings_file, imdb_unsupervised_embeddings)
    np.save(imdb_unsupervised_labels_file, imdb_unsupervised_labels)

    print("Saved train, test, and unsupervised embeddings and labels to disk.")

# Print shapes of embeddings and labels
print(f"IMDB Train embeddings shape: {imdb_train_embeddings.shape}")
print(f"IMDB Train labels shape: {imdb_train_labels.shape}")
print(f"IMDB Test embeddings shape: {imdb_test_embeddings.shape}")
print(f"IMDB Test labels shape: {imdb_test_labels.shape}")
print(f"IMDB Unsupervised embeddings shape: {imdb_unsupervised_embeddings.shape}")
print(f"IMDB Unsupervised labels shape: {imdb_unsupervised_labels.shape}")
# Out:
# 181it [00:23,  7.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 59
#      56         labels_list.append(example['label'])
#      58 # Extract embeddings for train, validation, and test sets
# ---> 59 extract_embeddings(dataset['train'], imdb_train_embeddings_list, imdb_train_labels_list)
#      60 extract_embeddings(dataset['test'], imdb_test_embeddings_list, imdb_test_labels_list)
#      61 extract_embeddings(dataset['unsupervised'], imdb_unsupervised_embeddings_list, imdb_unsupervised_labels_list)
#
# Cell In[31], line 52, in extract_embeddings(streamed_dataset, embeddings_list, labels_list)
#      44 inputs = tokenizer(
#      45     example['text'],
#      46     return_tensors='pt',
#    (...)
#      49     max_length=128
#      50 ).to(device)
#      51 with torch.no_grad():
# ---> 52     outputs = model(**inputs, output_hidden_states=True)
#      53 hidden_states = outputs.hidden_states[-1]  # last layer hidden states
#      54 embeddings = hidden_states.mean(dim=1).cpu().numpy()  # average over sequence length
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:831, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#     828 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     830 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 831 outputs = self.model(
#     832     input_ids=input_ids,
#     833     attention_mask=attention_mask,
#     834     position_ids=position_ids,
#     835     past_key_values=past_key_values,
#     836     inputs_embeds=inputs_embeds,
#     837     use_cache=use_cache,
#     838     output_attentions=output_attentions,
#     839     output_hidden_states=output_hidden_states,
#     840     return_dict=return_dict,
#     841     cache_position=cache_position,
#     842     **kwargs,
#     843 )
#     845 hidden_states = outputs[0]
#     846 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:566, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     563 hidden_states = inputs_embeds
#     565 # create position embeddings to be shared across the decoder layers
# --> 566 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     568 # decoder layers
#     569 all_hidden_states = () if output_hidden_states else None
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/nlp-project/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:131, in LlamaRotaryEmbedding.forward(self, x, position_ids)
#     129     emb = torch.cat((freqs, freqs), dim=-1)
#     130     cos = emb.cos()
# --> 131     sin = emb.sin()
#     133 # Advanced RoPE types (e.g. yarn) apply a post-processing scaling factor, equivalent to scaling attention
#     134 cos = cos * self.attention_scaling
#
# KeyboardInterrupt:

# %%
imdb_train_X = torch.from_numpy(imdb_train_embeddings).float()
imdb_train_y = torch.from_numpy(imdb_train_labels).long()

# Prepare DataLoader with indices to match soft targets
train_dataset_with_indices = TensorDataset(imdb_train_X, imdb_train_y)
train_loader_with_indices = DataLoader(train_dataset_with_indices, batch_size=batch_size, shuffle=False)

student_model.eval()
with torch.no_grad():
            val_outputs = student_model(imdb_train_X.to(device))
            val_probs = nn.functional.softmax(val_outputs, dim=1).cpu().numpy()
            val_preds = np.argmax(val_probs, axis=1)
            
            # Calculate Accuracy, NLL, ECE, and F1 score on validation data
            acc = accuracy_score(imdb_train_y.numpy(), val_preds)
            nll = log_loss(imdb_train_y.numpy(), val_probs)
            ece = compute_ece(val_probs, imdb_train_y.numpy())
            f1 = f1_score(imdb_train_y.numpy(), val_preds, average='weighted')  # Using weighted averaging

print(f"Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8234, NLL: 0.5521, ECE: 0.0964, F1 Score: 0.8228
