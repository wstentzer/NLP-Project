# %% [markdown]
# ## TODO
# - start med student har samme arkitæktur som ensemble (kinda done)
# - fix some of the plots for the ensemble that broke (i think they broke when changing size of the ensemble and or epochs)
# - do more comparative analysis of the student model and ensemble

# %% [markdown]
# # Embed dataset:

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, accuracy_score, ConfusionMatrixDisplay, log_loss, f1_score
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
import warnings

# %%
# Check for GPU
if torch.backends.mps.is_available():
    device = torch.device('mps')
    print('Using MPS device')
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print('Using CUDA device')
else:
    device = torch.device('cpu')
    print('No GPU found. Using CPU')
# Out:
# Using CUDA device

# %%
# Paths to save/load embeddings and labels
train_embeddings_file = 'train_embeddings.npy'
train_labels_file = 'train_labels.npy'
validation_embeddings_file = 'validation_embeddings.npy'
validation_labels_file = 'validation_labels.npy'
test_embeddings_file = 'test_embeddings.npy'
test_labels_file = 'test_labels.npy'

# Check if embeddings and labels are already saved
if (os.path.exists(train_embeddings_file) and os.path.exists(train_labels_file) and
    os.path.exists(validation_embeddings_file) and os.path.exists(validation_labels_file) and
    os.path.exists(test_embeddings_file) and os.path.exists(test_labels_file)):
    # Load embeddings and labels
    train_embeddings = np.load(train_embeddings_file)
    train_labels = np.load(train_labels_file)
    validation_embeddings = np.load(validation_embeddings_file)
    validation_labels = np.load(validation_labels_file)
    test_embeddings = np.load(test_embeddings_file)
    test_labels = np.load(test_labels_file)
    print("Loaded train, validation, and test embeddings and labels from disk.")
else:
    # Load model directly
    tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")
    model = AutoModelForCausalLM.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")

    # Move the model to GPU
    model = model.to(device)

    # Load the SST-2 dataset from the GLUE benchmark with streaming
    dataset = load_dataset('glue', 'sst2', streaming=True)

    # Initialize lists to store embeddings and labels for each set
    train_embeddings_list = []
    train_labels_list = []
    validation_embeddings_list = []
    validation_labels_list = []
    test_embeddings_list = []
    test_labels_list = []

    # Function to extract embeddings
    def extract_embeddings(streamed_dataset, embeddings_list, labels_list):
        for example in tqdm(streamed_dataset):
            inputs = tokenizer(
                example['sentence'],
                return_tensors='pt',
                padding=True,
                truncation=True,
                max_length=128
            ).to(device)
            with torch.no_grad():
                outputs = model(**inputs, output_hidden_states=True)
            hidden_states = outputs.hidden_states[-1]  # last layer hidden states
            embeddings = hidden_states.mean(dim=1).cpu().numpy()  # average over sequence length
            embeddings_list.append(embeddings.squeeze())  # shape (hidden_size,)
            labels_list.append(example['label'])

    # Extract embeddings for train, validation, and test sets
    extract_embeddings(dataset['train'], train_embeddings_list, train_labels_list)
    extract_embeddings(dataset['validation'], validation_embeddings_list, validation_labels_list)
    extract_embeddings(dataset['test'], test_embeddings_list, test_labels_list)

    # Convert lists to numpy arrays
    train_embeddings = np.vstack(train_embeddings_list)
    train_labels = np.array(train_labels_list)
    validation_embeddings = np.vstack(validation_embeddings_list)
    validation_labels = np.array(validation_labels_list)
    test_embeddings = np.vstack(test_embeddings_list)
    test_labels = np.array(test_labels_list)

    # Standardize the embeddings
    scaler = StandardScaler()
    train_embeddings = scaler.fit_transform(train_embeddings)
    validation_embeddings = scaler.transform(validation_embeddings)
    test_embeddings = scaler.transform(test_embeddings)

    # Save embeddings, labels, and scaler to disk
    np.save(train_embeddings_file, train_embeddings)
    np.save(train_labels_file, train_labels)
    np.save(validation_embeddings_file, validation_embeddings)
    np.save(validation_labels_file, validation_labels)
    np.save(test_embeddings_file, test_embeddings)
    np.save(test_labels_file, test_labels)

    print("Saved train, validation, and test embeddings and labels to disk.")

# Print shapes of embeddings and labels
print(f"Train embeddings shape: {train_embeddings.shape}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Validation embeddings shape: {validation_embeddings.shape}")
print(f"Validation labels shape: {validation_labels.shape}")
print(f"Test embeddings shape: {test_embeddings.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Loaded train, validation, and test embeddings and labels from disk.
# Train embeddings shape: (67349, 2048)
# Train labels shape: (67349,)
# Validation embeddings shape: (872, 2048)
# Validation labels shape: (872,)
# Test embeddings shape: (1821, 2048)
# Test labels shape: (1821,)

# %%
print(train_labels)
# Out:
# [0 0 1 ... 1 1 0]

# %%
train80_embeddings, distil_embeddings, train80_labels, distil_labels = train_test_split(
        train_embeddings, 
        train_labels, 
        test_size=0.20,       # This specifies that 20% of the data goes to the distil
        random_state=42,      # Ensures reproducibility
        stratify=train_labels # Ensures that the class distribution is preserved
    )

print(f"Train80 embeddings shape: {train80_embeddings.shape}")
print(f"Train80 labels shape: {train80_labels.shape}")
print(f"Distil embeddings shape: {distil_embeddings.shape}")
print(f"Distil labels shape: {distil_labels.shape}")
# Out:
# Train80 embeddings shape: (53879, 2048)
# Train80 labels shape: (53879,)
# Distil embeddings shape: (13470, 2048)
# Distil labels shape: (13470,)

# %% [markdown]
# # Ensemble training

# %%
# Ensure reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Number of MLPs in the ensemble
N = 100
batch_size = 2024
epochs = 10
hidden_size = 128

class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=64, output_size=2):
        super(MLP, self).__init__()
        # Input layer to first hidden layer
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        # Optional dropout to help prevent overfitting
        self.dropout1 = nn.Dropout(p=0.5)
        # First hidden layer to second hidden layer
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.dropout2 = nn.Dropout(p=0.5)
        # Second hidden layer to output layer
        self.fc3 = nn.Linear(hidden_dim2, output_size)
    
    def forward(self, x):
        # First hidden layer with ReLU activation
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        # Second hidden layer with ReLU activation
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        # Output layer
        x = self.fc3(x)
        # returns the logits
        return x

# Load your embeddings and labels (assuming they are already loaded)
# train_embeddings, train_labels, validation_embeddings, validation_labels, test_embeddings, test_labels

# Convert data to PyTorch tensors
# train_X = torch.from_numpy(train80_embeddings).float()
# train_y = torch.from_numpy(train80_labels).long()
train_X = torch.from_numpy(train_embeddings).float()
train_y = torch.from_numpy(train_labels).long()
val_X = torch.from_numpy(validation_embeddings).float()
val_y = torch.from_numpy(validation_labels).long()

# Create data loaders
train_dataset = TensorDataset(train_X, train_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

ensemble_models = []

# Metrics storage
ensemble_sizes = []
accuracies = []
nlls = []
eces = []
f1_list = []

# Function to compute Expected Calibration Error
def compute_ece(probs, labels, n_bins=10, mode='ECE'):
    """
    Compute Expected Calibration Error (ECE), Weighted ECE, or Maximum Calibration Error (MCE).

    Args:
        probs (np.ndarray): Predicted probabilities (shape: [n_samples, n_classes]).
        labels (np.ndarray): Ground truth labels (shape: [n_samples]).
        n_bins (int): Number of bins for confidence intervals.
        mode (str): Type of calibration error to compute ('ECE', 'wECE', 'MCE').

    Returns:
        float: Calibration error (ECE, wECE, or MCE).
    """
    assert probs.ndim == 2, "probs must be a 2D array with shape (n_samples, n_classes)"
    assert probs.shape[0] == labels.shape[0], "probs and labels must have the same number of samples"
    assert np.allclose(np.sum(probs, axis=1), 1, atol=1e-6), "Each row of probs must sum to 1"

    bin_boundaries = np.linspace(0, 1, n_bins + 1)
    bin_lowers = bin_boundaries[:-1]
    bin_uppers = bin_boundaries[1:]

    confidences = np.max(probs, axis=1)
    predictions = np.argmax(probs, axis=1)
    accuracies = predictions == labels

    ece = 0.0
    max_calib_error = 0.0
    for bin_lower, bin_upper in zip(bin_lowers, bin_uppers):
        # Handle last bin's inclusion
        if bin_upper == 1.0:
            in_bin = np.logical_and(confidences >= bin_lower, confidences <= bin_upper)
        else:
            in_bin = np.logical_and(confidences >= bin_lower, confidences < bin_upper)

        prop_in_bin = np.mean(in_bin)
        if in_bin.sum() > 0:  # Only process non-empty bins
            accuracy_in_bin = np.mean(accuracies[in_bin])
            avg_confidence_in_bin = np.mean(confidences[in_bin])

            calib_error = np.abs(avg_confidence_in_bin - accuracy_in_bin)
            ece += prop_in_bin * calib_error
            max_calib_error = max(max_calib_error, calib_error)

    if mode == 'ECE':
        return ece
    elif mode == 'MCE':
        return max_calib_error
    else:
        raise ValueError(f"Unsupported mode: {mode}. Choose 'ECE' or 'MCE'.")

# %%
# Training and evaluation loop
for n in range(1, N + 1):
    print(f"Training MLP {n}/{N}")
    input_size = train_X.shape[1]
    model = MLP(input_size, hidden_size, output_size=2).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    
    # Train the model
    model.train()
    for epoch in range(epochs):
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    # Evaluate the current individual model
    model.eval()
    with torch.no_grad():
        outputs = model(val_X.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        preds = np.argmax(probs, axis=1)
        
        single_probs = probs
        
        # Compute individual model metrics
        acc = accuracy_score(val_y.numpy(), preds)
        nll = log_loss(val_y.numpy(), probs)
        ece = compute_ece(probs, val_y.numpy())
        f1 = f1_score(val_y.numpy(),preds)
        
        print(f"Validation -- Model {n}: Accuracy = {acc:.4f}, NLL = {nll:.4f}, ECE = {ece:.4f}, F1 = {f1:.4f}")
    

    # Add the trained model to the ensemble
    ensemble_models.append(model)
    
    # Evaluate the ensemble up to the current number of models
    model.eval()
    with torch.no_grad():
        # Collect outputs from each model in the ensemble
        ensemble_outputs = []
        for m in ensemble_models:
            outputs = m(val_X.to(device))
            probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
            ensemble_outputs.append(probs)
        
        # Average the probabilities
        ensemble_probs = np.mean(ensemble_outputs, axis=0)
        ensemble_preds = np.argmax(ensemble_probs, axis=1)
        
        # Compute metrics
        acc = accuracy_score(val_y.numpy(), ensemble_preds)
        nll = log_loss(val_y.numpy(), ensemble_probs)
        ece = compute_ece(ensemble_probs, val_y.numpy())
        f1 = f1_score(val_y.numpy(), ensemble_preds, average='weighted')  # Using weighted averaging
        
        # Store metrics
        ensemble_sizes.append(n)
        accuracies.append(acc)
        nlls.append(nll)
        eces.append(ece)
        f1_list.append(f1)
        
        print(f"Validation -- Ensemble Size {n}: Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")

# Plot metrics as a function of ensemble size
plt.figure(figsize=(16, 4))

plt.subplot(1, 4, 1)
plt.plot(ensemble_sizes, accuracies, marker='o')
plt.title('Accuracy vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 4, 2)
plt.plot(ensemble_sizes, nlls, marker='o', color='orange')
plt.title('NLL vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Negative Log-Likelihood')
plt.grid(True)

plt.subplot(1, 4, 3)
plt.plot(ensemble_sizes, eces, marker='o', color='green')
plt.title('ECE vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('Expected Calibration Error')
plt.grid(True)

# F1 Score Plot
plt.subplot(1, 4, 4)
plt.plot(ensemble_sizes, f1_list, marker='o', color='purple')
plt.title('F1 Score vs Ensemble Size')
plt.xlabel('Number of MLPs')
plt.ylabel('F1 Score')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Training MLP 1/100
# Validation -- Model 1: Accuracy = 0.8612, NLL = 0.3524, ECE = 0.0572, F1 = 0.8683
# Validation -- Ensemble Size 1: Accuracy: 0.8612, NLL: 0.3524, ECE: 0.0572, F1 Score: 0.8610
# Training MLP 2/100
# Validation -- Model 2: Accuracy = 0.8509, NLL = 0.3639, ECE = 0.0691, F1 = 0.8571
# Validation -- Ensemble Size 2: Accuracy: 0.8578, NLL: 0.3459, ECE: 0.0575, F1 Score: 0.8577
# Training MLP 3/100
# Validation -- Model 3: Accuracy = 0.8647, NLL = 0.3624, ECE = 0.0687, F1 = 0.8683
# Validation -- Ensemble Size 3: Accuracy: 0.8601, NLL: 0.3389, ECE: 0.0547, F1 Score: 0.8600
# Training MLP 4/100
# Validation -- Model 4: Accuracy = 0.8647, NLL = 0.3488, ECE = 0.0552, F1 = 0.8680
# Validation -- Ensemble Size 4: Accuracy: 0.8647, NLL: 0.3365, ECE: 0.0501, F1 Score: 0.8646
# Training MLP 5/100
# Validation -- Model 5: Accuracy = 0.8601, NLL = 0.3867, ECE = 0.0738, F1 = 0.8697
# Validation -- Ensemble Size 5: Accuracy: 0.8635, NLL: 0.3393, ECE: 0.0503, F1 Score: 0.8634
# Training MLP 6/100
# Validation -- Model 6: Accuracy = 0.8693, NLL = 0.3752, ECE = 0.0611, F1 = 0.8739
# Validation -- Ensemble Size 6: Accuracy: 0.8647, NLL: 0.3401, ECE: 0.0500, F1 Score: 0.8646
# Training MLP 7/100
# Validation -- Model 7: Accuracy = 0.8589, NLL = 0.3582, ECE = 0.0614, F1 = 0.8644
# Validation -- Ensemble Size 7: Accuracy: 0.8647, NLL: 0.3391, ECE: 0.0525, F1 Score: 0.8646
# Training MLP 8/100
# Validation -- Model 8: Accuracy = 0.8681, NLL = 0.3515, ECE = 0.0579, F1 = 0.8683
# Validation -- Ensemble Size 8: Accuracy: 0.8693, NLL: 0.3359, ECE: 0.0544, F1 Score: 0.8692
# Training MLP 9/100
# Validation -- Model 9: Accuracy = 0.8681, NLL = 0.3740, ECE = 0.0591, F1 = 0.8738
# Validation -- Ensemble Size 9: Accuracy: 0.8693, NLL: 0.3366, ECE: 0.0470, F1 Score: 0.8692
# Training MLP 10/100
# Validation -- Model 10: Accuracy = 0.8635, NLL = 0.3515, ECE = 0.0575, F1 = 0.8676
# Validation -- Ensemble Size 10: Accuracy: 0.8681, NLL: 0.3360, ECE: 0.0463, F1 Score: 0.8681
# Training MLP 11/100
# Validation -- Model 11: Accuracy = 0.8670, NLL = 0.3710, ECE = 0.0594, F1 = 0.8750
# Validation -- Ensemble Size 11: Accuracy: 0.8693, NLL: 0.3366, ECE: 0.0473, F1 Score: 0.8692
# Training MLP 12/100
# Validation -- Model 12: Accuracy = 0.8624, NLL = 0.3467, ECE = 0.0507, F1 = 0.8655
# Validation -- Ensemble Size 12: Accuracy: 0.8670, NLL: 0.3354, ECE: 0.0458, F1 Score: 0.8669
# Training MLP 13/100
# Validation -- Model 13: Accuracy = 0.8624, NLL = 0.3672, ECE = 0.0670, F1 = 0.8698
# Validation -- Ensemble Size 13: Accuracy: 0.8670, NLL: 0.3357, ECE: 0.0471, F1 Score: 0.8669
# Training MLP 14/100
# Validation -- Model 14: Accuracy = 0.8727, NLL = 0.3344, ECE = 0.0473, F1 = 0.8757
# Validation -- Ensemble Size 14: Accuracy: 0.8693, NLL: 0.3334, ECE: 0.0451, F1 Score: 0.8692
# Training MLP 15/100
# Validation -- Model 15: Accuracy = 0.8761, NLL = 0.3589, ECE = 0.0566, F1 = 0.8818
# Validation -- Ensemble Size 15: Accuracy: 0.8681, NLL: 0.3333, ECE: 0.0461, F1 Score: 0.8681
# Training MLP 16/100
# Validation -- Model 16: Accuracy = 0.8670, NLL = 0.3702, ECE = 0.0638, F1 = 0.8745
# Validation -- Ensemble Size 16: Accuracy: 0.8681, NLL: 0.3336, ECE: 0.0457, F1 Score: 0.8680
# Training MLP 17/100
# Validation -- Model 17: Accuracy = 0.8716, NLL = 0.3689, ECE = 0.0661, F1 = 0.8772
# Validation -- Ensemble Size 17: Accuracy: 0.8681, NLL: 0.3340, ECE: 0.0459, F1 Score: 0.8681
# Training MLP 18/100
# Validation -- Model 18: Accuracy = 0.8670, NLL = 0.3403, ECE = 0.0530, F1 = 0.8717
# Validation -- Ensemble Size 18: Accuracy: 0.8658, NLL: 0.3333, ECE: 0.0479, F1 Score: 0.8657
# Training MLP 19/100
# Validation -- Model 19: Accuracy = 0.8670, NLL = 0.3515, ECE = 0.0513, F1 = 0.8670
# Validation -- Ensemble Size 19: Accuracy: 0.8681, NLL: 0.3324, ECE: 0.0452, F1 Score: 0.8681
# Training MLP 20/100
# Validation -- Model 20: Accuracy = 0.8635, NLL = 0.3592, ECE = 0.0581, F1 = 0.8658
# Validation -- Ensemble Size 20: Accuracy: 0.8681, NLL: 0.3325, ECE: 0.0452, F1 Score: 0.8681
# Training MLP 21/100
# Validation -- Model 21: Accuracy = 0.8681, NLL = 0.3666, ECE = 0.0622, F1 = 0.8743
# Validation -- Ensemble Size 21: Accuracy: 0.8670, NLL: 0.3328, ECE: 0.0465, F1 Score: 0.8669
# Training MLP 22/100
# Validation -- Model 22: Accuracy = 0.8716, NLL = 0.3758, ECE = 0.0653, F1 = 0.8758
# Validation -- Ensemble Size 22: Accuracy: 0.8658, NLL: 0.3333, ECE: 0.0479, F1 Score: 0.8657
# Training MLP 23/100
# Validation -- Model 23: Accuracy = 0.8727, NLL = 0.3422, ECE = 0.0544, F1 = 0.8740
# Validation -- Ensemble Size 23: Accuracy: 0.8670, NLL: 0.3327, ECE: 0.0469, F1 Score: 0.8669
# Training MLP 24/100
# Validation -- Model 24: Accuracy = 0.8647, NLL = 0.3642, ECE = 0.0585, F1 = 0.8715
# Validation -- Ensemble Size 24: Accuracy: 0.8670, NLL: 0.3330, ECE: 0.0469, F1 Score: 0.8669
# Training MLP 25/100
# Validation -- Model 25: Accuracy = 0.8670, NLL = 0.3552, ECE = 0.0565, F1 = 0.8700
# Validation -- Ensemble Size 25: Accuracy: 0.8681, NLL: 0.3328, ECE: 0.0458, F1 Score: 0.8681
# Training MLP 26/100
# Validation -- Model 26: Accuracy = 0.8647, NLL = 0.3515, ECE = 0.0611, F1 = 0.8695
# Validation -- Ensemble Size 26: Accuracy: 0.8681, NLL: 0.3327, ECE: 0.0461, F1 Score: 0.8681
# Training MLP 27/100
# Validation -- Model 27: Accuracy = 0.8612, NLL = 0.3533, ECE = 0.0633, F1 = 0.8666
# Validation -- Ensemble Size 27: Accuracy: 0.8693, NLL: 0.3325, ECE: 0.0448, F1 Score: 0.8692
# Training MLP 28/100
# Validation -- Model 28: Accuracy = 0.8693, NLL = 0.3597, ECE = 0.0572, F1 = 0.8736
# Validation -- Ensemble Size 28: Accuracy: 0.8693, NLL: 0.3323, ECE: 0.0449, F1 Score: 0.8692
# Training MLP 29/100
# Validation -- Model 29: Accuracy = 0.8647, NLL = 0.3389, ECE = 0.0478, F1 = 0.8683
# Validation -- Ensemble Size 29: Accuracy: 0.8681, NLL: 0.3317, ECE: 0.0457, F1 Score: 0.8681
# Training MLP 30/100
# Validation -- Model 30: Accuracy = 0.8624, NLL = 0.3589, ECE = 0.0580, F1 = 0.8710
# Validation -- Ensemble Size 30: Accuracy: 0.8670, NLL: 0.3319, ECE: 0.0466, F1 Score: 0.8669
# Training MLP 31/100
# Validation -- Model 31: Accuracy = 0.8658, NLL = 0.3637, ECE = 0.0565, F1 = 0.8719
# Validation -- Ensemble Size 31: Accuracy: 0.8681, NLL: 0.3319, ECE: 0.0454, F1 Score: 0.8681
# Training MLP 32/100
# Validation -- Model 32: Accuracy = 0.8704, NLL = 0.3440, ECE = 0.0559, F1 = 0.8754
# Validation -- Ensemble Size 32: Accuracy: 0.8693, NLL: 0.3314, ECE: 0.0442, F1 Score: 0.8692
# Training MLP 33/100
# Validation -- Model 33: Accuracy = 0.8658, NLL = 0.3468, ECE = 0.0526, F1 = 0.8699
# Validation -- Ensemble Size 33: Accuracy: 0.8704, NLL: 0.3312, ECE: 0.0431, F1 Score: 0.8704
# Training MLP 34/100
# Validation -- Model 34: Accuracy = 0.8681, NLL = 0.3690, ECE = 0.0643, F1 = 0.8692
# Validation -- Ensemble Size 34: Accuracy: 0.8704, NLL: 0.3313, ECE: 0.0433, F1 Score: 0.8704
# Training MLP 35/100
# Validation -- Model 35: Accuracy = 0.8716, NLL = 0.3475, ECE = 0.0557, F1 = 0.8758
# Validation -- Ensemble Size 35: Accuracy: 0.8716, NLL: 0.3312, ECE: 0.0448, F1 Score: 0.8715
# Training MLP 36/100
# Validation -- Model 36: Accuracy = 0.8647, NLL = 0.3760, ECE = 0.0640, F1 = 0.8674
# Validation -- Ensemble Size 36: Accuracy: 0.8716, NLL: 0.3316, ECE: 0.0439, F1 Score: 0.8715
# Training MLP 37/100
# Validation -- Model 37: Accuracy = 0.8658, NLL = 0.3732, ECE = 0.0546, F1 = 0.8721
# Validation -- Ensemble Size 37: Accuracy: 0.8704, NLL: 0.3320, ECE: 0.0434, F1 Score: 0.8704
# Training MLP 38/100
# Validation -- Model 38: Accuracy = 0.8716, NLL = 0.3733, ECE = 0.0609, F1 = 0.8750
# Validation -- Ensemble Size 38: Accuracy: 0.8681, NLL: 0.3322, ECE: 0.0516, F1 Score: 0.8681
# Training MLP 39/100
# Validation -- Model 39: Accuracy = 0.8647, NLL = 0.3749, ECE = 0.0641, F1 = 0.8674
# Validation -- Ensemble Size 39: Accuracy: 0.8681, NLL: 0.3325, ECE: 0.0483, F1 Score: 0.8681
# Training MLP 40/100
# Validation -- Model 40: Accuracy = 0.8716, NLL = 0.3488, ECE = 0.0525, F1 = 0.8769
# Validation -- Ensemble Size 40: Accuracy: 0.8693, NLL: 0.3323, ECE: 0.0448, F1 Score: 0.8692
# Training MLP 41/100
# Validation -- Model 41: Accuracy = 0.8681, NLL = 0.3549, ECE = 0.0591, F1 = 0.8712
# Validation -- Ensemble Size 41: Accuracy: 0.8704, NLL: 0.3322, ECE: 0.0447, F1 Score: 0.8704
# Training MLP 42/100
# Validation -- Model 42: Accuracy = 0.8716, NLL = 0.3574, ECE = 0.0556, F1 = 0.8742
# Validation -- Ensemble Size 42: Accuracy: 0.8716, NLL: 0.3322, ECE: 0.0449, F1 Score: 0.8715
# Training MLP 43/100
# Validation -- Model 43: Accuracy = 0.8681, NLL = 0.3638, ECE = 0.0606, F1 = 0.8726
# Validation -- Ensemble Size 43: Accuracy: 0.8716, NLL: 0.3323, ECE: 0.0443, F1 Score: 0.8715
# Training MLP 44/100
# Validation -- Model 44: Accuracy = 0.8624, NLL = 0.3623, ECE = 0.0608, F1 = 0.8698
# Validation -- Ensemble Size 44: Accuracy: 0.8704, NLL: 0.3323, ECE: 0.0442, F1 Score: 0.8704
# Training MLP 45/100
# Validation -- Model 45: Accuracy = 0.8647, NLL = 0.3688, ECE = 0.0696, F1 = 0.8720
# Validation -- Ensemble Size 45: Accuracy: 0.8727, NLL: 0.3324, ECE: 0.0481, F1 Score: 0.8727
# Training MLP 46/100
# Validation -- Model 46: Accuracy = 0.8761, NLL = 0.3502, ECE = 0.0486, F1 = 0.8792
# Validation -- Ensemble Size 46: Accuracy: 0.8739, NLL: 0.3322, ECE: 0.0492, F1 Score: 0.8738
# Training MLP 47/100
# Validation -- Model 47: Accuracy = 0.8589, NLL = 0.3645, ECE = 0.0654, F1 = 0.8662
# Validation -- Ensemble Size 47: Accuracy: 0.8716, NLL: 0.3323, ECE: 0.0446, F1 Score: 0.8715
# Training MLP 48/100
# Validation -- Model 48: Accuracy = 0.8555, NLL = 0.3852, ECE = 0.0762, F1 = 0.8606
# Validation -- Ensemble Size 48: Accuracy: 0.8693, NLL: 0.3328, ECE: 0.0453, F1 Score: 0.8692
# Training MLP 49/100
# Validation -- Model 49: Accuracy = 0.8750, NLL = 0.3485, ECE = 0.0517, F1 = 0.8768
# Validation -- Ensemble Size 49: Accuracy: 0.8693, NLL: 0.3323, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 50/100
# Validation -- Model 50: Accuracy = 0.8739, NLL = 0.3549, ECE = 0.0532, F1 = 0.8753
# Validation -- Ensemble Size 50: Accuracy: 0.8693, NLL: 0.3323, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 51/100
# Validation -- Model 51: Accuracy = 0.8647, NLL = 0.3436, ECE = 0.0544, F1 = 0.8715
# Validation -- Ensemble Size 51: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 52/100
# Validation -- Model 52: Accuracy = 0.8658, NLL = 0.3393, ECE = 0.0567, F1 = 0.8693
# Validation -- Ensemble Size 52: Accuracy: 0.8693, NLL: 0.3316, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 53/100
# Validation -- Model 53: Accuracy = 0.8544, NLL = 0.3858, ECE = 0.0724, F1 = 0.8603
# Validation -- Ensemble Size 53: Accuracy: 0.8681, NLL: 0.3320, ECE: 0.0465, F1 Score: 0.8681
# Training MLP 54/100
# Validation -- Model 54: Accuracy = 0.8670, NLL = 0.3567, ECE = 0.0554, F1 = 0.8722
# Validation -- Ensemble Size 54: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 55/100
# Validation -- Model 55: Accuracy = 0.8670, NLL = 0.3555, ECE = 0.0621, F1 = 0.8720
# Validation -- Ensemble Size 55: Accuracy: 0.8693, NLL: 0.3320, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 56/100
# Validation -- Model 56: Accuracy = 0.8612, NLL = 0.3545, ECE = 0.0629, F1 = 0.8645
# Validation -- Ensemble Size 56: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0443, F1 Score: 0.8704
# Training MLP 57/100
# Validation -- Model 57: Accuracy = 0.8670, NLL = 0.3583, ECE = 0.0608, F1 = 0.8722
# Validation -- Ensemble Size 57: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0450, F1 Score: 0.8704
# Training MLP 58/100
# Validation -- Model 58: Accuracy = 0.8635, NLL = 0.3479, ECE = 0.0572, F1 = 0.8670
# Validation -- Ensemble Size 58: Accuracy: 0.8681, NLL: 0.3318, ECE: 0.0466, F1 Score: 0.8681
# Training MLP 59/100
# Validation -- Model 59: Accuracy = 0.8670, NLL = 0.3635, ECE = 0.0649, F1 = 0.8711
# Validation -- Ensemble Size 59: Accuracy: 0.8681, NLL: 0.3319, ECE: 0.0465, F1 Score: 0.8681
# Training MLP 60/100
# Validation -- Model 60: Accuracy = 0.8693, NLL = 0.3490, ECE = 0.0532, F1 = 0.8728
# Validation -- Ensemble Size 60: Accuracy: 0.8681, NLL: 0.3318, ECE: 0.0466, F1 Score: 0.8681
# Training MLP 61/100
# Validation -- Model 61: Accuracy = 0.8704, NLL = 0.3559, ECE = 0.0576, F1 = 0.8743
# Validation -- Ensemble Size 61: Accuracy: 0.8693, NLL: 0.3318, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 62/100
# Validation -- Model 62: Accuracy = 0.8612, NLL = 0.3613, ECE = 0.0581, F1 = 0.8686
# Validation -- Ensemble Size 62: Accuracy: 0.8681, NLL: 0.3318, ECE: 0.0465, F1 Score: 0.8681
# Training MLP 63/100
# Validation -- Model 63: Accuracy = 0.8647, NLL = 0.3745, ECE = 0.0616, F1 = 0.8698
# Validation -- Ensemble Size 63: Accuracy: 0.8681, NLL: 0.3319, ECE: 0.0465, F1 Score: 0.8681
# Training MLP 64/100
# Validation -- Model 64: Accuracy = 0.8658, NLL = 0.3750, ECE = 0.0687, F1 = 0.8666
# Validation -- Ensemble Size 64: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 65/100
# Validation -- Model 65: Accuracy = 0.8658, NLL = 0.3714, ECE = 0.0609, F1 = 0.8741
# Validation -- Ensemble Size 65: Accuracy: 0.8693, NLL: 0.3320, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 66/100
# Validation -- Model 66: Accuracy = 0.8716, NLL = 0.3361, ECE = 0.0463, F1 = 0.8747
# Validation -- Ensemble Size 66: Accuracy: 0.8693, NLL: 0.3317, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 67/100
# Validation -- Model 67: Accuracy = 0.8681, NLL = 0.3637, ECE = 0.0621, F1 = 0.8706
# Validation -- Ensemble Size 67: Accuracy: 0.8693, NLL: 0.3317, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 68/100
# Validation -- Model 68: Accuracy = 0.8727, NLL = 0.3506, ECE = 0.0540, F1 = 0.8779
# Validation -- Ensemble Size 68: Accuracy: 0.8693, NLL: 0.3316, ECE: 0.0456, F1 Score: 0.8692
# Training MLP 69/100
# Validation -- Model 69: Accuracy = 0.8612, NLL = 0.3759, ECE = 0.0599, F1 = 0.8695
# Validation -- Ensemble Size 69: Accuracy: 0.8681, NLL: 0.3317, ECE: 0.0466, F1 Score: 0.8681
# Training MLP 70/100
# Validation -- Model 70: Accuracy = 0.8681, NLL = 0.3659, ECE = 0.0610, F1 = 0.8729
# Validation -- Ensemble Size 70: Accuracy: 0.8693, NLL: 0.3318, ECE: 0.0455, F1 Score: 0.8692
# Training MLP 71/100
# Validation -- Model 71: Accuracy = 0.8727, NLL = 0.3451, ECE = 0.0509, F1 = 0.8765
# Validation -- Ensemble Size 71: Accuracy: 0.8681, NLL: 0.3316, ECE: 0.0466, F1 Score: 0.8681
# Training MLP 72/100
# Validation -- Model 72: Accuracy = 0.8624, NLL = 0.3585, ECE = 0.0560, F1 = 0.8684
# Validation -- Ensemble Size 72: Accuracy: 0.8693, NLL: 0.3316, ECE: 0.0453, F1 Score: 0.8692
# Training MLP 73/100
# Validation -- Model 73: Accuracy = 0.8658, NLL = 0.3515, ECE = 0.0563, F1 = 0.8657
# Validation -- Ensemble Size 73: Accuracy: 0.8693, NLL: 0.3313, ECE: 0.0453, F1 Score: 0.8692
# Training MLP 74/100
# Validation -- Model 74: Accuracy = 0.8624, NLL = 0.3578, ECE = 0.0574, F1 = 0.8681
# Validation -- Ensemble Size 74: Accuracy: 0.8681, NLL: 0.3313, ECE: 0.0463, F1 Score: 0.8681
# Training MLP 75/100
# Validation -- Model 75: Accuracy = 0.8681, NLL = 0.3746, ECE = 0.0693, F1 = 0.8726
# Validation -- Ensemble Size 75: Accuracy: 0.8704, NLL: 0.3314, ECE: 0.0449, F1 Score: 0.8704
# Training MLP 76/100
# Validation -- Model 76: Accuracy = 0.8647, NLL = 0.3564, ECE = 0.0590, F1 = 0.8712
# Validation -- Ensemble Size 76: Accuracy: 0.8693, NLL: 0.3313, ECE: 0.0453, F1 Score: 0.8692
# Training MLP 77/100
# Validation -- Model 77: Accuracy = 0.8681, NLL = 0.3568, ECE = 0.0571, F1 = 0.8721
# Validation -- Ensemble Size 77: Accuracy: 0.8693, NLL: 0.3314, ECE: 0.0454, F1 Score: 0.8692
# Training MLP 78/100
# Validation -- Model 78: Accuracy = 0.8670, NLL = 0.3587, ECE = 0.0669, F1 = 0.8667
# Validation -- Ensemble Size 78: Accuracy: 0.8704, NLL: 0.3312, ECE: 0.0442, F1 Score: 0.8704
# Training MLP 79/100
# Validation -- Model 79: Accuracy = 0.8647, NLL = 0.3844, ECE = 0.0640, F1 = 0.8712
# Validation -- Ensemble Size 79: Accuracy: 0.8704, NLL: 0.3314, ECE: 0.0443, F1 Score: 0.8704
# Training MLP 80/100
# Validation -- Model 80: Accuracy = 0.8670, NLL = 0.3469, ECE = 0.0503, F1 = 0.8688
# Validation -- Ensemble Size 80: Accuracy: 0.8704, NLL: 0.3313, ECE: 0.0442, F1 Score: 0.8704
# Training MLP 81/100
# Validation -- Model 81: Accuracy = 0.8635, NLL = 0.3779, ECE = 0.0631, F1 = 0.8682
# Validation -- Ensemble Size 81: Accuracy: 0.8704, NLL: 0.3315, ECE: 0.0443, F1 Score: 0.8704
# Training MLP 82/100
# Validation -- Model 82: Accuracy = 0.8727, NLL = 0.3718, ECE = 0.0653, F1 = 0.8751
# Validation -- Ensemble Size 82: Accuracy: 0.8704, NLL: 0.3317, ECE: 0.0444, F1 Score: 0.8704
# Training MLP 83/100
# Validation -- Model 83: Accuracy = 0.8612, NLL = 0.3737, ECE = 0.0650, F1 = 0.8672
# Validation -- Ensemble Size 83: Accuracy: 0.8704, NLL: 0.3318, ECE: 0.0444, F1 Score: 0.8704
# Training MLP 84/100
# Validation -- Model 84: Accuracy = 0.8704, NLL = 0.3578, ECE = 0.0529, F1 = 0.8743
# Validation -- Ensemble Size 84: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 85/100
# Validation -- Model 85: Accuracy = 0.8612, NLL = 0.3582, ECE = 0.0614, F1 = 0.8680
# Validation -- Ensemble Size 85: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0458, F1 Score: 0.8692
# Training MLP 86/100
# Validation -- Model 86: Accuracy = 0.8704, NLL = 0.3503, ECE = 0.0479, F1 = 0.8768
# Validation -- Ensemble Size 86: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0457, F1 Score: 0.8692
# Training MLP 87/100
# Validation -- Model 87: Accuracy = 0.8658, NLL = 0.3676, ECE = 0.0648, F1 = 0.8707
# Validation -- Ensemble Size 87: Accuracy: 0.8693, NLL: 0.3320, ECE: 0.0456, F1 Score: 0.8692
# Training MLP 88/100
# Validation -- Model 88: Accuracy = 0.8704, NLL = 0.3722, ECE = 0.0640, F1 = 0.8743
# Validation -- Ensemble Size 88: Accuracy: 0.8693, NLL: 0.3321, ECE: 0.0456, F1 Score: 0.8692
# Training MLP 89/100
# Validation -- Model 89: Accuracy = 0.8739, NLL = 0.3433, ECE = 0.0571, F1 = 0.8753
# Validation -- Ensemble Size 89: Accuracy: 0.8693, NLL: 0.3319, ECE: 0.0456, F1 Score: 0.8692
# Training MLP 90/100
# Validation -- Model 90: Accuracy = 0.8567, NLL = 0.3805, ECE = 0.0677, F1 = 0.8649
# Validation -- Ensemble Size 90: Accuracy: 0.8704, NLL: 0.3321, ECE: 0.0444, F1 Score: 0.8704
# Training MLP 91/100
# Validation -- Model 91: Accuracy = 0.8727, NLL = 0.3478, ECE = 0.0548, F1 = 0.8760
# Validation -- Ensemble Size 91: Accuracy: 0.8704, NLL: 0.3320, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 92/100
# Validation -- Model 92: Accuracy = 0.8693, NLL = 0.3581, ECE = 0.0634, F1 = 0.8713
# Validation -- Ensemble Size 92: Accuracy: 0.8704, NLL: 0.3320, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 93/100
# Validation -- Model 93: Accuracy = 0.8647, NLL = 0.3542, ECE = 0.0597, F1 = 0.8656
# Validation -- Ensemble Size 93: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0444, F1 Score: 0.8704
# Training MLP 94/100
# Validation -- Model 94: Accuracy = 0.8612, NLL = 0.3471, ECE = 0.0627, F1 = 0.8663
# Validation -- Ensemble Size 94: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 95/100
# Validation -- Model 95: Accuracy = 0.8670, NLL = 0.3634, ECE = 0.0592, F1 = 0.8705
# Validation -- Ensemble Size 95: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 96/100
# Validation -- Model 96: Accuracy = 0.8693, NLL = 0.3628, ECE = 0.0590, F1 = 0.8722
# Validation -- Ensemble Size 96: Accuracy: 0.8704, NLL: 0.3320, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 97/100
# Validation -- Model 97: Accuracy = 0.8693, NLL = 0.3497, ECE = 0.0555, F1 = 0.8731
# Validation -- Ensemble Size 97: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0446, F1 Score: 0.8704
# Training MLP 98/100
# Validation -- Model 98: Accuracy = 0.8658, NLL = 0.3639, ECE = 0.0581, F1 = 0.8716
# Validation -- Ensemble Size 98: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0446, F1 Score: 0.8704
# Training MLP 99/100
# Validation -- Model 99: Accuracy = 0.8635, NLL = 0.3584, ECE = 0.0546, F1 = 0.8694
# Validation -- Ensemble Size 99: Accuracy: 0.8704, NLL: 0.3318, ECE: 0.0445, F1 Score: 0.8704
# Training MLP 100/100
# Validation -- Model 100: Accuracy = 0.8647, NLL = 0.3661, ECE = 0.0617, F1 = 0.8683
# Validation -- Ensemble Size 100: Accuracy: 0.8704, NLL: 0.3319, ECE: 0.0445, F1 Score: 0.8704

# %% [markdown]
# Har gjort MLPen dybere for at den ikke overfitter i distillation

# %% [markdown]
# ### The method used above for ensemble prediction is averaging (Mean Voting)
#    - **Description**: Each MLP produces a probability distribution over classes or a continuous output. The ensemble output is the average of these predictions.
#    - **Application**: Commonly used for regression tasks or classification tasks where probabilities are averaged.
#    - **Pros**: Simple to implement; works well when individual models are reasonably accurate and diverse.
#    - **Cons**: Does not account for cases where some models are more accurate than others.

# %%
all_probs = []
for model in ensemble_models:
    model.eval()
    with torch.no_grad():
        outputs = model(inputs.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        all_probs.append(probs)

all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)

# Predictive mean (averaged probabilities)
mean_probs = np.mean(all_probs, axis=0)

# Predictive variance (epistemic uncertainty)
variance_probs = np.var(all_probs, axis=0)

# Predictive entropy
entropy = -np.sum(mean_probs * np.log(mean_probs + 1e-9), axis=1)

# %% [markdown]
# ## Predictive Variance Histogram
# Purpose: To see the distribution of uncertainties across all predictions.

# %%
# Sum variances across classes if multi-class (for overall uncertainty)
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.hist(total_variance, bins=50, color='skyblue', edgecolor='black')
plt.title('Histogram of Predictive Variance')
plt.xlabel('Predictive Variance')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Predictive Entropy Histogram
# Purpose: Similar to variance, entropy gives a sense of uncertainty in predictions.

# %%
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Scatter Plots of Uncertainty vs. Confidence
#
# Purpose: To observe the relationship between model confidence and uncertainty.

# %%
# Model confidence: max probability from mean_probs
confidence = np.max(mean_probs, axis=1)

# Total variance or entropy as uncertainty measure
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.scatter(confidence, total_variance, alpha=0.5)
plt.title('Predictive Variance vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Variance')
plt.show()

# %% [markdown]
# ## Uncertainty vs. Correctness
# Purpose: To check if higher uncertainties correspond to incorrect predictions.

# %%
# # Predicted labels
# predicted_labels = np.argmax(mean_probs, axis=1)

# # True labels
# true_labels = val_y.numpy()

# # Correct predictions
# correct = (predicted_labels == true_labels)

# # Total variance or entropy
# total_variance = np.sum(variance_probs, axis=1)

# plt.figure(figsize=(8, 6))
# plt.scatter(total_variance, correct, alpha=0.5, c=correct, cmap='bwr')
# plt.title('Predictive Variance vs. Correctness')
# plt.xlabel('Predictive Variance')
# plt.ylabel('Correct Prediction (1=True, 0=False)')
# plt.show()

# %% [markdown]
# ## Reliability Diagram (Calibration Curve)
# Purpose: To assess how well the predicted probabilities are calibrated.

# %%
def plot_reliability_diagram(prob_pos, true_labels, n_bins=10):
    """
    Compute and plot a reliability diagram.
    
    Parameters:
    - prob_pos: 1D array of predicted probabilities for the positive class.
    - true_labels: 1D array of ground truth binary labels.
    - n_bins: Number of bins in the diagram.
    """
    # Define bins from 0 to 1
    bins = np.linspace(0, 1, n_bins + 1)
    
    # Arrays to store the bin means and fraction of positives
    bin_preds = np.zeros(n_bins)
    bin_true = np.zeros(n_bins)
    bin_counts = np.zeros(n_bins)
    
    for i in range(n_bins):
        # Find samples with predictions in the current bin.
        indices = np.where((prob_pos >= bins[i]) & (prob_pos < bins[i+1]))[0]
        if len(indices) > 0:
            bin_preds[i] = np.mean(prob_pos[indices])
            bin_true[i] = np.mean(true_labels[indices])
            bin_counts[i] = len(indices)
    
    # Plot the reliability diagram
    plt.figure(figsize=(8, 6))
    plt.plot(bin_preds, bin_true, "s-", label="Ensemble")
    plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    plt.title("Reliability Diagram (Manual Binning)")
    plt.xlabel("Mean Predicted Probability")
    plt.ylabel("Fraction of Positives")
    plt.legend()
    plt.show()
    
    # Optionally print the bin counts for analysis
    print("Bin counts:", bin_counts)

# Example usage:
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.
ensemble_prob_pos = ensemble_probs[:, 1]  # Extract probability for positive class
plot_reliability_diagram(ensemble_prob_pos, val_y.numpy(), n_bins=10)
# Out:
# Bin counts: [296.  42.  26.  24.  31.  19.  21.  24.  45. 323.]

# %%
def plot_reliability_diagram(prob_pos, true_labels, n_bins=10):
    """
    Compute and plot a reliability diagram.
    
    Parameters:
    - prob_pos: 1D array of predicted probabilities for the positive class.
    - true_labels: 1D array of ground truth binary labels.
    - n_bins: Number of bins in the diagram.
    """
    # Define bins from 0 to 1
    bins = np.linspace(0, 1, n_bins + 1)
    
    # Arrays to store the bin means and fraction of positives
    bin_preds = np.zeros(n_bins)
    bin_true = np.zeros(n_bins)
    bin_counts = np.zeros(n_bins)
    
    for i in range(n_bins):
        # Find samples with predictions in the current bin.
        indices = np.where((prob_pos >= bins[i]) & (prob_pos < bins[i+1]))[0]
        if len(indices) > 0:
            bin_preds[i] = np.mean(prob_pos[indices])
            bin_true[i] = np.mean(true_labels[indices])
            bin_counts[i] = len(indices)
    
    # Plot the reliability diagram
    plt.figure(figsize=(8, 6))
    plt.plot(bin_preds, bin_true, "s-", label="Ensemble")
    plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    plt.title("Reliability Diagram (Manual Binning)")
    plt.xlabel("Mean Predicted Probability")
    plt.ylabel("Fraction of Positives")
    plt.legend()
    plt.show()
    
    # Optionally print the bin counts for analysis
    print("Bin counts:", bin_counts)

# Example usage:
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.
single_prob_pos = single_probs[:, 1]  # Extract probability for positive class
plot_reliability_diagram(single_prob_pos, val_y.numpy(), n_bins=10)
# Out:
# Bin counts: [314.  37.  27.  21.  21.  18.  20.  23.  35. 336.]

# %% [markdown]
# ## Misclassification vs. Uncertainty
# Highlight samples where the model is both uncertain and incorrect.

# %%
# # Identify misclassified samples with high uncertainty
# incorrect = (predicted_labels != true_labels)
# high_uncertainty = entropy > np.percentile(entropy, 75)  # Top 25% uncertainty

# misclassified_uncertain = incorrect & high_uncertainty

# # Print or visualize these samples
# print(f"Number of misclassified and highly uncertain samples: {np.sum(misclassified_uncertain)}")

# %% [markdown]
# ## Comparative Plots Between Individual Models and Ensemble
# Purpose: To show how the ensemble reduces uncertainty compared to individual models.

# %%
# Compute uncertainties for individual models
entropies_individual = []
for probs in all_probs:
    entropy_individual = -np.sum(probs * np.log(probs + 1e-9), axis=1)
    entropies_individual.append(entropy_individual) 

# Average individual entropies
mean_entropy_individual = np.mean(entropies_individual, axis=0)

# Plot comparison
plt.figure(figsize=(8, 6))
plt.hist(mean_entropy_individual, bins=50, alpha=0.5, label='Individual Models')
plt.hist(entropy, bins=50, alpha=0.5, label='Ensemble')
plt.title('Entropy Distribution: Individual vs Ensemble')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Additional Tips:
#
# - Interactive Visualizations: Use tools like Plotly or Bokeh for interactive plots that allow you to hover over data points to see exact values.
# - Dimension Reduction: Apply techniques like t-SNE or UMAP to project high-dimensional data into 2D and color-code the points based on uncertainty.

# %%
# from sklearn.manifold import TSNE

# tsne = TSNE(n_components=2, random_state=0)
# embeddings_2d = tsne.fit_transform(val_X.numpy())

# plt.figure(figsize=(8, 6))
# plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=entropy, cmap='viridis', alpha=0.7)
# plt.colorbar(label='Predictive Entropy')
# plt.title('t-SNE Projection Colored by Uncertainty')
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.show()

# %% [markdown]
# - 	Thresholding: Set thresholds for uncertainty measures to flag or further investigate certain predictions.
#
# Integrating Visualizations into Your Workflow:
#
# 1.	Run the ensemble_uncertainty Function:
#
# mean_probs, variance_probs, entropy = ensemble_uncertainty(ensemble_models, val_X, device)
#
#
# 2.	Choose Appropriate Visualizations:
# - For overall understanding, start with histograms.
# - To explore relationships, use scatter plots.
# - For calibration, use reliability diagrams.
# - For data with spatial structure, consider heatmaps.
# 3.	Interpret the Results:
# - High Variance/Entropy: Indicates where the model is uncertain; consider investigating these samples.
# - Calibration Curves: Help you understand if the probabilities reflect true likelihoods.
# - Misclassifications with High Uncertainty: Potentially difficult samples or outliers.
# 4.	Refine the Model:
# - Use insights from visualizations to improve data preprocessing, model architecture, or training strategies.
# - Consider collecting more data in regions of high uncertainty.
#
# Example Workflow:
#
# Here’s how you might put it all together:

# %%
# Step 1: Compute Uncertainties
all_probs = []
for model in ensemble_models:
    model.eval()
    with torch.no_grad():
        outputs = model(inputs.to(device))
        probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
        all_probs.append(probs)

all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)

# Predictive mean (averaged probabilities)
mean_probs = np.mean(all_probs, axis=0)

# Predictive variance (epistemic uncertainty)
variance_probs = np.var(all_probs, axis=0)

# Predictive entropy
entropy = -np.sum(mean_probs * np.log(mean_probs + 1e-9), axis=1)

# Step 2: Visualize Histogram of Predictive Entropy
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# Step 3: Scatter Plot of Confidence vs. Predictive Entropy
confidence = np.max(mean_probs, axis=1)
plt.figure(figsize=(8, 6))
plt.scatter(confidence, entropy, alpha=0.5)
plt.title('Predictive Entropy vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Entropy')
plt.show()

# Step 4: Reliability Diagram
# from sklearn.calibration import calibration_curve

# prob_pos = mean_probs[:, 1]
# fraction_of_positives, mean_predicted_value = calibration_curve(val_y.numpy(), prob_pos, n_bins=10)

# plt.figure(figsize=(8, 6))
# plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Ensemble")
# plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
# plt.title('Reliability Diagram')
# plt.xlabel('Mean Predicted Probability')
# plt.ylabel('Fraction of Positives')
# plt.legend()
# plt.show()

# %% [markdown]
# By employing these visualization techniques, you’ll gain a deeper understanding of where and why your model is uncertain. This can guide you in making informed decisions about model improvements, data collection, or even deploying the model in real-world scenarios where uncertainty estimation is critical.
#
# Remember, the key is not just to compute uncertainty measures but to interpret them in the context of your specific problem and data.

# %% [markdown]
# # Distilation

# %% [markdown]
# Certainly! Knowledge distillation is a technique where a smaller model (student) is trained to replicate the behavior of a larger model or an ensemble of models (teacher). In your case, you can distill the knowledge from the ensemble of MLP models into a single MLP model.
#
# Here’s how you can proceed:
# 	1.	Generate Soft Targets: Use the ensemble to generate probability distributions (soft labels) for the training data.
# 	2.	Train the Student Model: Train a single MLP model using these soft targets, minimizing the difference between the student’s outputs and the soft targets from the ensemble.
# 	3.	Implement Distillation Loss: Use a combination of cross-entropy loss with the true labels and Kullback-Leibler (KL) divergence loss with the soft labels.
#
# Below is the complete code integrating knowledge distillation into your existing setup.
#
# Step-by-Step Guide
#
# 1. Generate Soft Targets from the Ensemble
#
# - Use the trained ensemble models to generate the averaged probabilities (mean of softmax outputs) for the training data.
#
# 2. Define the Student Model
#
# - Create a new MLP model that will serve as the student.
#
# 3. Implement the Distillation Loss Function
#
# - Use a custom loss function that combines the standard cross-entropy loss with the KL divergence between the student’s outputs and the soft targets.
# - Introduce a temperature parameter T to soften the probabilities.
#
# 4. Train the Student Model
#
# - Train the student model on the training data using the distillation loss.
# - Monitor the validation performance.

# %%
# Generate Soft Targets from the Ensemble for Training Data
def generate_soft_targets(ensemble_models, train_X):
    all_probs = []
    train_X = train_X.to(device)
    for model in ensemble_models:
        model.eval()
        model.to(device)
        with torch.no_grad():
            outputs = model(train_X)
            probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
            all_probs.append(probs)
        model.cpu()
    all_probs = np.stack(all_probs)  # Shape: (N_models, N_samples, N_classes)
    soft_targets = np.mean(all_probs, axis=0)
    return soft_targets

# Generate soft targets
soft_targets = generate_soft_targets(ensemble_models, train_X)

# Define the Student Model - Using the same architecture as models in the Ensemble
class StudentMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=64, output_size=2):
        super(StudentMLP, self).__init__()
        # Input layer to first hidden layer
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        # Optional dropout to help prevent overfitting
        self.dropout1 = nn.Dropout(p=0.5)
        # First hidden layer to second hidden layer
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.dropout2 = nn.Dropout(p=0.5)
        # Second hidden layer to output layer
        self.fc3 = nn.Linear(hidden_dim2, output_size)
    
    def forward(self, x):
        # First hidden layer with ReLU activation
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        # Second hidden layer with ReLU activation
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        # Output layer
        x = self.fc3(x)
        # returns the logits
        return x

# The Distillation Loss Function
def distillation_loss(y_student_logits, y_true_labels, y_teacher_probs, T=2.0, alpha=0.7, beta=None):
    """
    y_student_logits: Logits output by the student model
    y_true_labels: Ground truth labels
    y_teacher_probs: Soft targets (probabilities) from the teacher (ensemble)
    T: Temperature parameter
    alpha: Weighting factor for hard targets
    beta: Weighting factor for soft targets (default: 1 - alpha)
    """
    if beta is None:
        beta = 1 - alpha

    # Shape checks
    assert y_student_logits.shape[0] == y_true_labels.shape[0], "Batch size mismatch between logits and labels."
    assert y_student_logits.shape[0] == y_teacher_probs.shape[0], "Batch size mismatch between logits and teacher probabilities."

    # Convert teacher probabilities to tensor if necessary
    if not isinstance(y_teacher_probs, torch.Tensor):
        teacher_probs_T = torch.tensor(y_teacher_probs, dtype=torch.float32, device=y_student_logits.device)
    else:
        teacher_probs_T = y_teacher_probs.to(y_student_logits.device)

    # Normalize teacher probabilities
    teacher_probs_T = teacher_probs_T / teacher_probs_T.sum(dim=1, keepdim=True)

    # Logits clipping for stability
    clipped_logits = torch.clamp(y_student_logits, min=-1e9, max=1e9)
    
    # Cross-Entropy Loss with true labels (hard targets)
    ce_loss = nn.CrossEntropyLoss()(clipped_logits, y_true_labels)

    # KL Divergence Loss with soft targets (from teacher)
    log_student_probs = nn.functional.log_softmax(clipped_logits / T, dim=1)
    kl_loss = nn.KLDivLoss(reduction='batchmean')(log_student_probs, teacher_probs_T)

    # Combined Loss
    loss = alpha * ce_loss + beta * (T ** 2) * kl_loss
    return loss


# Train the Student Model with Evaluation Metrics Collected at Each Epoch
def train_student_model(student_model, train_loader, val_X, val_y, soft_targets, epochs=50, T=2.0, alpha=0.7):
    student_model.to(device)
    optimizer = optim.Adam(student_model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)
    scaler = torch.cuda.amp.GradScaler()  # Mixed precision training

    loss_plot, acc_list, nll_list, ece_list, f1_list = [], [], [], [], []

    # Convert soft_targets to tensor
    soft_targets_tensor = torch.tensor(soft_targets, dtype=torch.float32)
    
    # Create validation DataLoader
    val_loader = DataLoader(TensorDataset(val_X, val_y), batch_size=2024, shuffle=False)

    for epoch in range(epochs):
        student_model.train()
        epoch_losses = []

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            # Map soft targets for the current batch
            batch_start = batch_idx * train_loader.batch_size
            batch_end = batch_start + inputs.size(0)
            y_teacher_probs = soft_targets_tensor[batch_start:batch_end].to(device)

            with torch.cuda.amp.autocast():
                outputs = student_model(inputs)
                loss = distillation_loss(outputs, labels, y_teacher_probs, T=T, alpha=alpha)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_losses.append(loss.item())

        avg_loss = np.mean(epoch_losses)
        loss_plot.append(avg_loss)
        scheduler.step(avg_loss)
        print(f"Epoch {epoch + 1}/{epochs}, Loss: {avg_loss:.4f}")

        # Validation loop
        student_model.eval()
        all_val_probs, all_val_preds, all_val_labels = [], [], []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.numpy()
                outputs = student_model(inputs)
                probs = nn.functional.softmax(outputs, dim=1).cpu().numpy()
                preds = np.argmax(probs, axis=1)

                all_val_probs.append(probs)
                all_val_preds.append(preds)
                all_val_labels.append(labels)

        all_val_probs = np.concatenate(all_val_probs, axis=0)
        all_val_preds = np.concatenate(all_val_preds, axis=0)
        all_val_labels = np.concatenate(all_val_labels, axis=0)

        # Compute metrics
        acc = accuracy_score(all_val_labels, all_val_preds)
        nll = log_loss(all_val_labels, all_val_probs)
        ece = compute_ece(all_val_probs, all_val_labels)
        f1 = f1_score(all_val_labels, all_val_preds, average='weighted')

        acc_list.append(acc)
        nll_list.append(nll)
        ece_list.append(ece)
        f1_list.append(f1)

        print(f"Validation -- Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")

    # Plot the evaluation metrics
    epochs_range = range(1, epochs + 1)
    plt.figure(figsize=(16, 4))
    
    # Accuracy Plot
    plt.subplot(1, 4, 1)
    plt.plot(epochs_range, acc_list, marker='o', color='blue')
    plt.title('Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    
    # NLL Plot
    plt.subplot(1, 4, 2)
    plt.plot(epochs_range, nll_list, marker='o', color='green')
    plt.title('Validation NLL')
    plt.xlabel('Epoch')
    plt.ylabel('Negative Log Likelihood')
    plt.grid(True)
    
    # ECE Plot
    plt.subplot(1, 4, 3)
    plt.plot(epochs_range, ece_list, marker='o', color='red')
    plt.title('Validation ECE')
    plt.xlabel('Epoch')
    plt.ylabel('ECE')
    plt.grid(True)
    
    # F1 Score Plot
    plt.subplot(1, 4, 4)
    plt.plot(epochs_range, f1_list, marker='o', color='purple')
    plt.title('Validation F1 Score')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(4, 4))
    # Loss Plot
    plt.plot(epochs_range, loss_plot, marker='o', color='orange')
    plt.title('Distillation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    return student_model, loss_plot

# --- Data Preparation ---

# Convert data to PyTorch tensors
train_X = torch.from_numpy(train_embeddings).float()
train_y = torch.from_numpy(train_labels).long()

# Prepare DataLoader with indices to match soft targets
train_dataset_with_indices = TensorDataset(train_X, train_y)
train_loader_with_indices = DataLoader(train_dataset_with_indices, batch_size=batch_size, shuffle=False)

# Instantiate the student model
student_model = StudentMLP(input_dim=train_X.shape[1], output_size=2)

# Settings
epochs = 100
T = 1.0
alpha = 0.3

# Ignore warnings of a specific category
warnings.filterwarnings('ignore', category=UserWarning)

student_model, loss_plot = train_student_model(
    student_model,
    train_loader_with_indices,
    val_X,
    val_y,
    soft_targets,
    epochs=epochs,
    T=T,
    alpha=alpha
)

# Re-enable warnings by clearing or overriding the filter
warnings.filterwarnings('default', category=UserWarning)
# Out:
# Epoch 1/100, Loss: 0.2710
# Validation -- Accuracy: 0.8509, NLL: 0.3426, ECE: 0.0217, F1 Score: 0.8508
# Epoch 2/100, Loss: 0.1552
# Validation -- Accuracy: 0.8555, NLL: 0.3261, ECE: 0.0372, F1 Score: 0.8553
# Epoch 3/100, Loss: 0.1294
# Validation -- Accuracy: 0.8601, NLL: 0.3184, ECE: 0.0376, F1 Score: 0.8600
# Epoch 4/100, Loss: 0.1123
# Validation -- Accuracy: 0.8601, NLL: 0.3369, ECE: 0.0500, F1 Score: 0.8598
# Epoch 5/100, Loss: 0.1035
# Validation -- Accuracy: 0.8612, NLL: 0.3424, ECE: 0.0535, F1 Score: 0.8608
# Epoch 6/100, Loss: 0.0961
# Validation -- Accuracy: 0.8589, NLL: 0.3522, ECE: 0.0588, F1 Score: 0.8588
# Epoch 7/100, Loss: 0.0891
# Validation -- Accuracy: 0.8589, NLL: 0.3459, ECE: 0.0616, F1 Score: 0.8589
# Epoch 8/100, Loss: 0.0860
# Validation -- Accuracy: 0.8567, NLL: 0.3578, ECE: 0.0637, F1 Score: 0.8565
# Epoch 9/100, Loss: 0.0831
# Validation -- Accuracy: 0.8578, NLL: 0.3536, ECE: 0.0632, F1 Score: 0.8577
# Epoch 10/100, Loss: 0.0813
# Validation -- Accuracy: 0.8601, NLL: 0.3429, ECE: 0.0580, F1 Score: 0.8600
# Epoch 11/100, Loss: 0.0796
# Validation -- Accuracy: 0.8612, NLL: 0.3386, ECE: 0.0562, F1 Score: 0.8611
# Epoch 12/100, Loss: 0.0782
# Validation -- Accuracy: 0.8635, NLL: 0.3525, ECE: 0.0598, F1 Score: 0.8634
# Epoch 13/100, Loss: 0.0759
# Validation -- Accuracy: 0.8624, NLL: 0.3639, ECE: 0.0615, F1 Score: 0.8620
# Epoch 14/100, Loss: 0.0748
# Validation -- Accuracy: 0.8555, NLL: 0.3694, ECE: 0.0674, F1 Score: 0.8551
# Epoch 15/100, Loss: 0.0746
# Validation -- Accuracy: 0.8624, NLL: 0.3471, ECE: 0.0577, F1 Score: 0.8622
# Epoch 16/100, Loss: 0.0738
# Validation -- Accuracy: 0.8567, NLL: 0.3603, ECE: 0.0660, F1 Score: 0.8565
# Epoch 17/100, Loss: 0.0723
# Validation -- Accuracy: 0.8589, NLL: 0.3511, ECE: 0.0617, F1 Score: 0.8588
# Epoch 18/100, Loss: 0.0723
# Validation -- Accuracy: 0.8635, NLL: 0.3428, ECE: 0.0530, F1 Score: 0.8635
# Epoch 19/100, Loss: 0.0718
# Validation -- Accuracy: 0.8693, NLL: 0.3414, ECE: 0.0518, F1 Score: 0.8692
# Epoch 20/100, Loss: 0.0712
# Validation -- Accuracy: 0.8624, NLL: 0.3476, ECE: 0.0660, F1 Score: 0.8624
# Epoch 21/100, Loss: 0.0713
# Validation -- Accuracy: 0.8624, NLL: 0.3576, ECE: 0.0588, F1 Score: 0.8622
# Epoch 22/100, Loss: 0.0701
# Validation -- Accuracy: 0.8589, NLL: 0.3657, ECE: 0.0600, F1 Score: 0.8585
# Epoch 23/100, Loss: 0.0706
# Validation -- Accuracy: 0.8670, NLL: 0.3540, ECE: 0.0650, F1 Score: 0.8668
# Epoch 24/100, Loss: 0.0698
# Validation -- Accuracy: 0.8612, NLL: 0.3472, ECE: 0.0579, F1 Score: 0.8611
# Epoch 25/100, Loss: 0.0711
# Validation -- Accuracy: 0.8658, NLL: 0.3497, ECE: 0.0560, F1 Score: 0.8657
# Epoch 26/100, Loss: 0.0702
# Validation -- Accuracy: 0.8727, NLL: 0.3431, ECE: 0.0610, F1 Score: 0.8726
# Epoch 27/100, Loss: 0.0700
# Validation -- Accuracy: 0.8635, NLL: 0.3491, ECE: 0.0559, F1 Score: 0.8634
# Epoch 28/100, Loss: 0.0689
# Validation -- Accuracy: 0.8589, NLL: 0.3517, ECE: 0.0646, F1 Score: 0.8587
# Epoch 29/100, Loss: 0.0690
# Validation -- Accuracy: 0.8681, NLL: 0.3410, ECE: 0.0528, F1 Score: 0.8681
# Epoch 30/100, Loss: 0.0690
# Validation -- Accuracy: 0.8578, NLL: 0.3410, ECE: 0.0585, F1 Score: 0.8577
# Epoch 31/100, Loss: 0.0679
# Validation -- Accuracy: 0.8612, NLL: 0.3477, ECE: 0.0570, F1 Score: 0.8610
# Epoch 32/100, Loss: 0.0679
# Validation -- Accuracy: 0.8681, NLL: 0.3462, ECE: 0.0516, F1 Score: 0.8679
# Epoch 33/100, Loss: 0.0674
# Validation -- Accuracy: 0.8589, NLL: 0.3474, ECE: 0.0626, F1 Score: 0.8586
# Epoch 34/100, Loss: 0.0674
# Validation -- Accuracy: 0.8612, NLL: 0.3508, ECE: 0.0609, F1 Score: 0.8611
# Epoch 35/100, Loss: 0.0678
# Validation -- Accuracy: 0.8635, NLL: 0.3454, ECE: 0.0562, F1 Score: 0.8635
# Epoch 36/100, Loss: 0.0685
# Validation -- Accuracy: 0.8647, NLL: 0.3488, ECE: 0.0556, F1 Score: 0.8646
# Epoch 37/100, Loss: 0.0678
# Validation -- Accuracy: 0.8693, NLL: 0.3453, ECE: 0.0575, F1 Score: 0.8692
# Epoch 38/100, Loss: 0.0677
# Validation -- Accuracy: 0.8658, NLL: 0.3402, ECE: 0.0619, F1 Score: 0.8658
# Epoch 39/100, Loss: 0.0676
# Validation -- Accuracy: 0.8681, NLL: 0.3435, ECE: 0.0617, F1 Score: 0.8680
# Epoch 40/100, Loss: 0.0633
# Validation -- Accuracy: 0.8750, NLL: 0.3453, ECE: 0.0595, F1 Score: 0.8749
# Epoch 41/100, Loss: 0.0579
# Validation -- Accuracy: 0.8716, NLL: 0.3442, ECE: 0.0560, F1 Score: 0.8714
# Epoch 42/100, Loss: 0.0556
# Validation -- Accuracy: 0.8750, NLL: 0.3451, ECE: 0.0583, F1 Score: 0.8749
# Epoch 43/100, Loss: 0.0544
# Validation -- Accuracy: 0.8727, NLL: 0.3441, ECE: 0.0537, F1 Score: 0.8726
# Epoch 44/100, Loss: 0.0535
# Validation -- Accuracy: 0.8739, NLL: 0.3414, ECE: 0.0542, F1 Score: 0.8738
# Epoch 45/100, Loss: 0.0529
# Validation -- Accuracy: 0.8739, NLL: 0.3434, ECE: 0.0562, F1 Score: 0.8737
# Epoch 46/100, Loss: 0.0517
# Validation -- Accuracy: 0.8727, NLL: 0.3424, ECE: 0.0544, F1 Score: 0.8726
# Epoch 47/100, Loss: 0.0514
# Validation -- Accuracy: 0.8750, NLL: 0.3462, ECE: 0.0565, F1 Score: 0.8749
# Epoch 48/100, Loss: 0.0505
# Validation -- Accuracy: 0.8681, NLL: 0.3439, ECE: 0.0573, F1 Score: 0.8680
# Epoch 49/100, Loss: 0.0506
# Validation -- Accuracy: 0.8727, NLL: 0.3453, ECE: 0.0620, F1 Score: 0.8726
# Epoch 50/100, Loss: 0.0505
# Validation -- Accuracy: 0.8693, NLL: 0.3428, ECE: 0.0587, F1 Score: 0.8692
# Epoch 51/100, Loss: 0.0498
# Validation -- Accuracy: 0.8739, NLL: 0.3434, ECE: 0.0577, F1 Score: 0.8738
# Epoch 52/100, Loss: 0.0490
# Validation -- Accuracy: 0.8727, NLL: 0.3454, ECE: 0.0627, F1 Score: 0.8726
# Epoch 53/100, Loss: 0.0494
# Validation -- Accuracy: 0.8716, NLL: 0.3440, ECE: 0.0576, F1 Score: 0.8715
# Epoch 54/100, Loss: 0.0483
# Validation -- Accuracy: 0.8727, NLL: 0.3450, ECE: 0.0572, F1 Score: 0.8726
# Epoch 55/100, Loss: 0.0481
# Validation -- Accuracy: 0.8716, NLL: 0.3462, ECE: 0.0578, F1 Score: 0.8715
# Epoch 56/100, Loss: 0.0484
# Validation -- Accuracy: 0.8727, NLL: 0.3439, ECE: 0.0577, F1 Score: 0.8726
# Epoch 57/100, Loss: 0.0477
# Validation -- Accuracy: 0.8704, NLL: 0.3464, ECE: 0.0588, F1 Score: 0.8703
# Epoch 58/100, Loss: 0.0478
# Validation -- Accuracy: 0.8727, NLL: 0.3460, ECE: 0.0592, F1 Score: 0.8726
# Epoch 59/100, Loss: 0.0475
# Validation -- Accuracy: 0.8739, NLL: 0.3439, ECE: 0.0633, F1 Score: 0.8738
# Epoch 60/100, Loss: 0.0474
# Validation -- Accuracy: 0.8727, NLL: 0.3464, ECE: 0.0584, F1 Score: 0.8726
# Epoch 61/100, Loss: 0.0470
# Validation -- Accuracy: 0.8716, NLL: 0.3459, ECE: 0.0618, F1 Score: 0.8715
# Epoch 62/100, Loss: 0.0470
# Validation -- Accuracy: 0.8727, NLL: 0.3478, ECE: 0.0582, F1 Score: 0.8726
# Epoch 63/100, Loss: 0.0469
# Validation -- Accuracy: 0.8681, NLL: 0.3495, ECE: 0.0614, F1 Score: 0.8680
# Epoch 64/100, Loss: 0.0465
# Validation -- Accuracy: 0.8750, NLL: 0.3461, ECE: 0.0594, F1 Score: 0.8749
# Epoch 65/100, Loss: 0.0467
# Validation -- Accuracy: 0.8704, NLL: 0.3513, ECE: 0.0597, F1 Score: 0.8703
# Epoch 66/100, Loss: 0.0464
# Validation -- Accuracy: 0.8693, NLL: 0.3520, ECE: 0.0595, F1 Score: 0.8692
# Epoch 67/100, Loss: 0.0459
# Validation -- Accuracy: 0.8693, NLL: 0.3512, ECE: 0.0581, F1 Score: 0.8692
# Epoch 68/100, Loss: 0.0459
# Validation -- Accuracy: 0.8716, NLL: 0.3484, ECE: 0.0639, F1 Score: 0.8715
# Epoch 69/100, Loss: 0.0460
# Validation -- Accuracy: 0.8693, NLL: 0.3463, ECE: 0.0596, F1 Score: 0.8692
# Epoch 70/100, Loss: 0.0458
# Validation -- Accuracy: 0.8681, NLL: 0.3491, ECE: 0.0587, F1 Score: 0.8680
# Epoch 71/100, Loss: 0.0456
# Validation -- Accuracy: 0.8704, NLL: 0.3484, ECE: 0.0619, F1 Score: 0.8704
# Epoch 72/100, Loss: 0.0455
# Validation -- Accuracy: 0.8727, NLL: 0.3495, ECE: 0.0611, F1 Score: 0.8726
# Epoch 73/100, Loss: 0.0457
# Validation -- Accuracy: 0.8693, NLL: 0.3506, ECE: 0.0671, F1 Score: 0.8692
# Epoch 74/100, Loss: 0.0456
# Validation -- Accuracy: 0.8716, NLL: 0.3517, ECE: 0.0587, F1 Score: 0.8714
# Epoch 75/100, Loss: 0.0455
# Validation -- Accuracy: 0.8716, NLL: 0.3480, ECE: 0.0591, F1 Score: 0.8715
# Epoch 76/100, Loss: 0.0448
# Validation -- Accuracy: 0.8670, NLL: 0.3517, ECE: 0.0606, F1 Score: 0.8669
# Epoch 77/100, Loss: 0.0453
# Validation -- Accuracy: 0.8716, NLL: 0.3546, ECE: 0.0629, F1 Score: 0.8714
# Epoch 78/100, Loss: 0.0452
# Validation -- Accuracy: 0.8681, NLL: 0.3517, ECE: 0.0593, F1 Score: 0.8680
# Epoch 79/100, Loss: 0.0453
# Validation -- Accuracy: 0.8670, NLL: 0.3502, ECE: 0.0598, F1 Score: 0.8669
# Epoch 80/100, Loss: 0.0449
# Validation -- Accuracy: 0.8693, NLL: 0.3511, ECE: 0.0586, F1 Score: 0.8692
# Epoch 81/100, Loss: 0.0451
# Validation -- Accuracy: 0.8670, NLL: 0.3489, ECE: 0.0608, F1 Score: 0.8669
# Epoch 82/100, Loss: 0.0445
# Validation -- Accuracy: 0.8658, NLL: 0.3525, ECE: 0.0620, F1 Score: 0.8658
# Epoch 83/100, Loss: 0.0442
# Validation -- Accuracy: 0.8704, NLL: 0.3519, ECE: 0.0651, F1 Score: 0.8703
# Epoch 84/100, Loss: 0.0446
# Validation -- Accuracy: 0.8716, NLL: 0.3550, ECE: 0.0604, F1 Score: 0.8715
# Epoch 85/100, Loss: 0.0444
# Validation -- Accuracy: 0.8681, NLL: 0.3498, ECE: 0.0601, F1 Score: 0.8681
# Epoch 86/100, Loss: 0.0445
# Validation -- Accuracy: 0.8681, NLL: 0.3537, ECE: 0.0599, F1 Score: 0.8680
# Epoch 87/100, Loss: 0.0442
# Validation -- Accuracy: 0.8693, NLL: 0.3510, ECE: 0.0591, F1 Score: 0.8692
# Epoch 88/100, Loss: 0.0445
# Validation -- Accuracy: 0.8716, NLL: 0.3539, ECE: 0.0642, F1 Score: 0.8715
# Epoch 89/100, Loss: 0.0442
# Validation -- Accuracy: 0.8670, NLL: 0.3573, ECE: 0.0633, F1 Score: 0.8669
# Epoch 90/100, Loss: 0.0439
# Validation -- Accuracy: 0.8670, NLL: 0.3554, ECE: 0.0614, F1 Score: 0.8669
# Epoch 91/100, Loss: 0.0434
# Validation -- Accuracy: 0.8681, NLL: 0.3546, ECE: 0.0628, F1 Score: 0.8681
# Epoch 92/100, Loss: 0.0433
# Validation -- Accuracy: 0.8670, NLL: 0.3540, ECE: 0.0657, F1 Score: 0.8669
# Epoch 93/100, Loss: 0.0435
# Validation -- Accuracy: 0.8704, NLL: 0.3525, ECE: 0.0596, F1 Score: 0.8704
# Epoch 94/100, Loss: 0.0429
# Validation -- Accuracy: 0.8704, NLL: 0.3529, ECE: 0.0593, F1 Score: 0.8704
# Epoch 95/100, Loss: 0.0433
# Validation -- Accuracy: 0.8704, NLL: 0.3540, ECE: 0.0618, F1 Score: 0.8704
# Epoch 96/100, Loss: 0.0432
# Validation -- Accuracy: 0.8693, NLL: 0.3545, ECE: 0.0648, F1 Score: 0.8692
# Epoch 97/100, Loss: 0.0431
# Validation -- Accuracy: 0.8693, NLL: 0.3531, ECE: 0.0611, F1 Score: 0.8692
# Epoch 98/100, Loss: 0.0432
# Validation -- Accuracy: 0.8693, NLL: 0.3535, ECE: 0.0617, F1 Score: 0.8692
# Epoch 99/100, Loss: 0.0426
# Validation -- Accuracy: 0.8704, NLL: 0.3538, ECE: 0.0632, F1 Score: 0.8704
# Epoch 100/100, Loss: 0.0428
# Validation -- Accuracy: 0.8681, NLL: 0.3540, ECE: 0.0629, F1 Score: 0.8681

# %% [markdown]
# Explanation
#
# - Temperature (T): A higher temperature softens the probability distribution, making the model pay more attention to less probable classes. It’s common to set T=2.0 or higher.
# - Alpha (alpha): Balances the importance between the hard targets (true labels) and the soft targets (ensemble outputs). Adjusting alpha allows you to emphasize either the true labels or the knowledge from the ensemble.
# - DataLoader Modification: We ensure that the data loader does not shuffle the data so that the indices of the soft targets align with the batches.
#
# Notes
#
# - Device Management: Ensure that all tensors and models are on the same device during training and inference.
# - Memory Considerations: Storing soft targets for the entire dataset may consume significant memory for large datasets. If this is an issue, consider generating soft targets on-the-fly during training.
# - Performance Evaluation: After training, compare the performance of the student model with the ensemble and individual models to assess the effectiveness of distillation.

# %%
# Paths to save/load embeddings and labels
imdb_train_embeddings_file = 'imdb_train_embeddings.npy'
imdb_train_labels_file = 'imdb_train_labels.npy'
imdb_test_embeddings_file = 'imdb_test_embeddings.npy'
imdb_test_labels_file = 'imdb_test_labels.npy'
imdb_unsupervised_embeddings_file = 'imdb_unsupervised_embeddings.npy'
imdb_unsupervised_labels_file = 'imdb_unsupervised_labels.npy'

# Check if embeddings and labels are already saved
if (os.path.exists(imdb_train_embeddings_file) and os.path.exists(imdb_train_labels_file) and
    os.path.exists(imdb_test_embeddings_file) and os.path.exists(imdb_test_labels_file) and
    os.path.exists(imdb_unsupervised_embeddings_file) and os.path.exists(imdb_unsupervised_labels_file)):
    # Load embeddings and labels
    imdb_train_embeddings = np.load(imdb_train_embeddings_file)
    imdb_train_labels = np.load(imdb_train_labels_file)
    imdb_test_embeddings = np.load(imdb_test_embeddings_file)
    imdb_test_labels = np.load(imdb_test_labels_file)
    imdb_unsupervised_embeddings = np.load(imdb_unsupervised_embeddings_file)
    imdb_unsupervised_labels = np.load(imdb_unsupervised_labels_file)
    print("Loaded train, validation, and test embeddings and labels from disk.")
else:
    # Load model directly
    tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")
    model = AutoModelForCausalLM.from_pretrained("HuggingFaceTB/SmolLM-1.7B-Instruct")

    # Move the model to GPU
    model = model.to(device)


    # Load the SST-2 dataset from the GLUE benchmark with streaming
    dataset = load_dataset("stanfordnlp/imdb", streaming=True)

    # Initialize lists to store embeddings and labels for each set
    imdb_train_embeddings_list = []
    imdb_train_labels_list = []
    imdb_test_embeddings_list = []
    imdb_test_labels_list = []
    imdb_unsupervised_embeddings_list = []
    imdb_unsupervised_labels_list = []

    # Function to extract embeddings
    def extract_embeddings(streamed_dataset, embeddings_list, labels_list):
        for example in tqdm(streamed_dataset):
            inputs = tokenizer(
                example['text'],
                return_tensors='pt',
                padding=True,
                truncation=True,
                max_length=128
            ).to(device)
            with torch.no_grad():
                outputs = model(**inputs, output_hidden_states=True)
            hidden_states = outputs.hidden_states[-1]  # last layer hidden states
            embeddings = hidden_states.mean(dim=1).cpu().numpy()  # average over sequence length
            embeddings_list.append(embeddings.squeeze())  # shape (hidden_size,)
            labels_list.append(example['label'])

    # Extract embeddings for train, validation, and test sets
    extract_embeddings(dataset['train'], imdb_train_embeddings_list, imdb_train_labels_list)
    extract_embeddings(dataset['test'], imdb_test_embeddings_list, imdb_test_labels_list)
    extract_embeddings(dataset['unsupervised'], imdb_unsupervised_embeddings_list, imdb_unsupervised_labels_list)

    # Convert lists to numpy arrays
    imdb_train_embeddings = np.vstack(imdb_train_embeddings_list)
    imdb_train_labels = np.array(imdb_train_labels_list)
    imdb_test_embeddings = np.vstack(imdb_test_embeddings_list)
    imdb_test_labels = np.array(imdb_test_labels_list)
    imdb_unsupervised_embeddings = np.vstack(imdb_unsupervised_embeddings_list)
    imdb_unsupervised_labels = np.array(imdb_unsupervised_labels_list)

    # Standardize the embeddings
    scaler = StandardScaler()
    imdb_train_embeddings = scaler.fit_transform(imdb_train_embeddings)
    imdb_test_embeddings = scaler.transform(imdb_test_embeddings)
    imdb_unsupervised_embeddings = scaler.transform(imdb_unsupervised_embeddings)

    # Save embeddings, labels, and scaler to disk
    np.save(imdb_train_embeddings_file, imdb_train_embeddings)
    np.save(imdb_train_labels_file, imdb_train_labels)
    np.save(imdb_test_embeddings_file, imdb_test_embeddings)
    np.save(imdb_test_labels_file, imdb_test_labels)
    np.save(imdb_unsupervised_embeddings_file, imdb_unsupervised_embeddings)
    np.save(imdb_unsupervised_labels_file, imdb_unsupervised_labels)

    print("Saved train, test, and unsupervised embeddings and labels to disk.")

# Print shapes of embeddings and labels
print(f"IMDB Train embeddings shape: {imdb_train_embeddings.shape}")
print(f"IMDB Train labels shape: {imdb_train_labels.shape}")
print(f"IMDB Test embeddings shape: {imdb_test_embeddings.shape}")
print(f"IMDB Test labels shape: {imdb_test_labels.shape}")
print(f"IMDB Unsupervised embeddings shape: {imdb_unsupervised_embeddings.shape}")
print(f"IMDB Unsupervised labels shape: {imdb_unsupervised_labels.shape}")
# Out:
# 25000it [08:20, 49.99it/s]
# 25000it [08:24, 49.51it/s]
# 50000it [16:31, 50.44it/s]
# Saved train, test, and unsupervised embeddings and labels to disk.
# IMDB Train embeddings shape: (25000, 2048)
# IMDB Train labels shape: (25000,)
# IMDB Test embeddings shape: (25000, 2048)
# IMDB Test labels shape: (25000,)
# IMDB Unsupervised embeddings shape: (50000, 2048)
# IMDB Unsupervised labels shape: (50000,)

# %%
imdb_train_X = torch.from_numpy(imdb_train_embeddings).float()
imdb_train_y = torch.from_numpy(imdb_train_labels).long()

# Prepare DataLoader with indices to match soft targets
train_dataset_with_indices = TensorDataset(imdb_train_X, imdb_train_y)
train_loader_with_indices = DataLoader(train_dataset_with_indices, batch_size=batch_size, shuffle=False)

student_model.eval()
with torch.no_grad():
            val_outputs = student_model(imdb_train_X.to(device))
            val_probs = nn.functional.softmax(val_outputs, dim=1).cpu().numpy()
            val_preds = np.argmax(val_probs, axis=1)
            
            # Calculate Accuracy, NLL, ECE, and F1 score on validation data
            acc = accuracy_score(imdb_train_y.numpy(), val_preds)
            nll = log_loss(imdb_train_y.numpy(), val_probs)
            ece = compute_ece(val_probs, imdb_train_y.numpy())
            f1 = f1_score(imdb_train_y.numpy(), val_preds, average='weighted')  # Using weighted averaging

print(f"Accuracy: {acc:.4f}, NLL: {nll:.4f}, ECE: {ece:.4f}, F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8234, NLL: 0.5521, ECE: 0.0964, F1 Score: 0.8228
