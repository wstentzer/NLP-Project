# %% [markdown]
# ## TODO
# - start med student har samme arkitæktur som ensemble (kinda done)
# - fix some of the plots for the ensemble that broke (i think they broke when changing size of the ensemble and or epochs)
# - do more comparative analysis of the student model and ensemble

# %% [markdown]
# - Try with the imdb dataet (DONE)
# - Split the train set fo sst to test and train sets (DONE)
# - Incorperate early stopping during training
# - Simplify the loss function for distillation so there is less parameters
# - Make a combinded ECE Plot
# - Test on the the training set

# %% [markdown]
# # Embed dataset:

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings 
from utils import *
from train import *

# %% [markdown]
# # Eval function

# %% [markdown]
# ## Process embeddings and labels

# %%
train_embeddings_file='train_embeddings.npy'
train_labels_file='train_labels.npy'
validation_embeddings_file='validation_embeddings.npy'
validation_labels_file='validation_labels.npy'
test_embeddings_file='test_embeddings.npy'
test_labels_file='test_labels.npy'

# Load embeddings and labels from disk
train_em = np.load(train_embeddings_file)
train_la = np.load(train_labels_file)
validation_em = np.load(validation_embeddings_file)
validation_la = np.load(validation_labels_file)
test_em = np.load(test_embeddings_file)
test_la = np.load(test_labels_file)
print("Loaded train, validation, and test embeddings and labels from disk.")
# Out:
# Loaded train, validation, and test embeddings and labels from disk.

# %%
imdb_train_embeddings_file='imdb_long_train_em.npy'
imdb_train_labels_file='imdb_long_train_la.npy'
imdb_test_embeddings_file='imdb_long_test_em.npy'
imdb_test_labels_file='imdb_long_test_la.npy'
imdb_unsupervised_embeddings_file='imdb_long_unsuper_em.npy'
imdb_unsupervised_labels_file='imdb_long_unsuper_la.npy'

imdb_train_em = np.load(imdb_train_embeddings_file)
imdb_train_la = np.load(imdb_train_labels_file)
imdb_test_em = np.load(imdb_test_embeddings_file)
imdb_test_la = np.load(imdb_test_labels_file)
imdb_unsuper_em = np.load(imdb_unsupervised_embeddings_file)
imdb_unsuper_la = np.load(imdb_unsupervised_labels_file)
print("Loaded train, test, and unsupervised embeddings and labels from disk.")
# Out:
# Loaded train, test, and unsupervised embeddings and labels from disk.

# %%
cola_train_em_file='cola_train_em.npy'
cola_train_la_file='cola_train_la.npy'
cola_val_em_file='cola_val_em.npy'
cola_val_la_file='cola_val_la.npy'
cola_test_em_file='cola_test_em.npy'
cola_test_la_file='cola_test_la.npy'

cola_train_em = np.load(cola_train_em_file)
cola_train_la = np.load(cola_train_la_file)
cola_val_em = np.load(cola_val_em_file)
cola_val_la = np.load(cola_val_la_file)
cola_test_em = np.load(cola_test_em_file)
cola_test_la = np.load(cola_test_la_file)
print("Loaded train, test, and unsupervised embeddings and labels from disk.")
# Out:
# Loaded train, test, and unsupervised embeddings and labels from disk.

# %%
scaler = StandardScaler()
imdb_train_em = scaler.fit_transform(imdb_train_em)
imdb_test_em = scaler.transform(imdb_test_em)
imdb_unsuper_em = scaler.transform(imdb_unsuper_em)

train_em = scaler.transform(train_em)
validation_em = scaler.transform(validation_em)
test_em = scaler.transform(test_em)

cola_train_em = scaler.transform(cola_train_em)
cola_val_em = scaler.transform(cola_val_em)
cola_test_em = scaler.transform(cola_test_em)

# %%
imdb_test_em, imdb_val_em, imdb_test_la, imdb_val_la = train_test_split(
        imdb_test_em, 
        imdb_test_la, 
        test_size=0.20,       # This specifies that 20% of the data goes to the distil
        random_state=42,      # Ensures reproducibility
        stratify=imdb_train_la # Ensures that the class distribution is preserved
    )

print(f"Test embeddings shape: {imdb_test_em.shape}")
print(f"Test labels shape: {imdb_test_la.shape}")
print(f"Val embeddings shape: {imdb_val_em.shape}")
print(f"Val labels shape: {imdb_val_la.shape}")
# Out:
# Test embeddings shape: (20000, 2048)
# Test labels shape: (20000,)
# Val embeddings shape: (5000, 2048)
# Val labels shape: (5000,)

# %% [markdown]
# # Ensemble training

# %% [markdown]
# Har gjort MLPen dybere for at den ikke overfitter i distillation

# %%
class MLP(nn.Module):
        def __init__(self, input_dim, hidden_dim1=512, hidden_dim2=128, output_size=2):
            super(MLP, self).__init__()
            self.fc1 = nn.Linear(input_dim, hidden_dim1)
            self.dropout1 = nn.Dropout(p=0.5)
            self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
            self.dropout2 = nn.Dropout(p=0.5)
            self.fc3 = nn.Linear(hidden_dim2, output_size)
        
        def forward(self, x):
            x = torch.relu(self.fc1(x))
            x = self.dropout1(x)
            x = torch.relu(self.fc2(x))
            x = self.dropout2(x)
            x = self.fc3(x)
            return x

# %%
ensemble_models, metrics, ensemble_probs, individual_metrics = train_ensemble_with_early_stopping(imdb_train_em, imdb_train_la,
                                    imdb_val_em, imdb_val_la, MLP=MLP,
                                    N=100, batch_size=1024, epochs=20,
                                    model_patience=3,
                                    ensemble_patience=3)
# Out:
# Training MLP 1/100
# Epoch 1 -- Train Loss: 0.3015, Val Loss: 0.2156
# Epoch 2 -- Train Loss: 0.2155, Val Loss: 0.2058
# Epoch 3 -- Train Loss: 0.1958, Val Loss: 0.2019
# Epoch 4 -- Train Loss: 0.1828, Val Loss: 0.1995
# Epoch 5 -- Train Loss: 0.1732, Val Loss: 0.2000
# Epoch 6 -- Train Loss: 0.1605, Val Loss: 0.1994
# Epoch 7 -- Train Loss: 0.1459, Val Loss: 0.2110
# Epoch 8 -- Train Loss: 0.1343, Val Loss: 0.2115
# Epoch 9 -- Train Loss: 0.1309, Val Loss: 0.2191
# Early stopping for this model triggered at epoch 9.
# Model 1: Accuracy = 0.9196, NLL = 0.2191, ECE = 0.0195, F1 = 0.9196
# Ensemble Size 1 -- Accuracy: 0.9196, NLL: 0.2191, ECE: 0.0195, F1: 0.9196
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 2/100
# Epoch 1 -- Train Loss: 0.2991, Val Loss: 0.2128
# Epoch 2 -- Train Loss: 0.2155, Val Loss: 0.2019
# Epoch 3 -- Train Loss: 0.1958, Val Loss: 0.2039
# Epoch 4 -- Train Loss: 0.1853, Val Loss: 0.1941
# Epoch 5 -- Train Loss: 0.1709, Val Loss: 0.1996
# Epoch 6 -- Train Loss: 0.1585, Val Loss: 0.1988
# Epoch 7 -- Train Loss: 0.1476, Val Loss: 0.2043
# Early stopping for this model triggered at epoch 7.
# Model 2: Accuracy = 0.9238, NLL = 0.2043, ECE = 0.0129, F1 = 0.9238
# Ensemble Size 2 -- Accuracy: 0.9226, NLL: 0.2040, ECE: 0.0113, F1: 0.9226
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP
# Epoch 6 -- Train Loss: 0.1641, Val Loss: 0.2030
# Epoch 7 -- Train Loss: 0.1506, Val Loss: 0.2109
# Epoch 8 -- Train Loss: 0.1425, Val Loss: 0.2068
# Early stopping for this model triggered at epoch 8.
# Model 11: Accuracy = 0.9238, NLL = 0.2068, ECE = 0.0143, F1 = 0.9238
# Ensemble Size 11 -- Accuracy: 0.9260, NLL: 0.1956, ECE: 0.0090, F1: 0.9260
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 12/100
# Epoch 1 -- Train Loss: 0.2993, Val Loss: 0.2185
# Epoch 2 -- Train Loss: 0.2169, Val Loss: 0.2001
# Epoch 3 -- Train Loss: 0.1974, Val Loss: 0.1991
# Epoch 4 -- Train Loss: 0.1837, Val Loss: 0.2013
# Epoch 5 -- Train Loss: 0.1701, Val Loss: 0.2008
# Epoch 6 -- Train Loss: 0.1595, Val Loss: 0.1985
# Epoch 7 -- Train Loss: 0.1510, Val Loss: 0.2070
# Epoch 8 -- Train Loss: 0.1419, Val Loss: 0.2035
# Epoch 9 -- Train Loss: 0.1287, Val Loss: 0.2184
# Early stopping for this model triggered at epoch 9.
# Model 12: Accuracy = 0.9194, NLL = 0.2184, ECE = 0.0173, F1 = 0.9194
# Ensemble Size 12 -- Accuracy: 0.9260, NLL: 0.1961, ECE: 0.0097, F1: 0.9260
# No ensemble improvement count: 1/3
#
# Training MLP 13/100
# Epoch 1 -- Train Loss: 0.3007, Val Loss: 0.2159
# Epoch 2 -- Train Loss: 0.2156, Val Loss: 0.2020
# Epoch 3 -- Train Loss: 0.1971, Val Loss: 0.2001
# Epoch 4 -- Train Loss: 0.1832, Val Loss: 0.1974
# Epoch 5 -- Train Loss: 0.1726, Val Loss: 0.1960
# Epoch 6 -- Train Loss: 0.1574, Val Loss: 0.1990
# Epoch 7 -- Train Loss: 0.1494, Val Loss: 0.2067
# Epoch 8 -- Train Loss: 0.1414, Val Loss: 0.2111
# Early stopping for this model triggered at epoch 8.
# Model 13: Accuracy = 0.9224, NLL = 0.2111, ECE = 0.0196, F1 = 0.9224
# Ensemble Size 13 -- Accuracy: 0.9258, NLL: 0.1957, ECE: 0.0123, F1: 0.9258
# No ensemble improvement count: 2/3
#
# Training MLP 14/100
# Epoch 1 -- Train Loss: 0.3066, Val Loss: 0.2141
# Epoch 2 -- Train Loss: 0.2175, Val Loss: 0.2044
# Epoch 3 -- Train Loss: 0.1971, Val Loss: 0.1984
# Epoch 4 -- Train Loss: 0.1816, Val Loss: 0.1975
# Epoch 5 -- Train Loss: 0.1702, Val Loss: 0.1991
# Epoch 6 -- Train Loss: 0.1578, Val Loss: 0.2022
# Epoch 7 -- Train Loss: 0.1547, Val Loss: 0.2002
# Early stopping for this model triggered at epoch 7.
# Model 14: Accuracy = 0.9216, NLL = 0.2002, ECE = 0.0125, F1 = 0.9216
# Ensemble Size 14 -- Accuracy: 0.9264, NLL: 0.1952, ECE: 0.0120, F1: 0.9264
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP
F1: 0.9260
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 20/100
# Epoch 1 -- Train Loss: 0.3070, Val Loss: 0.2113
# Epoch 2 -- Train Loss: 0.2168, Val Loss: 0.2080
# Epoch 3 -- Train Loss: 0.1991, Val Loss: 0.2012
# Epoch 4 -- Train Loss: 0.1832, Val Loss: 0.2017
# Epoch 5 -- Train Loss: 0.1727, Val Loss: 0.1999
# Epoch 6 -- Train Loss: 0.1644, Val Loss: 0.2063
# Epoch 7 -- Train Loss: 0.1506, Val Loss: 0.2066
# Epoch 8 -- Train Loss: 0.1444, Val Loss: 0.2063
# Early stopping for this model triggered at epoch 8.
# Model 20: Accuracy = 0.9224, NLL = 0.2063, ECE = 0.0132, F1 = 0.9224
# Ensemble Size 20 -- Accuracy: 0.9258, NLL: 0.1947, ECE: 0.0115, F1: 0.9258
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 21/100
# Epoch 1 -- Train Loss: 0.3027, Val Loss: 0.2143
# Epoch 2 -- Train Loss: 0.2182, Val Loss: 0.2052
# Epoch 3 -- Train Loss: 0.1959, Val Loss: 0.2031
# Epoch 4 -- Train Loss: 0.1834, Val Loss: 0.1978
# Epoch 5 -- Train Loss: 0.1709, Val Loss: 0.2078
# Epoch 6 -- Train Loss: 0.1629, Val Loss: 0.1977
# Epoch 7 -- Train Loss: 0.1485, Val Loss: 0.2108
# Epoch 8 -- Train Loss: 0.1420, Val Loss: 0.2036
# Epoch 9 -- Train Loss: 0.1358, Val Loss: 0.2087
# Early stopping for this model triggered at epoch 9.
# Model 21: Accuracy = 0.9220, NLL = 0.2087, ECE = 0.0199, F1 = 0.9220
# Ensemble Size 21 -- Accuracy: 0.9262, NLL: 0.1946, ECE: 0.0095, F1: 0.9262
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 22/100
# Epoch 1 -- Train Loss: 0.3015, Val Loss: 0.2221
# Epoch 2 -- Train Loss: 0.2167, Val Loss: 0.2017
# Epoch 3 -- Train Loss: 0.1947, Val Loss: 0.2002
# Epoch 4 -- Train Loss: 0.1850, Val Loss: 0.2015
# Epoch 5 -- Train Loss: 0.1718, Val Loss: 0.2004
# Epoch 6 -- Train Loss: 0.1589, Val Loss: 0.2003
# Early stopping for this model triggered at epoch 6.
# Model 22: Accuracy = 0.9234, NLL = 0.2003, ECE = 0.0103, F1 = 0.9234
# Ensemble Size 22 -- Accuracy: 0.9258, NLL: 0.1945, ECE: 0.0102, F1: 0.9258
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 23/100
# Epoch 1 -- Train Loss: 0.3039, Val Loss: 0.2171
# Epoch 2 -- Train Loss: 0.2170, Val Loss: 0.2041
# Epoch 3 -- Train Loss: 0.1952, Val Loss: 0.1974
# Epoch 4 -- Train Loss: 0.1828, Val Loss: 0.1977
# Epoch 5 -- Train Loss: 0.1702, Val Loss: 0.2040
# Epoch 6 -- Train Loss: 0.1616, Val Loss: 0.1986
# Early stopping for this model triggered at epoch 6.
# Model 23: Accuracy = 0.9246, NLL = 0.1986, ECE = 0.0159, F1 = 0.9246
# Ensemble Size 23 -- Accuracy: 0.9254, NLL: 0.1942, ECE: 0.0110, F1: 0.9254
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 24/100
# Epoch 1 -- Train Loss: 0.3002, Val Loss: 0.2131
# Epoch 2 -- Train Loss: 0.2168, Val Loss: 0.2003
# Epoch 3 -- Train Loss: 0.1955, Val Loss: 0.1998
# Epoch 4 -- Train Loss: 0.1854, Val Loss: 0.1971
# Epoch 5 -- Train Loss: 0.1728, Val Loss: 0.1966
# Epoch 6 -- Train Loss: 0.1619, Val Loss: 0.1982
# Epoch 7 -- Train Loss: 0.1515, Val Loss: 0.2067
# Epoch 8 -- Train Loss: 0.1402, Val Loss: 0.2081
# Early stopping for this model triggered at epoch 8.
# Model 24: Accuracy = 0.9238, NLL = 0.2081, ECE = 0.0150, F1 = 0.9238
# Ensemble Size 24 -- Accuracy: 0.9250, NLL: 0.1942, ECE: 0.0115, F1: 0.9250
# No ensemble improvement count: 1/3
#
# Training MLP 25/100
# Epoch 1 -- Train Loss: 0.3082, Val Loss: 0.2175
# Epoch 2 -- Train Loss: 0.2156, Val Loss: 0.2015
# Epoch 3 -- Train Loss: 0.1980, Val Loss: 0.2062
# Epoch 4 -- Train Loss: 0.1839, Val Loss: 0.1945
# Epoch 5 -- Train Loss: 0.1769, Val Loss: 0.2028
# Epoch 6 -- Train Loss: 0.1620, Val Loss: 0.1997
# Epoch 7 -- Train Loss: 0.1495, Val Loss: 0.2085
# Early stopping for this model triggered at epoch 7.
# Model 25: Accuracy = 0.9204, NLL = 0.2085, ECE = 0.0160, F1 = 0.9204
# Ensemble Size 25 -- Accuracy: 0.9254, NLL: 0.1942, ECE: 0.0110, F1: 0.9254
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 26/100
# Epoch 1 -- Train Loss: 0.2992, Val Loss: 0.2152
# Epoch 2 -- Train Loss: 0.2162, Val Loss: 0.2090
# Epoch 3 -- Train Loss: 0.2026, Val Loss: 0.2046
# Epoch 4 -- Train Loss: 0.1813, Val Loss: 0.1981
# Epoch 5 -- Train Loss: 0.1725, Val Loss: 0.2006
# Epoch 6 -- Train Loss: 0.1579, Val Loss: 0.2011
# Epoch 7 -- Train Loss: 0.1488, Val Loss: 0.2135
# Early stopping for this model triggered at epoch 7.
# Model 26: Accuracy = 0.9186, NLL = 0.2135, ECE = 0.0146, F1 = 0.9186
# Ensemble Size 26 -- Accuracy: 0.9248, NLL: 0.1943, ECE: 0.0116, F1: 0.9248
# No ensemble improvement count: 1/3
#
# Training MLP 27/100
# Epoch 1 -- Train Loss: 0.3024, Val Loss: 0.2145
# Epoch 2 -- Train Loss: 0.2153, Val Loss: 0.2051
# Epoch 3 -- Train Loss: 0.1992, Val Loss: 0.2044
# Epoch 4 -- Train Loss: 0.1841, Val Loss: 0.1989
# Epoch 5 -- Train Loss: 0.1720, Val Loss: 0.1993
# Epoch 6 -- Train Loss: 0.1610, Val Loss: 0.2061
# Epoch 7 -- Train Loss: 0.1505, Val Loss: 0.2122
# Early stopping for this model triggered at epoch 7.
# Model 27: Accuracy = 0.9232, NLL = 0.2122, ECE = 0.0173, F1 = 0.9232
# Ensemble Size 27 -- Accuracy: 0.9252, NLL: 0.1944, ECE: 0.0116, F1: 0.9252
# No ensemble improvement count: 2/3
#
# Training MLP 28/100
# Epoch 1 -- Train Loss: 0.3063, Val Loss: 0.2151
# Epoch 2 -- Train Loss: 0.2147, Val Loss: 0.2090
# Epoch 3 -- Train Loss: 0.1978, Val Loss: 0.1991
# Epoch 4 -- Train Loss: 0.1854, Val Loss: 0.1988
# Epoch 5 -- Train Loss: 0.1728, Val Loss: 0.1992
# Epoch 6 -- Train Loss: 0.1642, Val Loss: 0.1994
# Epoch 7 -- Train Loss: 0.1505, Val Loss: 0.2056
# Early stopping for this model triggered at epoch 7.
# Model 28: Accuracy = 0.9224, NLL = 0.2056, ECE = 0.0163, F1 = 0.9224
# Ensemble Size 28 -- Accuracy: 0.9264, NLL: 0.1943, ECE: 0.0099, F1: 0.9264
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 29/100
# Epoch 1 -- Train Loss: 0.3052, Val Loss: 0.2155
# Epoch 2 -- Train Loss: 0.2173, Val Loss: 0.2028
# Epoch 3 -- Train Loss: 0.1977, Val Loss: 0.1981
# Epoch 4 -- Train Loss: 0.1817, Val Loss: 0.1969
# Epoch 5 -- Train Loss: 0.1711, Val Loss: 0.2042
# Epoch 6 -- Train Loss: 0.1618, Val Loss: 0.2035
# Epoch 7 -- Train Loss: 0.1509, Val Loss: 0.2049
# Early stopping for this model triggered at epoch 7.
# Model 29: Accuracy = 0.9266, NLL = 0.2049, ECE = 0.0156, F1 = 0.9266
# Ensemble Size 29 -- Accuracy: 0.9264, NLL: 0.1942, ECE: 0.0097, F1: 0.9264
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 30/100
# Epoch 1 -- Train Loss: 0.2995, Val Loss: 0.2129
# Epoch 2 -- Train Loss: 0.2182, Val Loss: 0.2044
# Epoch 3 -- Train Loss: 0.1978, Val Loss: 0.2049
# Epoch 4 -- Train Loss: 0.1840, Val Loss: 0.2016
# Epoch 5 -- Train Loss: 0.1712, Val Loss: 0.2004
# Epoch 6 -- Train Loss: 0.1586, Val Loss: 0.2039
# Epoch 7 -- Train Loss: 0.1504, Val Loss: 0.2056
# Epoch 8 -- Train Loss: 0.1400, Val Loss: 0.2050
# Early stopping for this model triggered at epoch 8.
# Model 30: Accuracy = 0.9238, NLL = 0.2050, ECE = 0.0123, F1 = 0.9238
# Ensemble Size 30 -- Accuracy: 0.9266, NLL: 0.1942, ECE: 0.0091, F1: 0.9266
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 31/100
# Epoch 1 -- Train Loss: 0.3030, Val Loss: 0.2163
# Epoch 2 -- Train Loss: 0.2162, Val Loss: 0.2045
# Epoch 3 -- Train Loss: 0.1975, Val Loss: 0.2005
# Epoch 4 -- Train Loss: 0.1813, Val Loss: 0.1958
# Epoch 5 -- Train Loss: 0.1729, Val Loss: 0.2051
# Epoch 6 -- Train Loss: 0.1600, Val Loss: 0.2020
# Epoch 7 -- Train Loss: 0.1478, Val Loss: 0.2004
# Early stopping for this model triggered at epoch 7.
# Model 31: Accuracy = 0.9246, NLL = 0.2004, ECE = 0.0133, F1 = 0.9246
# Ensemble Size 31 -- Accuracy: 0.9268, NLL: 0.1940, ECE: 0.0094, F1: 0.9268
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 32/100
# Epoch 1 -- Train Loss: 0.3052, Val Loss: 0.2142
# Epoch 2 -- Train Loss: 0.2176, Val Loss: 0.2062
# Epoch 3 -- Train Loss: 0.1975, Val Loss: 0.1943
# Epoch 4 -- Train Loss: 0.1808, Val Loss: 0.2014
# Epoch 5 -- Train Loss: 0.1742, Val Loss: 0.2032
# Epoch 6 -- Train Loss: 0.1586, Val Loss: 0.2034
# Early stopping for this model triggered at epoch 6.
# Model 32: Accuracy = 0.9224, NLL = 0.2034, ECE = 0.0115, F1 = 0.9224
# Ensemble Size 32 -- Accuracy: 0.9268, NLL: 0.1938, ECE: 0.0095, F1: 0.9268
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 33/100
# Epoch 1 -- Train Loss: 0.3047, Val Loss: 0.2147
# Epoch 2 -- Train Loss: 0.2156, Val Loss: 0.2030
# Epoch 3 -- Train Loss: 0.1958, Val Loss: 0.1992
# Epoch 4 -- Train Loss: 0.1830, Val Loss: 0.1985
# Epoch 5 -- Train Loss: 0.1741, Val Loss: 0.2076
# Epoch 6 -- Train Loss: 0.1605, Val Loss: 0.1982
# Epoch 7 -- Train Loss: 0.1483, Val Loss: 0.2051
# Epoch 8 -- Train Loss: 0.1435, Val Loss: 0.2069
# Epoch 9 -- Train Loss: 0.1303, Val Loss: 0.2164
# Early stopping for this model triggered at epoch 9.
# Model 33: Accuracy = 0.9208, NLL = 0.2164, ECE = 0.0189, F1 = 0.9208
# Ensemble Size 33 -- Accuracy: 0.9266, NLL: 0.1939, ECE: 0.0099, F1: 0.9266
# No ensemble improvement count: 1/3
#
# Training MLP 34/100
# Epoch 1 -- Train Loss: 0.3072, Val Loss: 0.2174
# Epoch 2 -- Train Loss: 0.2170, Val Loss: 0.2039
# Epoch 3 -- Train Loss: 0.1982, Val Loss: 0.1991
# Epoch 4 -- Train Loss: 0.1832, Val Loss: 0.2027
# Epoch 5 -- Train Loss: 0.1714, Val Loss: 0.2011
# Epoch 6 -- Train Loss: 0.1604, Val Loss: 0.2011
# Early stopping for this model triggered at epoch 6.
# Model 34: Accuracy = 0.9250, NLL = 0.2011, ECE = 0.0108, F1 = 0.9250
# Ensemble Size 34 -- Accuracy: 0.9268, NLL: 0.1938, ECE: 0.0099, F1: 0.9268
# No ensemble improvement count: 2/3
#
# Training MLP 35/100
# Epoch 1 -- Train Loss: 0.3071, Val Loss: 0.2164
# Epoch 2 -- Train Loss: 0.2187, Val Loss: 0.2075
# Epoch 3 -- Train Loss: 0.1973, Val Loss: 0.1983
# Epoch 4 -- Train Loss: 0.1855, Val Loss: 0.1979
# Epoch 5 -- Train Loss: 0.1713, Val Loss: 0.1989
# Epoch 6 -- Train Loss: 0.1581, Val Loss: 0.2001
# Epoch 7 -- Train Loss: 0.1523, Val Loss: 0.2023
# Early stopping for this model triggered at epoch 7.
# Model 35: Accuracy = 0.9242, NLL = 0.2023, ECE = 0.0128, F1 = 0.9242
# Ensemble Size 35 -- Accuracy: 0.9264, NLL: 0.1937, ECE: 0.0108, F1: 0.9264
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 40/100
# Epoch 1 -- Train Loss: 0.3037, Val Loss: 0.2164
# Epoch 2 -- Train Loss: 0.2178, Val Loss: 0.2045
# Epoch 3 -- Train Loss: 0.1999, Val Loss: 0.2003
# Epoch 4 -- Train Loss: 0.1825, Val Loss: 0.2015
# Epoch 5 -- Train Loss: 0.1714, Val Loss: 0.1979
# Epoch 6 -- Train Loss: 0.1614, Val Loss: 0.2021
# Epoch 7 -- Train Loss: 0.1511, Val Loss: 0.1993
# Epoch 8 -- Train Loss: 0.1399, Val Loss: 0.2149
# Early stopping for this model triggered at epoch 8.
# Model 40: Accuracy = 0.9260, NLL = 0.2149, ECE = 0.0237, F1 = 0.9260
# Ensemble Size 40 -- Accuracy: 0.9264, NLL: 0.1939, ECE: 0.0109, F1: 0.9264
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 41/100
# Epoch 1 -- Train Loss: 0.3113, Val Loss: 0.2150
# Epoch 2 -- Train Loss: 0.2165, Val Loss: 0.2031
# Epoch 3 -- Train Loss: 0.1989, Val Loss: 0.1941
# Epoch 4 -- Train Loss: 0.1852, Val Loss: 0.2028
# Epoch 5 -- Train Loss: 0.1684, Val Loss: 0.2022
# Epoch 6 -- Train Loss: 0.1606, Val Loss: 0.2043
# Early stopping for this model triggered at epoch 6.
# Model 41: Accuracy = 0.9210, NLL = 0.2043, ECE = 0.0125, F1 = 0.9210
# Ensemble Size 41 -- Accuracy: 0.9260, NLL: 0.1938, ECE: 0.0112, F1: 0.9260
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 42/100
# Epoch 1 -- Train Loss: 0.3036, Val Loss: 0.2148
# Epoch 2 -- Train Loss: 0.2161, Val Loss: 0.2043
# Epoch 3 -- Train Loss: 0.1967, Val Loss: 0.2041
# Epoch 4 -- Train Loss: 0.1832, Val Loss: 0.1982
# Epoch 5 -- Train Loss: 0.1686, Val Loss: 0.2005
# Epoch 6 -- Train Loss: 0.1600, Val Loss: 0.2004
# Epoch 7 -- Train Loss: 0.1492, Val Loss: 0.2054
# Early stopping for this model triggered at epoch 7.
# Model 42: Accuracy = 0.9226, NLL = 0.2054, ECE = 0.0142, F1 = 0.9226
# Ensemble Size 42 -- Accuracy: 0.9258, NLL: 0.1938, ECE: 0.0113, F1: 0.9258
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 43/100
# Epoch 1 -- Train Loss: 0.3040, Val Loss: 0.2155
# Epoch 2 -- Train Loss: 0.2168, Val Loss: 0.2050
# Epoch 3 -- Train Loss: 0.1965, Val Loss: 0.2029
# Epoch 4 -- Train Loss: 0.1816, Val Loss: 0.2002
# Epoch 5 -- Train Loss: 0.1694, Val Loss: 0.1960
# Epoch 6 -- Train Loss: 0.1624, Val Loss: 0.2054
# Epoch 7 -- Train Loss: 0.1498, Val Loss: 0.2070
# Epoch 8 -- Train Loss: 0.1394, Val Loss: 0.2053
# Early stopping for this model triggered at epoch 8.
# Model 43: Accuracy = 0.9218, NLL = 0.2053, ECE = 0.0142, F1 = 0.9218
# Ensemble Size 43 -- Accuracy: 0.9262, NLL: 0.1938, ECE: 0.0093, F1: 0.9262
# Ensemble performance improved (NLL or ECE decreased, ACC or F1 increased).
#
# Training MLP 44/100
# Epoch 1 -- Train Loss: 0.3011, Val Loss: 0.2162
# Epoch 2 -- Train Loss: 0.2165, Val Loss: 0.2077
# Epoch 3 -- Train Loss: 0.1966, Val Loss: 0.1992
# Epoch 4 -- Train Loss: 0.1813, Val Loss: 0.1971
# Epoch 5 -- Train Loss: 0.1701, Val Loss: 0.2040
# Epoch 6 -- Train Loss: 0.1598, Val Loss: 0.2016
# Epoch 7 -- Train Loss: 0.1492, Val Loss: 0.2092
# Early stopping for this model triggered at epoch 7.
# Model 44: Accuracy = 0.9200, NLL = 0.2092, ECE = 0.0176, F1 = 0.9200
# Ensemble Size 44 -- Accuracy: 0.9258, NLL: 0.1939, ECE: 0.0105, F1: 0.9258
# No ensemble improvement count: 1/3
#
# Training MLP 45/100
# Epoch 1 -- Train Loss: 0.3034, Val Loss: 0.2155
# Epoch 2 -- Train Loss: 0.2169, Val Loss: 0.2055
# Epoch 3 -- Train Loss: 0.1987, Val Loss: 0.1979
# Epoch 4 -- Train Loss: 0.1817, Val Loss: 0.2003
# Epoch 5 -- Train Loss: 0.1692, Val Loss: 0.2021
# Epoch 6 -- Train Loss: 0.1562, Val Loss: 0.2054
# Early stopping for this model triggered at epoch 6.
# Model 45: Accuracy = 0.9216, NLL = 0.2054, ECE = 0.0134, F1 = 0.9216
# Ensemble Size 45 -- Accuracy: 0.9262, NLL: 0.1939, ECE: 0.0096, F1: 0.9262
# No ensemble improvement count: 2/3
#
# Training MLP 46/100
# Epoch 1 -- Train Loss: 0.3001, Val Loss: 0.2113
# Epoch 2 -- Train Loss: 0.2201, Val Loss: 0.2052
# Epoch 3 -- Train Loss: 0.1970, Val Loss: 0.2017
# Epoch 4 -- Train Loss: 0.1829, Val Loss: 0.2014
# Epoch 5 -- Train Loss: 0.1750, Val Loss: 0.2004
# Epoch 6 -- Train Loss: 0.1582, Val Loss: 0.2036
# Epoch 7 -- Train Loss: 0.1531, Val Loss: 0.2014
# Epoch 8 -- Train Loss: 0.1360, Val Loss: 0.2070
# Early stopping for this model triggered at epoch 8.
# Model 46: Accuracy = 0.9250, NLL = 0.2070, ECE = 0.0172, F1 = 0.9250
# Ensemble Size 46 -- Accuracy: 0.9250, NLL: 0.1939, ECE: 0.0110, F1: 0.9250
# No ensemble improvement count: 3/3
# Ensemble-level early stopping triggered after 46 models.

# %% [markdown]
# ### The method used above for ensemble prediction is averaging (Mean Voting)
#    - **Description**: Each MLP produces a probability distribution over classes or a continuous output. The ensemble output is the average of these predictions.
#    - **Application**: Commonly used for regression tasks or classification tasks where probabilities are averaged.
#    - **Pros**: Simple to implement; works well when individual models are reasonably accurate and diverse.
#    - **Cons**: Does not account for cases where some models are more accurate than others.

# %%
all_probs = ensemble_probs['probs']

# Predictive mean (averaged probabilities)
mean_probs = ensemble_probs['mean']

# Predictive variance (epistemic uncertainty)
variance_probs = ensemble_probs['var']

# Predictive entropy
entropy = ensemble_probs['entropy']

# %% [markdown]
# ## Predictive Variance Histogram
# Purpose: To see the distribution of uncertainties across all predictions.

# %%
# Sum variances across classes if multi-class (for overall uncertainty)
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.hist(total_variance, bins=50, color='skyblue', edgecolor='black')
plt.title('Histogram of Predictive Variance')
plt.xlabel('Predictive Variance')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Predictive Entropy Histogram
# Purpose: Similar to variance, entropy gives a sense of uncertainty in predictions.

# %%
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Scatter Plots of Uncertainty vs. Confidence
#
# Purpose: To observe the relationship between model confidence and uncertainty.

# %%
# Model confidence: max probability from mean_probs
confidence = np.max(mean_probs, axis=1)

# Total variance or entropy as uncertainty measure
total_variance = np.sum(variance_probs, axis=1)

plt.figure(figsize=(8, 6))
plt.scatter(confidence, total_variance, alpha=0.5)
plt.title('Predictive Variance vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Variance')
plt.show()

# %% [markdown]
# ## Uncertainty vs. Correctness
# Purpose: To check if higher uncertainties correspond to incorrect predictions.

# %%
# # Predicted labels
# predicted_labels = np.argmax(mean_probs, axis=1)

# # True labels
# true_labels = val_y.numpy()

# # Correct predictions
# correct = (predicted_labels == true_labels)

# # Total variance or entropy
# total_variance = np.sum(variance_probs, axis=1)

# plt.figure(figsize=(8, 6))
# plt.scatter(total_variance, correct, alpha=0.5, c=correct, cmap='bwr')
# plt.title('Predictive Variance vs. Correctness')
# plt.xlabel('Predictive Variance')
# plt.ylabel('Correct Prediction (1=True, 0=False)')
# plt.show()

# %% [markdown]
# ## Reliability Diagram (Calibration Curve)
# Purpose: To assess how well the predicted probabilities are calibrated.

# %%
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.
# ensemble_prob_pos = mean_probs[:, 1]  # Extract probability for positive class
# val_y = torch.from_numpy(imdb_val_la).long()
# plot_reliability_diagram(ensemble_prob_pos, val_y.numpy(), n_bins=10)

# %%
# Assume ensemble_probs is computed in your training loop as the averaged probability outputs on the validation set.

# single_probs = all_probs[5]
# single_prob_pos = single_probs[:, 1]  # Extract probability for positive class
# plot_reliability_diagram(single_prob_pos, val_y.numpy(), n_bins=10)

# %% [markdown]
# ## Misclassification vs. Uncertainty
# Highlight samples where the model is both uncertain and incorrect.

# %%
# # Identify misclassified samples with high uncertainty
# incorrect = (predicted_labels != true_labels)
# high_uncertainty = entropy > np.percentile(entropy, 75)  # Top 25% uncertainty

# misclassified_uncertain = incorrect & high_uncertainty

# # Print or visualize these samples
# print(f"Number of misclassified and highly uncertain samples: {np.sum(misclassified_uncertain)}")

# %% [markdown]
# ## Comparative Plots Between Individual Models and Ensemble
# Purpose: To show how the ensemble reduces uncertainty compared to individual models.

# %%
# Compute uncertainties for individual models
entropies_individual = []
for probs in all_probs:
    entropy_individual = -np.sum(probs * np.log(probs + 1e-9), axis=1)
    entropies_individual.append(entropy_individual) 

# Average individual entropies
mean_entropy_individual = np.mean(entropies_individual, axis=0)

# Plot comparison
plt.figure(figsize=(8, 6))
plt.hist(mean_entropy_individual, bins=50, alpha=0.5, label='Individual Models')
plt.hist(entropy, bins=50, alpha=0.5, label='Ensemble')
plt.title('Entropy Distribution: Individual vs Ensemble')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Additional Tips:
#
# - Interactive Visualizations: Use tools like Plotly or Bokeh for interactive plots that allow you to hover over data points to see exact values.
# - Dimension Reduction: Apply techniques like t-SNE or UMAP to project high-dimensional data into 2D and color-code the points based on uncertainty.

# %%
# from sklearn.manifold import TSNE

# tsne = TSNE(n_components=2, random_state=0)
# embeddings_2d = tsne.fit_transform(val_X.numpy())

# plt.figure(figsize=(8, 6))
# plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=entropy, cmap='viridis', alpha=0.7)
# plt.colorbar(label='Predictive Entropy')
# plt.title('t-SNE Projection Colored by Uncertainty')
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.show()

# %% [markdown]
# - 	Thresholding: Set thresholds for uncertainty measures to flag or further investigate certain predictions.
#
# Integrating Visualizations into Your Workflow:
#
# 1.	Run the ensemble_uncertainty Function:
#
# mean_probs, variance_probs, entropy = ensemble_uncertainty(ensemble_models, val_X, device)
#
#
# 2.	Choose Appropriate Visualizations:
# - For overall understanding, start with histograms.
# - To explore relationships, use scatter plots.
# - For calibration, use reliability diagrams.
# - For data with spatial structure, consider heatmaps.
# 3.	Interpret the Results:
# - High Variance/Entropy: Indicates where the model is uncertain; consider investigating these samples.
# - Calibration Curves: Help you understand if the probabilities reflect true likelihoods.
# - Misclassifications with High Uncertainty: Potentially difficult samples or outliers.
# 4.	Refine the Model:
# - Use insights from visualizations to improve data preprocessing, model architecture, or training strategies.
# - Consider collecting more data in regions of high uncertainty.
#
# Example Workflow:
#
# Here’s how you might put it all together:

# %%
all_probs = ensemble_probs['probs']

# Predictive mean (averaged probabilities)
mean_probs = ensemble_probs['mean']

# Predictive variance (epistemic uncertainty)
variance_probs = ensemble_probs['var']

# Predictive entropy
entropy = ensemble_probs['entropy']

# Step 2: Visualize Histogram of Predictive Entropy
plt.figure(figsize=(8, 6))
plt.hist(entropy, bins=50, color='salmon', edgecolor='black')
plt.title('Histogram of Predictive Entropy')
plt.xlabel('Predictive Entropy')
plt.ylabel('Frequency')
plt.show()

# Step 3: Scatter Plot of Confidence vs. Predictive Entropy
confidence = np.max(mean_probs, axis=1)
plt.figure(figsize=(8, 6))
plt.scatter(confidence, entropy, alpha=0.5)
plt.title('Predictive Entropy vs. Confidence')
plt.xlabel('Model Confidence')
plt.ylabel('Predictive Entropy')
plt.show()

# Step 4: Reliability Diagram
# from sklearn.calibration import calibration_curve

# prob_pos = mean_probs[:, 1]
# fraction_of_positives, mean_predicted_value = calibration_curve(val_y.numpy(), prob_pos, n_bins=10)

# plt.figure(figsize=(8, 6))
# plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Ensemble")
# plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
# plt.title('Reliability Diagram')
# plt.xlabel('Mean Predicted Probability')
# plt.ylabel('Fraction of Positives')
# plt.legend()
# plt.show()

# %% [markdown]
# By employing these visualization techniques, you’ll gain a deeper understanding of where and why your model is uncertain. This can guide you in making informed decisions about model improvements, data collection, or even deploying the model in real-world scenarios where uncertainty estimation is critical.
#
# Remember, the key is not just to compute uncertainty measures but to interpret them in the context of your specific problem and data.

# %% [markdown]
# # Distilation

# %% [markdown]
# Certainly! Knowledge distillation is a technique where a smaller model (student) is trained to replicate the behavior of a larger model or an ensemble of models (teacher). In your case, you can distill the knowledge from the ensemble of MLP models into a single MLP model.
#
# Here’s how you can proceed:
# 	1.	Generate Soft Targets: Use the ensemble to generate probability distributions (soft labels) for the training data.
# 	2.	Train the Student Model: Train a single MLP model using these soft targets, minimizing the difference between the student’s outputs and the soft targets from the ensemble.
# 	3.	Implement Distillation Loss: Use a combination of cross-entropy loss with the true labels and Kullback-Leibler (KL) divergence loss with the soft labels.
#
# Below is the complete code integrating knowledge distillation into your existing setup.
#
# Step-by-Step Guide
#
# 1. Generate Soft Targets from the Ensemble
#
# - Use the trained ensemble models to generate the averaged probabilities (mean of softmax outputs) for the training data.
#
# 2. Define the Student Model
#
# - Create a new MLP model that will serve as the student.
#
# 3. Implement the Distillation Loss Function
#
# - Use a custom loss function that combines the standard cross-entropy loss with the KL divergence between the student’s outputs and the soft targets.
# - Introduce a temperature parameter T to soften the probabilities.
#
# 4. Train the Student Model
#
# - Train the student model on the training data using the distillation loss.
# - Monitor the validation performance.

# %%
# Ignore warnings of a specific category
warnings.filterwarnings('ignore', category=UserWarning)

student_model, loss_plot = train_student_model(
    MLP, imdb_train_em, imdb_train_la, 
    imdb_test_em, imdb_test_la, ensemble_models, 
    epochs=100, T=1.0, alpha=0.1, patience=5)

# Re-enable warnings by clearing or overriding the filter
warnings.filterwarnings('default', category=UserWarning)
# Out:
# Epoch 1/100, Loss: 0.4712
# Validation -- Accuracy: 0.8740, NLL: 0.3081, ECE: 0.0163, F1 Score: 0.8737
# Epoch 2/100, Loss: 0.1850
# Validation -- Accuracy: 0.9054, NLL: 0.2419, ECE: 0.0126, F1 Score: 0.9054
# Epoch 3/100, Loss: 0.1127
# Validation -- Accuracy: 0.9127, NLL: 0.2221, ECE: 0.0084, F1 Score: 0.9127
# Epoch 4/100, Loss: 0.0897
# Validation -- Accuracy: 0.9145, NLL: 0.2155, ECE: 0.0084, F1 Score: 0.9145
# Epoch 5/100, Loss: 0.0784
# Validation -- Accuracy: 0.9180, NLL: 0.2101, ECE: 0.0097, F1 Score: 0.9179
# Epoch 6/100, Loss: 0.0698
# Validation -- Accuracy: 0.9201, NLL: 0.2071, ECE: 0.0108, F1 Score: 0.9200
# Epoch 7/100, Loss: 0.0616
# Validation -- Accuracy: 0.9202, NLL: 0.2055, ECE: 0.0100, F1 Score: 0.9201
# Epoch 8/100, Loss: 0.0590
# Validation -- Accuracy: 0.9215, NLL: 0.2042, ECE: 0.0098, F1 Score: 0.9215
# Epoch 9/100, Loss: 0.0545
# Validation -- Accuracy: 0.9221, NLL: 0.2029, ECE: 0.0093, F1 Score: 0.9220
# Epoch 10/100, Loss: 0.0508
# Validation -- Accuracy: 0.9229, NLL: 0.2018, ECE: 0.0100, F1 Score: 0.9229
# Epoch 11/100, Loss: 0.0464
# Validation -- Accuracy: 0.9224, NLL: 0.2016, ECE: 0.0093, F1 Score: 0.9224
# Epoch 12/100, Loss: 0.0440
# Validation -- Accuracy: 0.9225, NLL: 0.2022, ECE: 0.0098, F1 Score: 0.9225
# No improvement for 1 consecutive epoch(s).
# Epoch 13/100, Loss: 0.0433
# Validation -- Accuracy: 0.9222, NLL: 0.2015, ECE: 0.0082, F1 Score: 0.9221
# Epoch 14/100, Loss: 0.0402
# Validation -- Accuracy: 0.9233, NLL: 0.2011, ECE: 0.0094, F1 Score: 0.9233
# Epoch 15/100, Loss: 0.0382
# Validation -- Accuracy: 0.9232, NLL: 0.2009, ECE: 0.0103, F1 Score: 0.9232
# Epoch 16/100, Loss: 0.0361
# Validation -- Accuracy: 0.9248, NLL: 0.2006, ECE: 0.0113, F1 Score: 0.9248
# Epoch 17/100, Loss: 0.0346
# Validation -- Accuracy: 0.9232, NLL: 0.2011, ECE: 0.0104, F1 Score: 0.9232
# Epoch 18/100, Loss: 0.0328
# Validation -- Accuracy: 0.9240, NLL: 0.2013, ECE: 0.0117, F1 Score: 0.9239
# No improvement for 1 consecutive epoch(s).
# Epoch 19/100, Loss: 0.0310
# Validation -- Accuracy: 0.9247, NLL: 0.2002, ECE: 0.0114, F1 Score: 0.9247
# Epoch 20/100, Loss: 0.0306
# Validation -- Accuracy: 0.9244, NLL: 0.2013, ECE: 0.0113, F1 Score: 0.9244
# Epoch 21/100, Loss: 0.0299
# Validation -- Accuracy: 0.9242, NLL: 0.2000, ECE: 0.0099, F1 Score: 0.9241
# Epoch 22/100, Loss: 0.0289
# Validation -- Accuracy: 0.9240, NLL: 0.2001, ECE: 0.0100, F1 Score: 0.9240
# No improvement for 1 consecutive epoch(s).
# Epoch 23/100, Loss: 0.0265
# Validation -- Accuracy: 0.9245, NLL: 0.2011, ECE: 0.0121, F1 Score: 0.9245
# No improvement for 2 consecutive epoch(s).
# Epoch 24/100, Loss: 0.0269
# Validation -- Accuracy: 0.9238, NLL: 0.2011, ECE: 0.0111, F1 Score: 0.9238
# No improvement for 3 consecutive epoch(s).
# Epoch 25/100, Loss: 0.0259
# Validation -- Accuracy: 0.9240, NLL: 0.2004, ECE: 0.0112, F1 Score: 0.9239
# No improvement for 4 consecutive epoch(s).
# Epoch 26/100, Loss: 0.0247
# Validation -- Accuracy: 0.9243, NLL: 0.2005, ECE: 0.0101, F1 Score: 0.9242
# No improvement for 5 consecutive epoch(s).
# Early stopping triggered at epoch 26. Restoring best model.

# %% [markdown]
# ## Eval in train set

# %%
metrics = evaluate_models(imdb_train_em, imdb_train_la, student_model, ensemble_models, device, 
                          batch_size=2024, dataset_key="imdb_train", trained_dataset="IMDB")
# Out:
# Student -- Accuracy: 0.9584, NLL: 0.1227, ECE: 0.0200, F1 Score: 0.9584
# Individual -- Accuracy: 0.9658, NLL: 0.0962, ECE: 0.0201, F1 Score: 0.9658
# Ensemble -- Accuracy: 0.9658, NLL: 0.1052, ECE: 0.0265, F1 Score: 0.9658

# %% [markdown]
# ## Eval on test set

# %%
metrics = evaluate_models(imdb_test_em, imdb_test_la, student_model, ensemble_models, device, 
                          batch_size=2024, dataset_key="imdb_test", trained_dataset="IMDB")
# Out:
# Student -- Accuracy: 0.9243, NLL: 0.2005, ECE: 0.0101, F1 Score: 0.9242
# Individual -- Accuracy: 0.9207, NLL: 0.2139, ECE: 0.0164, F1 Score: 0.9207
# Ensemble -- Accuracy: 0.9255, NLL: 0.1933, ECE: 0.0080, F1 Score: 0.9255

# %% [markdown]
# Explanation
#
# - Temperature (T): A higher temperature softens the probability distribution, making the model pay more attention to less probable classes. It’s common to set T=2.0 or higher.
# - Alpha (alpha): Balances the importance between the hard targets (true labels) and the soft targets (ensemble outputs). Adjusting alpha allows you to emphasize either the true labels or the knowledge from the ensemble.
# - DataLoader Modification: We ensure that the data loader does not shuffle the data so that the indices of the soft targets align with the batches.
#
# Notes
#
# - Device Management: Ensure that all tensors and models are on the same device during training and inference.
# - Memory Considerations: Storing soft targets for the entire dataset may consume significant memory for large datasets. If this is an issue, consider generating soft targets on-the-fly during training.
# - Performance Evaluation: After training, compare the performance of the student model with the ensemble and individual models to assess the effectiveness of distillation.

# %%
metrics = evaluate_models(train_em, train_la, student_model, ensemble_models, device, 
                          batch_size=2024, dataset_key="sst2_train", trained_dataset="IMDB")
# Out:
# Student -- Accuracy: 0.7304, NLL: 0.5726, ECE: 0.0678, F1 Score: 0.7313
# Individual -- Accuracy: 0.7228, NLL: 0.6225, ECE: 0.0888, F1 Score: 0.7235
# Ensemble -- Accuracy: 0.7318, NLL: 0.5652, ECE: 0.0668, F1 Score: 0.7327

# %% [markdown]
# ### CoLa

# %%
metrics = evaluate_models(cola_train_em, cola_train_la, student_model, ensemble_models, device, 
                          batch_size=2024, dataset_key="cola_train", trained_dataset="IMDB")
# Out:
# Student -- Accuracy: 0.4961, NLL: 1.0115, ECE: 0.2562, F1 Score: 0.5172
# Individual -- Accuracy: 0.5225, NLL: 1.0657, ECE: 0.2508, F1 Score: 0.5432
# Ensemble -- Accuracy: 0.5026, NLL: 1.0007, ECE: 0.2503, F1 Score: 0.5242
